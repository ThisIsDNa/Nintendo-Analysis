# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
plotly.tools.set_credentials_file(username='ThisIsDNa', api_key='RsEAzsWWOaupxCGJA00C')

sns.set(style="whitegrid", palette="pastel", color_codes=True)

init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
file = "Resources/Video_Games_Sales_as_at_22_Dec_2016.csv"
df = pd.read_csv(file).dropna()

# %%
df.drop(['EU_Sales', 'JP_Sales', 'Other_Sales'], axis=1, inplace = True)

# %%
df.rename(columns={'Year_of_Release': 'Release Date',
                       'NA_Sales': 'naSales',
                       'Global_Sales': 'gSales',
                       'Critic_Score': 'cScore',
                       'Critic_Count': 'cCount',
                       'User_Score': 'uScore',
                       'User_Count': 'uCount',
                       'Number_of_Games': 'Number of Games'}, inplace = True)

# %%
df = df[['Name',
         'Release Date',
         'Platform',
         'Developer',
         'Publisher',
         'cScore',
         'cCount',
         'uScore',
         'uCount',
         'naSales',
         'gSales',
         'Rating',
         'Genre']]

# %%
df['Release Date'] = df['Release Date'].astype('int64')
df['uScore'] = df['uScore'].astype('float64')
df['uCount'] = df['uCount'].astype('int64')
df['cScore'] = df['cScore'].astype('float64')
df['cCount'] = df['cCount'].astype('int64')

# %%
df.loc[:,'uScore']*= 10
df = df.iloc[1:]
df.head()
# Out:
#                         Name  Release Date Platform Developer Publisher  \
# 2             Mario Kart Wii          2008      Wii  Nintendo  Nintendo
# 3          Wii Sports Resort          2009      Wii  Nintendo  Nintendo
# 6      New Super Mario Bros.          2006       DS  Nintendo  Nintendo
# 7                   Wii Play          2006      Wii  Nintendo  Nintendo
# 8  New Super Mario Bros. Wii          2009      Wii  Nintendo  Nintendo
#
#    cScore  cCount  uScore  uCount  naSales  gSales Rating     Genre
# 2    82.0      73    83.0     709    15.68   35.52      E    Racing
# 3    80.0      73    80.0     192    15.61   32.77      E    Sports
# 6    89.0      65    85.0     431    11.28   29.80      E  Platform
# 7    58.0      41    66.0     129    13.96   28.92      E      Misc
# 8    87.0      80    84.0     594    14.44   28.32      E  Platform

# %%
#-----------------------------------------------------------------------
# TOP 10 BY PLATFORM && User Count
# - X360
# - PS3
# - PS4
# - PC
# - Wii
#-----------------------------------------------------------------------

is_X360 =  df['Platform']=='X360'
is_PS3 =  df['Platform']=='PS3'
is_PS4 =  df['Platform']=='PS4'
is_PC =  df['Platform']=='PC'
is_Wii =  df['Platform']=='Wii'

df_X360 = df[is_X360]
df_PS3 = df[is_PS3]
df_PS4 = df[is_PS4]
df_PC = df[is_PC]
df_Wii = df[is_Wii]

df_X360_TOP_10uC = df_X360.nlargest(10, 'uCount')
df_PS3_TOP_10uC = df_PS3.nlargest(10, 'uCount')
df_PS4_TOP_10uC = df_PS4.nlargest(10, 'uCount')
df_PC_TOP_10uC = df_PC.nlargest(10, 'uCount')
df_Wii_TOP_10uC = df_Wii.nlargest(10, 'uCount')

#-----------------------------------------------------------------------
# TOP 10 BY PLATFORM && Global Sales
#-----------------------------------------------------------------------

df_X360_TOP_10gS = df_X360.nlargest(10, 'gSales')
df_PS3_TOP_10gS = df_PS3.nlargest(10, 'gSales')
df_PS4_TOP_10gS = df_PS4.nlargest(10, 'gSales')
df_PC_TOP_10gS = df_PC.nlargest(10, 'gSales')
df_Wii_TOP_10gS = df_Wii.nlargest(10, 'gSales')

#-----------------------------------------------------------------------
# TOP 10 BY PLATFORM && North American Sales
#-----------------------------------------------------------------------

df_X360_TOP_10naS = df_X360.nlargest(10, 'naSales')
df_PS3_TOP_10naS = df_PS3.nlargest(10, 'naSales')
df_PS4_TOP_10naS = df_PS4.nlargest(10, 'naSales')
df_PC_TOP_10naS = df_PC.nlargest(10, 'naSales')
df_Wii_TOP_10naS = df_Wii.nlargest(10, 'naSales')

#-----------------------------------------------------------------------
# TOP 10 BY PLATFORM && Critic Score
#-----------------------------------------------------------------------

df_X360_TOP_10cS = df_X360.nlargest(10, 'cScore')
df_PS3_TOP_10cS = df_PS3.nlargest(10, 'cScore')
df_PS4_TOP_10cS = df_PS4.nlargest(10, 'cScore')
df_PC_TOP_10cS = df_PC.nlargest(10, 'cScore')
df_Wii_TOP_10cS = df_Wii.nlargest(10, 'cScore')

#-----------------------------------------------------------------------
# TOP 10 BY PLATFORM && User Score
#-----------------------------------------------------------------------

df_X360_TOP_10uS = df_X360.nlargest(10, 'uScore')
df_PS3_TOP_10uS = df_PS3.nlargest(10, 'uScore')
df_PS4_TOP_10uS = df_PS4.nlargest(10, 'uScore')
df_PC_TOP_10uS = df_PC.nlargest(10, 'uScore')
df_Wii_TOP_10uS = df_Wii.nlargest(10, 'uScore')

# %%
#-----------------------------------------------------------------------
# TOP 10 BY Publisher && User Count
# - Nintendo
# - Electronic Arts
# - Sony Computer Entertainment
# - Activision
# - Bethesda Softworks
#-----------------------------------------------------------------------

is_Nintendo = df['Publisher']=='Nintendo'
is_EA = df['Publisher']=='Electronic Arts'
is_Sony = df['Publisher']=='Sony Computer Entertainment'
is_Activision = df['Publisher']=='Activision'
is_Bethesda = df['Publisher']=='Bethesda Softworks'

df_Nintendo = df[is_Nintendo]
df_EA = df[is_EA]
df_Sony = df[is_Sony]
df_Activision = df[is_Activision]
df_Bethesda = df[is_Bethesda]

df_Nintendo_TOP_10uC = df_Nintendo.nlargest(10, 'uCount')
df_EA_TOP_10uC = df_EA.nlargest(10, 'uCount')
df_Sony_TOP_10uC = df_Sony.nlargest(10, 'uCount')
df_Activision_TOP_10uC = df_Activision.nlargest(10, 'uCount')
df_Bethesda_TOP_10uC = df_Bethesda.nlargest(10, 'uCount')

#-----------------------------------------------------------------------
# TOP 10 BY PUBLISHER && Global Sales
#-----------------------------------------------------------------------

df_Nintendo_TOP_10gS = df_Nintendo.nlargest(10, 'gSales')
df_EA_TOP_10gS = df_EA.nlargest(10, 'gSales')
df_Sony_TOP_10gS = df_Sony.nlargest(10, 'gSales')
df_Activision_TOP_10gS = df_Activision.nlargest(10, 'gSales')
df_Bethesda_TOP_10gS = df_Bethesda.nlargest(10, 'gSales')

#-----------------------------------------------------------------------
# TOP 10 BY PUBLISHER && North American Sales
#-----------------------------------------------------------------------

df_Nintendo_TOP_10naS = df_Nintendo.nlargest(10, 'naSales')
df_EA_TOP_10naS = df_EA.nlargest(10, 'naSales')
df_Sony_TOP_10naS = df_Sony.nlargest(10, 'naSales')
df_Activision_TOP_10naS = df_Activision.nlargest(10, 'naSales')
df_Bethesda_TOP_10naS = df_Bethesda.nlargest(10, 'naSales')

#-----------------------------------------------------------------------
# TOP 10 BY PUBLISHER && Critic Score
#-----------------------------------------------------------------------

df_Nintendo_TOP_10cS = df_Nintendo.nlargest(10, 'cScore')
df_EA_TOP_10cS = df_EA.nlargest(10, 'cScore')
df_Sony_TOP_10cS = df_Sony.nlargest(10, 'cScore')
df_Activision_TOP_10cS = df_Activision.nlargest(10, 'cScore')
df_Bethesda_TOP_10cS = df_Bethesda.nlargest(10, 'cScore')

#-----------------------------------------------------------------------
# TOP 10 BY PUBLISHER && User Score
#-----------------------------------------------------------------------

df_Nintendo_TOP_10uS = df_Nintendo.nlargest(10, 'uScore')
df_EA_TOP_10uS = df_EA.nlargest(10, 'uScore')
df_Sony_TOP_10uS = df_Sony.nlargest(10, 'uScore')
df_Activision_TOP_10uS = df_Activision.nlargest(10, 'uScore')
df_Bethesda_TOP_10uS = df_Bethesda.nlargest(10, 'uScore')

# %%
#-----------------------------------------------------------------------
# TOP 10 BY YEAR && User Count
# - 2011
# - 2012
# - 2013
# - 2014
# - 2015
#-----------------------------------------------------------------------

is_2011 = df['Release Date']==2011
is_2012 = df['Release Date']==2012
is_2013 = df['Release Date']==2013
is_2014 = df['Release Date']==2014
is_2015 = df['Release Date']==2014

df_2011 = df[is_2011]
df_2012 = df[is_2012]
df_2013 = df[is_2013]
df_2014 = df[is_2014]
df_2015 = df[is_2015]

df_2011_TOP_10uC = df_2011.nlargest(10, 'uCount')
df_2012_TOP_10uC = df_2012.nlargest(10, 'uCount')
df_2013_TOP_10uC = df_2013.nlargest(10, 'uCount')
df_2014_TOP_10uC = df_2014.nlargest(10, 'uCount')
df_2015_TOP_10uC = df_2015.nlargest(10, 'uCount')

#-----------------------------------------------------------------------
# TOP 10 BY YEAR && Global Sales
#-----------------------------------------------------------------------

df_2011_TOP_10gS = df_2011.nlargest(10, 'gSales')
df_2012_TOP_10gS = df_2012.nlargest(10, 'gSales')
df_2013_TOP_10gS = df_2013.nlargest(10, 'gSales')
df_2014_TOP_10gS = df_2014.nlargest(10, 'gSales')
df_2015_TOP_10gS = df_2015.nlargest(10, 'gSales')

#-----------------------------------------------------------------------
# TOP 10 BY YEAR && North American Sales
#-----------------------------------------------------------------------

df_2011_TOP_10naS = df_2011.nlargest(10, 'naSales')
df_2012_TOP_10naS = df_2012.nlargest(10, 'naSales')
df_2013_TOP_10naS = df_2013.nlargest(10, 'naSales')
df_2014_TOP_10naS = df_2014.nlargest(10, 'naSales')
df_2015_TOP_10naS = df_2015.nlargest(10, 'naSales')

#-----------------------------------------------------------------------
# TOP 10 BY YEAR && Critic Score
#-----------------------------------------------------------------------

df_2011_TOP_10cS = df_2011.nlargest(10, 'cScore')
df_2012_TOP_10cS = df_2012.nlargest(10, 'cScore')
df_2013_TOP_10cS = df_2013.nlargest(10, 'cScore')
df_2014_TOP_10cS = df_2014.nlargest(10, 'cScore')
df_2015_TOP_10cS = df_2015.nlargest(10, 'cScore')

#-----------------------------------------------------------------------
# TOP 10 BY YEAR && User Score
#-----------------------------------------------------------------------

df_2011_TOP_10uS = df_2011.nlargest(10, 'uScore')
df_2012_TOP_10uS = df_2012.nlargest(10, 'uScore')
df_2013_TOP_10uS = df_2013.nlargest(10, 'uScore')
df_2014_TOP_10uS = df_2014.nlargest(10, 'uScore')
df_2015_TOP_10uS = df_2015.nlargest(10, 'uScore')

# %%
#-----------------------------------------------------------------------
# TOP 10 BY GENRE && User Count
# - ACTION
# - SHOOTER
# - STRATEGY
# - SPORTS
# - ROLE-PLAYING
#-----------------------------------------------------------------------

is_Action = df['Genre']=='Action'
is_Shooter = df['Genre']=='Shooter'
is_Strategy = df['Genre']=='Strategy'
is_Sports = df['Genre']=='Sports'
is_RPG = df['Genre']=='Role-Playing'

df_Action = df[is_Action]
df_Shooter = df[is_Shooter]
df_Strategy = df[is_Strategy]
df_Sports = df[is_Sports]
df_RPG = df[is_RPG]

df_Action_TOP_10uC = df_Action.nlargest(10, 'uCount')
df_Shooter_TOP_10uC = df_Shooter.nlargest(10, 'uCount')
df_Strategy_TOP_10uC = df_Strategy.nlargest(10, 'uCount')
df_Sports_TOP_10uC = df_Sports.nlargest(10, 'uCount')
df_RPG_TOP_10uC = df_RPG.nlargest(10, 'uCount')

#-----------------------------------------------------------------------
# TOP 10 BY GENRE && Global Sales
#-----------------------------------------------------------------------

df_Action_TOP_10gS = df_Action.nlargest(10, 'gSales')
df_Shooter_TOP_10gS = df_Shooter.nlargest(10, 'gSales')
df_Strategy_TOP_10gS = df_Strategy.nlargest(10, 'gSales')
df_Sports_TOP_10gS = df_Sports.nlargest(10, 'gSales')
df_RPG_TOP_10gS = df_RPG.nlargest(10, 'gSales')

#-----------------------------------------------------------------------
# TOP 10 BY GENRE && North American Sales
#-----------------------------------------------------------------------

df_Action_TOP_10naS = df_Action.nlargest(10, 'naSales')
df_Shooter_TOP_10naS = df_Shooter.nlargest(10, 'naSales')
df_Strategy_TOP_10naS = df_Strategy.nlargest(10, 'naSales')
df_Sports_TOP_10naS = df_Sports.nlargest(10, 'naSales')
df_RPG_TOP_10naS = df_RPG.nlargest(10, 'naSales')

#-----------------------------------------------------------------------
# TOP 10 BY GENRE && Critic Score
#-----------------------------------------------------------------------

df_Action_TOP_10cS = df_Action.nlargest(10, 'cScore')
df_Shooter_TOP_10cS = df_Shooter.nlargest(10, 'cScore')
df_Strategy_TOP_10cS = df_Strategy.nlargest(10, 'cScore')
df_Sports_TOP_10cS = df_Sports.nlargest(10, 'cScore')
df_RPG_TOP_10cS = df_RPG.nlargest(10, 'cScore')

#-----------------------------------------------------------------------
# TOP 10 BY GENRE && User Score
#-----------------------------------------------------------------------

df_Action_TOP_10uS = df_Action.nlargest(10, 'uScore')
df_Shooter_TOP_10uS = df_Shooter.nlargest(10, 'uScore')
df_Strategy_TOP_10uS = df_Strategy.nlargest(10, 'uScore')
df_Sports_TOP_10uS = df_Sports.nlargest(10, 'uScore')
df_RPG_TOP_10uS = df_RPG.nlargest(10, 'uScore')

# %%
#-----------------------------------------------------------------------
# TOP 10 BY RATING && User Count
# - E
# - E10+
# - T
# - M
#-----------------------------------------------------------------------

is_E = df['Rating']=='E'
is_E10 = df['Rating']=='E10+'
is_T = df['Rating']=='T'
is_M = df['Rating']=='M'

df_E = df[is_E]
df_E10 = df[is_E10]
df_T = df[is_T]
df_M = df[is_M]

df_E_TOP_10uC = df_E.nlargest(10, 'uCount')
df_E10_TOP_10uC = df_E10.nlargest(10, 'uCount')
df_T_TOP_10uC = df_T.nlargest(10, 'uCount')
df_M_TOP_10uC = df_M.nlargest(10, 'uCount')

#-----------------------------------------------------------------------
# TOP 10 BY RATING && Global Sales
#-----------------------------------------------------------------------

df_E_TOP_10gS = df_E.nlargest(10, 'gSales')
df_E10_TOP_10gS = df_E10.nlargest(10, 'gSales')
df_T_TOP_10gS = df_T.nlargest(10, 'gSales')
df_M_TOP_10gS = df_M.nlargest(10, 'gSales')

#-----------------------------------------------------------------------
# TOP 10 BY RATING && North American Sales
#-----------------------------------------------------------------------

df_E_TOP_10naS = df_E.nlargest(10, 'naSales')
df_E10_TOP_10naS = df_E10.nlargest(10, 'naSales')
df_T_TOP_10naS = df_T.nlargest(10, 'naSales')
df_M_TOP_10naS = df_M.nlargest(10, 'naSales')

#-----------------------------------------------------------------------
# TOP 10 BY RATING && Critic Score
#-----------------------------------------------------------------------

df_E_TOP_10cS = df_E.nlargest(10, 'cScore')
df_E10_TOP_10cS = df_E10.nlargest(10, 'cScore')
df_T_TOP_10cS = df_T.nlargest(10, 'cScore')
df_M_TOP_10cS = df_M.nlargest(10, 'cScore')

#-----------------------------------------------------------------------
# TOP 10 BY RATING && User Score
#-----------------------------------------------------------------------

df_E_TOP_10uS = df_E.nlargest(10, 'uScore')
df_E10_TOP_10uS = df_E10.nlargest(10, 'uScore')
df_T_TOP_10uS = df_T.nlargest(10, 'uScore')
df_M_TOP_10uS = df_M.nlargest(10, 'uScore')

# %%
#-----------------------------------------------------------------------
# X360
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------
X360uC_bar_df = df_X360_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_X360_TOP_10uC.groupby('Name')[['gSales']].sum()
)
X360uC_bar_df.columns = ['naSales', 'gSales']
X360uC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=X360uC_bar_df.index,
    y=X360uC_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)


trace1 = go.Scatter(
    x=X360uC_bar_df.index,
    y=X360uC_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)


data = [trace0, trace1]
layout = {'title': 'Top 10 XBOX 360 Games (NA Sales vs Global Sales) [User Count]'}
X360uC_bar_fig = go.Figure(data=data, layout=layout)
iplot(X360uC_bar_fig, show_link=False)
# Out:
# <div id="901f7bd4-ada0-45f8-ad45-3179e30ae158" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("901f7bd4-ada0-45f8-ad45-3179e30ae158", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Grand Theft Auto V", "Call of Duty: Modern Warfare 3", "Call of Duty: Modern Warfare 2", "Halo 3", "Grand Theft Auto IV", "Halo 4", "The Elder Scrolls V: Skyrim", "Gears of War 2", "Mass Effect 2", "Mass Effect 3"], "y": [16.27, 14.73, 13.47, 12.12, 11.01, 9.71, 8.79, 6.75, 3.1, 3.04], "type": "bar", "uid": "ff1e9aa9-920c-454e-8d68-573b04e931f5"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Grand Theft Auto V", "Call of Duty: Modern Warfare 3", "Call of Duty: Modern Warfare 2", "Halo 3", "Grand Theft Auto IV", "Halo 4", "The Elder Scrolls V
# ...

# %%
X360cS_bar_df = df_X360_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_X360_TOP_10cS.groupby('Name')[['gSales']].sum()
)
X360cS_bar_df.columns = ['naSales', 'gSales']
X360cS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=X360cS_bar_df.index,
    y=X360cS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)


trace1 = go.Scatter(
    x=X360cS_bar_df.index,
    y=X360cS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 XBOX 360 Games (NA Sales vs Global Sales) [Critic Score]'}
X360cS_bar_fig = go.Figure(data=data, layout=layout)
iplot(X360cS_bar_fig, show_link=False)
# Out:
# <div id="4ce71201-a55e-4ba0-b1e2-86ef6f977974" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4ce71201-a55e-4ba0-b1e2-86ef6f977974", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Grand Theft Auto V", "Call of Duty: Modern Warfare 2", "Halo 3", "Grand Theft Auto IV", "The Elder Scrolls V: Skyrim", "Red Dead Redemption", "Mass Effect 2", "BioShock", "Portal 2", "The Orange Box"], "y": [16.27, 13.47, 12.12, 11.01, 8.79, 6.32, 3.1, 2.83, 2.08, 1.82], "type": "bar", "uid": "6a5a9cb9-55e5-466a-8c5f-61fcc788226c"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Grand Theft Auto V", "Call of Duty: Modern Warfare 2", "Halo 3", "Grand Theft Auto IV", "The Elder Scrolls V: Skyrim", "Red Dead Redemption", "Mass Effect 2", "BioShoc
# ...

# %%
X360uS_bar_df = df_X360_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_X360_TOP_10uS.groupby('Name')[['gSales']].sum()
)
X360uS_bar_df.columns = ['naSales', 'gSales']
X360uS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=X360uS_bar_df.index,
    y=X360uS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)


trace1 = go.Scatter(
    x=X360uS_bar_df.index,
    y=X360uS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 XBOX 360 Games (NA Sales vs Global Sales) [User Score]'}
X360uS_bar_fig = go.Figure(data=data, layout=layout)
iplot(X360uS_bar_fig, show_link=False)
# Out:
# <div id="575fe00b-a6c5-4347-bc36-780ed372b132" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("575fe00b-a6c5-4347-bc36-780ed372b132", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Red Dead Redemption", "Assassin's Creed II", "Mass Effect 2", "BioShock", "Fight Night Round 3", "The Orange Box", "Dance Dance Revolution Universe", "Zone of the Enders HD Collection", "Birds of Steel", "Cabela's North American Adventures"], "y": [6.32, 5.26, 3.1, 2.83, 1.47, 1.82, 0.32, 0.2, 0.15, 0.11], "type": "bar", "uid": "2a702fee-87b6-44cf-8485-edbc894af41b"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Red Dead Redemption", "Assassin's Creed II", "Mass Effect 2", "BioShock", "Fight Night Round 3", "The Orange Box", "Dance Dance Rev
# ...

# %%
X360gS_bar_df = df_X360_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_X360_TOP_10gS.groupby('Name')[['uScore']].sum()
)
X360gS_bar_df.columns = ['cScore', 'uScore']
X360gS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=X360gS_bar_df.index,
    y=X360gS_bar_df['uScore'],
    name='User Score',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    x=X360gS_bar_df.index,
    y=X360gS_bar_df['cScore'],
    name='Critic Score',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 X360 Games (Critic Score vs User Score) [Global Sales]'}
X360gS_bar_fig = go.Figure(data=data, layout=layout)
iplot(X360gS_bar_fig, show_link=False)
# Out:
# <div id="9d6aa186-61a5-4a02-9ce2-7bf277df227b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9d6aa186-61a5-4a02-9ce2-7bf277df227b", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "User Score", "x": ["Grand Theft Auto IV", "Grand Theft Auto V", "Call of Duty: Modern Warfare 2", "Halo 3", "Halo: Reach", "Call of Duty: Modern Warfare 3", "Call of Duty: Black Ops", "Call of Duty: Black Ops II", "Call of Duty: Ghosts", "Kinect Adventures!"], "y": [79.0, 81.0, 63.0, 78.0, 79.0, 34.0, 63.0, 48.0, 26.0, 63.0], "type": "scatter", "uid": "b77b15c6-8caa-4400-ab86-a5753f82d554"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "Critic Score", "x": ["Grand Theft Auto IV", "Grand Theft Auto V", "Call of Duty: Modern Warfare 2", "Halo 3", "Halo: Reach", "Call of Duty: Modern Warfare 3", 
# ...

# %%
X360naS_bar_df = df_X360_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_X360_TOP_10naS.groupby('Name')[['uScore']].sum()
)
X360naS_bar_df.columns = ['cScore', 'uScore']
X360naS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=X360naS_bar_df.index,
    y=X360naS_bar_df['uScore'],
    name='User Score',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    x=X360naS_bar_df.index,
    y=X360naS_bar_df['cScore'],
    name='Critic Score',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 X360 Games (Critic Score vs User Score) [North American Sales]'}
X360naS_bar_fig = go.Figure(data=data, layout=layout)
iplot(X360naS_bar_fig, show_link=False)
# Out:
# <div id="d7aba6b0-bbf8-4e3e-9f85-cb28b772aca9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d7aba6b0-bbf8-4e3e-9f85-cb28b772aca9", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "User Score", "x": ["Grand Theft Auto IV", "Grand Theft Auto V", "Call of Duty: Modern Warfare 2", "Halo 3", "Halo: Reach", "Call of Duty: Modern Warfare 3", "Call of Duty: Black Ops", "Call of Duty: Black Ops II", "Call of Duty: Ghosts", "Kinect Adventures!"], "y": [79.0, 81.0, 63.0, 78.0, 79.0, 34.0, 63.0, 48.0, 26.0, 63.0], "type": "scatter", "uid": "be2d4fea-7a42-47a2-af33-1790efa06f17"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "Critic Score", "x": ["Grand Theft Auto IV", "Grand Theft Auto V", "Call of Duty: Modern Warfare 2", "Halo 3", "Halo: Reach", "Call of Duty: Modern Warfare 3", 
# ...

# %%
#-----------------------------------------------------------------------
# PS3
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

PS3uC_bar_df = df_PS3_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_PS3_TOP_10uC.groupby('Name')[['gSales']].sum()
)
PS3uC_bar_df.columns = ['naSales', 'gSales']
PS3uC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PS3uC_bar_df.index,
    y=PS3uC_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PS3uC_bar_df.index,
    y=PS3uC_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 PS3 Games (NA Sales vs Global Sales) [User Count]'}
PS3uC_bar_fig = go.Figure(data=data, layout=layout)
iplot(PS3uC_bar_fig, show_link=False)
# Out:
# <div id="b964da00-8db9-4df5-b4c0-9d48a95809c4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b964da00-8db9-4df5-b4c0-9d48a95809c4", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Grand Theft Auto V", "Call of Duty: Modern Warfare 3", "Grand Theft Auto IV", "Uncharted 2: Among Thieves", "LittleBigPlanet", "Uncharted 3: Drake's Deception", "Metal Gear Solid 4: Guns of the Patriots", "The Last of Us", "Heavy Rain", "Beyond: Two Souls"], "y": [21.04, 13.32, 10.5, 6.66, 5.82, 6.74, 5.99, 5.87, 3.03, 1.63], "type": "bar", "uid": "28b30e9a-2e04-4757-a015-97f2f0fdb13b"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Grand Theft Auto V", "Call of Duty: Modern Warfare 3", "Grand Theft Auto IV", "Uncharted 2: Among Thieves", "Li
# ...

# %%
PS3cS_bar_df = df_PS3_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_PS3_TOP_10cS.groupby('Name')[['gSales']].sum()
)
PS3cS_bar_df.columns = ['naSales', 'gSales']
PS3cS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PS3cS_bar_df.index,
    y=PS3cS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PS3cS_bar_df.index,
    y=PS3cS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)


data = [trace0, trace1]
layout = {'title': 'Top 10 PS3 Games (NA Sales vs Global Sales) [Critic Score]'}
PS3cS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PS3cS_bar_fig, show_link=False)
# Out:
# <div id="1083eccb-468f-4d03-bd79-e0f2748d18d6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1083eccb-468f-4d03-bd79-e0f2748d18d6", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Grand Theft Auto V", "Call of Duty: Modern Warfare 2", "Grand Theft Auto IV", "Uncharted 2: Among Thieves", "Call of Duty 4: Modern Warfare", "LittleBigPlanet", "Red Dead Redemption", "Batman: Arkham City", "The Last of Us", "Portal 2"], "y": [21.04, 10.6, 10.5, 6.66, 6.68, 5.82, 6.49, 5.48, 5.87, 1.7], "type": "bar", "uid": "ce5b0a7a-68b0-4294-9f7e-9392cacde3b2"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Grand Theft Auto V", "Call of Duty: Modern Warfare 2", "Grand Theft Auto IV", "Uncharted 2: Among Thieves", "Call of Duty 4: Modern Wa
# ...

# %%
PS3uS_bar_df = df_PS3_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_PS3_TOP_10uS.groupby('Name')[['gSales']].sum()
)
PS3uS_bar_df.columns = ['naSales', 'gSales']
PS3uS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PS3uS_bar_df.index,
    y=PS3uS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PS3uS_bar_df.index,
    y=PS3uS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 PS3 Games (NA Sales vs Global Sales) [User Score]'}
PS3uS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PS3uS_bar_fig, show_link=False)
# Out:
# <div id="5ea17762-4ce6-46af-8e13-e003eb3f890b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5ea17762-4ce6-46af-8e13-e003eb3f890b", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Uncharted 2: Among Thieves", "Red Dead Redemption", "The Last of Us", "Batman: Arkham Asylum", "Dead Space", "Demon's Souls", "The Sly Collection", "Devil May Cry HD Collection", "Hot Shots Golf: Out of Bounds", "Metal Gear Solid: The Legacy Collection"], "y": [6.66, 6.49, 5.87, 4.23, 2.0, 1.82, 0.68, 0.82, 1.14, 0.4], "type": "bar", "uid": "58b6d67c-e670-469a-944e-30f7e3dce00f"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Uncharted 2: Among Thieves", "Red Dead Redemption", "The Last of Us", "Batman: Arkham Asylum", "Dead Space", "Demon's 
# ...

# %%
PS3gS_bar_df = df_PS3_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_PS3_TOP_10gS.groupby('Name')[['uScore']].sum()
)
PS3gS_bar_df.columns = ['cScore', 'uScore']
PS3gS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=PS3gS_bar_df.index,
    y=PS3gS_bar_df['uScore'],
    name='User Score',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

trace1 = go.Bar(
    x=PS3gS_bar_df.index,
    y=PS3gS_bar_df['cScore'],
    name='Critic Score',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 PS3 Games (Critic Score vs User Score) [Global Sales]'}
PS3gS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PS3gS_bar_fig, show_link=False)
# Out:
# <div id="9b2523cd-bef4-4e1b-9ca2-c4250aad6454" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9b2523cd-bef4-4e1b-9ca2-c4250aad6454", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "x": ["Grand Theft Auto IV", "Grand Theft Auto V", "Call of Duty: Modern Warfare 2", "Call of Duty: Black Ops", "Call of Duty: Modern Warfare 3", "FIFA Soccer 13", "Battlefield 3", "Gran Turismo 5", "Call of Duty: Black Ops II", "Call of Duty: Ghosts"], "y": [75.0, 82.0, 63.0, 64.0, 32.0, 66.0, 75.0, 75.0, 53.0, 26.0], "type": "scatter", "uid": "f7e222b1-df23-424a-858b-c352e56c5553"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "x": ["Grand Theft Auto IV", "Grand Theft Auto V", "Call of Duty: Modern Warfare 2", "Call of Duty: Black Ops", "Call of Duty: Modern Warf
# ...

# %%
PS3naS_bar_df = df_PS3_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_PS3_TOP_10naS.groupby('Name')[['uScore']].sum()
)
PS3naS_bar_df.columns = ['cScore', 'uScore']
PS3naS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=PS3naS_bar_df.index,
    y=PS3naS_bar_df['uScore'],
    name='User Score',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

trace1 = go.Bar(
    x=PS3naS_bar_df.index,
    y=PS3naS_bar_df['cScore'],
    name='Critic Score',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 PS3 Games (Critic Score vs User Score) [North American Sales]'}
PS3naS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PS3naS_bar_fig, show_link=False)
# Out:
# <div id="aaa92003-3017-430c-af75-1ad00e5bef52" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aaa92003-3017-430c-af75-1ad00e5bef52", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "x": ["Grand Theft Auto IV", "Grand Theft Auto V", "Uncharted 2: Among Thieves", "Call of Duty 4: Modern Warfare", "Call of Duty: Modern Warfare 2", "Call of Duty: Black Ops", "Call of Duty: Modern Warfare 3", "Gran Turismo 5", "Call of Duty: Black Ops II", "Call of Duty: Ghosts"], "y": [75.0, 82.0, 88.0, 84.0, 63.0, 64.0, 32.0, 75.0, 53.0, 26.0], "type": "scatter", "uid": "8167e5b2-f7e8-422f-81de-4250971755be"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "x": ["Grand Theft Auto IV", "Grand Theft Auto V", "Uncharted 2: Among Thieves", "Call of Duty 4: Modern Warf
# ...

# %%
#-----------------------------------------------------------------------
# PS4
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

PS4uC_bar_df = df_PS4_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_PS4_TOP_10uC.groupby('Name')[['gSales']].sum()
)
PS4uC_bar_df.columns = ['naSales', 'gSales']
PS4uC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PS4uC_bar_df.index,
    y=PS4uC_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PS4uC_bar_df.index,
    y=PS4uC_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)
data = [trace0, trace1]
layout = {'title': 'Top 10 PS4 Games (Global Sales vs. North American Sales) [User Count]'}
PS4uC_bar_fig = go.Figure(data=data, layout=layout)
iplot(PS4uC_bar_fig, show_link=False)
# Out:
# <div id="6d956312-bffd-4fe7-9c4d-1835056b82dc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6d956312-bffd-4fe7-9c4d-1835056b82dc", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Fallout 4", "Destiny", "Uncharted 4: A Thief's End", "Watch Dogs", "inFAMOUS: Second Son", "Metal Gear Solid V: The Phantom Pain", "Bloodborne", "The Witcher 3: Wild Hunt", "No Man's Sky", "The Order: 1886"], "y": [7.16, 5.64, 5.38, 4.05, 2.79, 3.41, 2.48, 3.97, 1.7, 1.74], "type": "bar", "uid": "82905ed0-71ad-4ae5-ae4f-2cf768667fc0"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Fallout 4", "Destiny", "Uncharted 4: A Thief's End", "Watch Dogs", "inFAMOUS: Second Son", "Metal Gear Solid V: The Phantom Pain", "Bloodborne", "The Witcher 3: Wil
# ...

# %%
PS4cS_bar_df = df_PS4_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_PS4_TOP_10cS.groupby('Name')[['gSales']].sum()
)
PS4cS_bar_df.columns = ['naSales', 'gSales']
PS4cS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PS4cS_bar_df.index,
    y=PS4cS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PS4cS_bar_df.index,
    y=PS4cS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)
data = [trace0, trace1]
layout = {'title': 'Top 10 PS4 Games (Global Sales vs. North American Sales) [Critic Score]'}
PS4cS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PS4cS_bar_fig, show_link=False)
# Out:
# <div id="80978aa1-b387-4b4c-8a03-91918062f08f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("80978aa1-b387-4b4c-8a03-91918062f08f", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Grand Theft Auto V", "Uncharted 4: A Thief's End", "Metal Gear Solid V: The Phantom Pain", "Bloodborne", "The Witcher 3: Wild Hunt", "Overwatch", "Dragon Age: Inquisition", "Dark Souls III", "Rayman Legends", "Shovel Knight"], "y": [12.61, 5.38, 3.41, 2.48, 3.97, 2.14, 2.01, 1.65, 1.01, 0.08], "type": "bar", "uid": "8635493d-5cb6-4df7-8c02-9fda0faa113c"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Grand Theft Auto V", "Uncharted 4: A Thief's End", "Metal Gear Solid V: The Phantom Pain", "Bloodborne", "The Witcher 3: Wild Hunt", "Overwatch"
# ...

# %%
PS4uS_bar_df = df_PS4_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_PS4_TOP_10uS.groupby('Name')[['gSales']].sum()
)
PS4uS_bar_df.columns = ['naSales', 'gSales']
PS4uS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PS4uS_bar_df.index,
    y=PS4uS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PS4uS_bar_df.index,
    y=PS4uS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)
data = [trace0, trace1]
layout = {'title': 'Top 10 PS4 Games (Global Sales vs. North American Sales) [User Score]'}
PS4uS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PS4uS_bar_fig, show_link=False)
# Out:
# <div id="fd08597a-0965-49a1-a43a-8bf39539d079" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fd08597a-0965-49a1-a43a-8bf39539d079", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Bloodborne", "The Witcher 3: Wild Hunt", "Dark Souls III", "Rayman Legends", "Life is Strange", "BioShock The Collection", "The King of Fighters XIV", "Farming Simulator 17", "Brothers: A Tale of Two Sons", "Rocket League"], "y": [2.48, 3.97, 1.65, 1.01, 0.4, 0.37, 0.15, 0.41, 0.14, 0.37], "type": "bar", "uid": "6a13dd1f-3018-4da9-8196-4ce1514cd0e6"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Bloodborne", "The Witcher 3: Wild Hunt", "Dark Souls III", "Rayman Legends", "Life is Strange", "BioShock The Collection", "The King of Fighters XIV
# ...

# %%
PS4gS_bar_df = df_PS4_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_PS4_TOP_10gS.groupby('Name')[['uScore']].sum()
)
PS4gS_bar_df.columns = ['cScore', 'uScore']
PS4gS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PS4gS_bar_df.index,
    y=PS4gS_bar_df['uScore'],
    name='User Score',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PS4gS_bar_df.index,
    y=PS4gS_bar_df['cScore'],
    name='Critic Score',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)
data = [trace0, trace1]
layout = {'title': 'Top 10 PS4 Games (Critic Score vs User Score) [Global Sales]'}
PS4gS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PS4gS_bar_fig, show_link=False)
# Out:
# <div id="db8e0deb-c15d-4fb4-adc7-ce02ec16d905" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("db8e0deb-c15d-4fb4-adc7-ce02ec16d905", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "User Score", "x": ["Grand Theft Auto V", "Uncharted 4: A Thief's End", "Fallout 4", "Uncharted: The Nathan Drake Collection", "FIFA 17", "Call of Duty: Advanced Warfare", "FIFA 15", "FIFA 16", "Call of Duty: Infinite Warfare", "Destiny"], "y": [83.0, 79.0, 65.0, 81.0, 50.0, 57.0, 57.0, 43.0, 34.0, 61.0], "type": "bar", "uid": "cbf5f777-ab94-45e0-ac74-359636122d1c"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "Critic Score", "x": ["Grand Theft Auto V", "Uncharted 4: A Thief's End", "Fallout 4", "Uncharted: The Nathan Drake Collection", "FIFA 17", "Call of Duty: Advanced Warfare", "FIFA 15", "
# ...

# %%
PS4naS_bar_df = df_PS4_TOP_10naS.groupby('Name')[['naSales']].sum().join(
    df_PS4_TOP_10naS.groupby('Name')[['gSales']].sum()
)
PS4naS_bar_df.columns = ['naSales', 'gSales']
PS4naS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PS4naS_bar_df.index,
    y=PS4naS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PS4naS_bar_df.index,
    y=PS4naS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)
data = [trace0, trace1]
layout = {'title': 'Top 10 PS4 Games (Critic Score vs User Score) [North American Sales]'}
PS4naS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PS4naS_bar_fig, show_link=False)
# Out:
# <div id="f6e171ed-4904-4255-a2a7-8b10d356a0de" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f6e171ed-4904-4255-a2a7-8b10d356a0de", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Grand Theft Auto V", "Call of Duty: Advanced Warfare", "Fallout 4", "Destiny", "NBA 2K16", "Madden NFL 16", "Uncharted: The Nathan Drake Collection", "Uncharted 4: A Thief's End", "Call of Duty: Ghosts", "Call of Duty: Infinite Warfare"], "y": [12.61, 7.66, 7.16, 5.64, 3.88, 3.24, 4.62, 5.38, 3.83, 4.46], "type": "bar", "uid": "5ada0f98-3a2a-40fe-8947-5994b7830f7d"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Grand Theft Auto V", "Call of Duty: Advanced Warfare", "Fallout 4", "Destiny", "NBA 2K16", "Madden NFL 16", "Uncharted: The Nathan D
# ...

# %%
#-----------------------------------------------------------------------
# PC
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

PCuC_bar_df = df_PC_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_PC_TOP_10uC.groupby('Name')[['gSales']].sum()
)
PCuC_bar_df.columns = ['naSales', 'gSales']
PCuC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PCuC_bar_df.index,
    y=PCuC_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PCuC_bar_df.index,
    y=PCuC_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 PC Games (NA Sales vs Global Sales) [User Count]'}
PCuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(PCuC_bar_fig, show_link=False)
# Out:
# <div id="fe3bfeb6-f15c-417b-8a63-975f80001805" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fe3bfeb6-f15c-417b-8a63-975f80001805", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Diablo III", "Half-Life 2", "The Elder Scrolls V: Skyrim", "Fallout 4", "Portal 2", "BioShock Infinite", "The Witcher 3: Wild Hunt", "Company of Heroes 2", "Call of Duty: Modern Warfare 2", "Counter-Strike: Source"], "y": [5.14, 2.37, 3.88, 1.29, 0.76, 0.66, 0.72, 0.34, 0.88, 0.08], "type": "bar", "uid": "9dab771f-14d9-48e6-bf01-3394789f38b4"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Diablo III", "Half-Life 2", "The Elder Scrolls V: Skyrim", "Fallout 4", "Portal 2", "BioShock Infinite", "The Witcher 3: Wild Hunt", "Company of Heroes 2",
# ...

# %%
PCcS_bar_df = df_PC_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_PC_TOP_10cS.groupby('Name')[['gSales']].sum()
)
PCcS_bar_df.columns = ['naSales', 'gSales']
PCcS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PCcS_bar_df.index,
    y=PCcS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PCcS_bar_df.index,
    y=PCcS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 PC Games (NA Sales vs Global Sales) [Critic Score]'}
PCcS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PCcS_bar_fig, show_link=False)
# Out:
# <div id="99ac84be-e693-48f8-beec-96c625a347a3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("99ac84be-e693-48f8-beec-96c625a347a3", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Half-Life", "Half-Life 2", "The Elder Scrolls V: Skyrim", "Grand Theft Auto V", "Portal 2", "BioShock Infinite", "BioShock", "Diablo", "Mass Effect 2", "The Orange Box"], "y": [4.12, 2.37, 3.88, 1.17, 0.76, 0.66, 0.41, 1.59, 0.39, 0.14], "type": "bar", "uid": "7daa4974-68e7-4399-a7da-c51f1a48bd7b"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Half-Life", "Half-Life 2", "The Elder Scrolls V: Skyrim", "Grand Theft Auto V", "Portal 2", "BioShock Infinite", "BioShock", "Diablo", "Mass Effect 2", "The Orange Box"], "y": [4.03, 2.28, 1.16, 0.39, 
# ...

# %%
PCuS_bar_df = df_PC_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_PC_TOP_10uS.groupby('Name')[['gSales']].sum()
)
PCuS_bar_df.columns = ['naSales', 'gSales']
PCuS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PCuS_bar_df.index,
    y=PCuS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)


trace1 = go.Scatter(
    x=PCuS_bar_df.index,
    y=PCuS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 PC Games (NA Sales vs Global Sales) [User Score]'}
PCuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PCuS_bar_fig, show_link=False)
# Out:
# <div id="aab2ed7a-cff8-4e8b-a60a-8f906b0deead" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aab2ed7a-cff8-4e8b-a60a-8f906b0deead", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Half-Life", "Half-Life 2", "Diablo II: Lord of Destruction", "The Witcher 3: Wild Hunt", "Warcraft III: Reign of Chaos", "Planescape: Torment", "Deus Ex", "Left 4 Dead", "Rome: Total War", "The Orange Box"], "y": [4.12, 2.37, 1.06, 0.72, 0.13, 0.03, 0.01, 0.02, 0.1, 0.14], "type": "bar", "uid": "1929b967-57be-48ce-9c78-1aab399bc154"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Half-Life", "Half-Life 2", "Diablo II: Lord of Destruction", "The Witcher 3: Wild Hunt", "Warcraft III: Reign of Chaos", "Planescape: Torment", "Deus Ex", "Left 4 De
# ...

# %%
PCgS_bar_df = df_PC_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_PC_TOP_10gS.groupby('Name')[['uScore']].sum()
)
PCgS_bar_df.columns = ['cScore', 'uScore']
PCgS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PCgS_bar_df.index,
    y=PCgS_bar_df['cScore'],
    name='Critic Score',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PCgS_bar_df.index,
    y=PCgS_bar_df['uScore'],
    name='User Score',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 PC Games (Critic Score vs User Score) [Global Sales]'}
PCgS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PCgS_bar_fig, show_link=False)
# Out:
# <div id="1c3b8cb3-9ce1-4633-87fa-842e0edeaaf1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1c3b8cb3-9ce1-4633-87fa-842e0edeaaf1", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "x": ["Half-Life", "The Elder Scrolls V: Skyrim", "StarCraft II: Wings of Liberty", "World of Warcraft", "World of Warcraft: The Burning Crusade", "Diablo III", "The Sims 3", "The Sims: Unleashed", "The Sims: Vacation", "The Sims 4"], "y": [96.0, 94.0, 93.0, 93.0, 91.0, 88.0, 86.0, 79.0, 75.0, 70.0], "type": "bar", "uid": "4e00efd9-3e00-483b-bf91-c5e9e1e281e2"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "x": ["Half-Life", "The Elder Scrolls V: Skyrim", "StarCraft II: Wings of Liberty", "World of Warcraft", "World of Warcraft: The Burning Crusade", "Diablo III", 
# ...

# %%
PCnaS_bar_df = df_PC_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_PC_TOP_10naS.groupby('Name')[['uScore']].sum()
)
PCnaS_bar_df.columns = ['cScore', 'uScore']
PCnaS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Bar(
    x=PCnaS_bar_df.index,
    y=PCnaS_bar_df['cScore'],
    name='Critic Score',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=PCnaS_bar_df.index,
    y=PCnaS_bar_df['uScore'],
    name='User Score',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 PC Games (Critic Score vs User Score) [North American Sales]'}
PCnaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(PCnaS_bar_fig, show_link=False)
# Out:
# <div id="81b70cde-1cd1-476b-b11d-0079c05dbc20" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("81b70cde-1cd1-476b-b11d-0079c05dbc20", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "x": ["Half-Life", "Half-Life 2", "StarCraft II: Wings of Liberty", "World of Warcraft: The Burning Crusade", "World of Warcraft: Cataclysm", "Diablo III", "The Sims: Hot Date", "The Sims: Livin Large", "The Sims: Unleashed", "The Sims: Vacation"], "y": [96.0, 96.0, 93.0, 91.0, 90.0, 88.0, 85.0, 82.0, 79.0, 75.0], "type": "bar", "uid": "aa878377-f865-4dbe-be63-fed36990d0e9"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "x": ["Half-Life", "Half-Life 2", "StarCraft II: Wings of Liberty", "World of Warcraft: The Burning Crusade", "World of Warcraft: Cataclysm", "Diab
# ...

# %%
#-----------------------------------------------------------------------
# Wii
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

WiiuC_bar_df = df_Wii_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_Wii_TOP_10uC.groupby('Name')[['gSales']].sum()
)
WiiuC_bar_df.columns = ['naSales', 'gSales']
WiiuC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=WiiuC_bar_df.index,
    y=WiiuC_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=WiiuC_bar_df.index,
    y=WiiuC_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Wii Games (NA Sales vs Global Sales) [User Count]'}
WiiuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(WiiuC_bar_fig, show_link=False)
# Out:
# <div id="3bc925b5-37ce-4ec6-be88-2d2840049cc6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3bc925b5-37ce-4ec6-be88-2d2840049cc6", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Mario Kart Wii", "New Super Mario Bros. Wii", "Super Smash Bros. Brawl", "Super Mario Galaxy", "The Legend of Zelda: Twilight Princess", "Super Mario Galaxy 2", "The Legend of Zelda: Skyward Sword", "Metroid Prime 3: Corruption", "Metroid: Other M", "Xenoblade Chronicles"], "y": [35.52, 28.32, 12.84, 11.35, 7.15, 7.51, 3.95, 1.79, 1.34, 0.91], "type": "bar", "uid": "e92ca4a4-e291-48db-9a86-7b7be63c00a8"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Mario Kart Wii", "New Super Mario Bros. Wii", "Super Smash Bros. Brawl", "Super Mario Galaxy"
# ...

# %%
WiicS_bar_df = df_Wii_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_Wii_TOP_10cS.groupby('Name')[['gSales']].sum()
)
WiicS_bar_df.columns = ['naSales', 'gSales']
WiicS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=WiicS_bar_df.index,
    y=WiicS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=WiicS_bar_df.index,
    y=WiicS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Wii Games (NA Sales vs Global Sales) [Critic Score]'}
WiicS_bar_fig = go.Figure(data=data, layout=layout)
iplot(WiicS_bar_fig, show_link=False)
# Out:
# <div id="5cb38f7f-9644-4fa1-85c1-42764daa6f98" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5cb38f7f-9644-4fa1-85c1-42764daa6f98", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Super Smash Bros. Brawl", "Super Mario Galaxy", "The Legend of Zelda: Twilight Princess", "Super Mario Galaxy 2", "The Legend of Zelda: Skyward Sword", "Rock Band 2", "Rock Band 3", "Xenoblade Chronicles", "Metroid Prime: Trilogy", "Rayman Origins"], "y": [12.84, 11.35, 7.15, 7.51, 3.95, 1.02, 0.63, 0.91, 0.61, 0.55], "type": "bar", "uid": "cd42af5e-b2ce-4bb3-a8a8-2a89b0662e1f"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Super Smash Bros. Brawl", "Super Mario Galaxy", "The Legend of Zelda: Twilight Princess", "Super Mario Galaxy 2", "The 
# ...

# %%
WiiuS_bar_df = df_Wii_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_Wii_TOP_10uS.groupby('Name')[['gSales']].sum()
)
WiiuS_bar_df.columns = ['naSales', 'gSales']
WiiuS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=WiiuS_bar_df.index,
    y=WiiuS_bar_df['gSales'],
    name='Global Sales',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=WiiuS_bar_df.index,
    y=WiiuS_bar_df['naSales'],
    name='North American Sales',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Wii Games (NA Sales vs Global Sales) [User Score]'}
WiiuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(WiiuS_bar_fig, show_link=False)
# Out:
# <div id="76e5cbc5-3bbf-4ba0-b365-1c0be03a7f14" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("76e5cbc5-3bbf-4ba0-b365-1c0be03a7f14", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "x": ["Super Smash Bros. Brawl", "Super Mario Galaxy", "The Legend of Zelda: Twilight Princess", "LEGO Star Wars: The Complete Saga", "Super Mario Galaxy 2", "The Beatles: Rock Band", "Metroid Prime 3: Corruption", "Harvest Moon: Animal Parade", "Xenoblade Chronicles", "Metroid Prime: Trilogy"], "y": [12.84, 11.35, 7.15, 5.64, 7.51, 1.71, 1.79, 0.73, 0.91, 0.61], "type": "bar", "uid": "55558dcb-726b-40e7-a6f7-61e3caa115dc"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "x": ["Super Smash Bros. Brawl", "Super Mario Galaxy", "The Legend of Zelda: Twilight P
# ...

# %%
WiigS_bar_df = df_Wii_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_Wii_TOP_10gS.groupby('Name')[['uScore']].sum()
)
WiigS_bar_df.columns = ['cScore', 'uScore']
WiigS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Bar(
    x=WiigS_bar_df.index,
    y=WiigS_bar_df['cScore'],
    name='Critic Score',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=WiigS_bar_df.index,
    y=WiigS_bar_df['uScore'],
    name='User Score',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Wii Games (Critic Score vs User Score) [Global Sales]'}
WiigS_bar_fig = go.Figure(data=data, layout=layout)
iplot(WiigS_bar_fig, show_link=False)
# Out:
# <div id="5928d979-b91a-48f4-9a5b-40b5982b4a5c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5928d979-b91a-48f4-9a5b-40b5982b4a5c", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "x": ["Super Mario Galaxy", "Super Smash Bros. Brawl", "New Super Mario Bros. Wii", "Mario Kart Wii", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", "Just Dance 2", "Just Dance 3", "Wii Play"], "y": [97.0, 93.0, 87.0, 82.0, 80.0, 80.0, 80.0, 74.0, 74.0, 58.0], "type": "bar", "uid": "c9f00035-82b4-4e29-bdf2-0b1db82e9f92"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "x": ["Super Mario Galaxy", "Super Smash Bros. Brawl", "New Super Mario Bros. Wii", "Mario Kart Wii", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", "Just Dance 2", "Just Dance 3", "Wii Play"], "y": [
# ...

# %%
WiinaS_bar_df = df_Wii_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_Wii_TOP_10naS.groupby('Name')[['uScore']].sum()
)
WiinaS_bar_df.columns = ['cScore', 'uScore']
WiinaS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Bar(
    x=WiinaS_bar_df.index,
    y=WiinaS_bar_df['cScore'],
    name='Critic Score',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Scatter(
    x=WiinaS_bar_df.index,
    y=WiinaS_bar_df['uScore'],
    name='User Score',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Wii Games (Critic Score vs User Score) [North American Sales]'}
WiinaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(WiinaS_bar_fig, show_link=False)
# Out:
# <div id="5d4ab392-08f9-4e2e-9b43-be04caab2a8a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5d4ab392-08f9-4e2e-9b43-be04caab2a8a", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "x": ["Super Mario Galaxy", "Super Smash Bros. Brawl", "New Super Mario Bros. Wii", "Mario Kart Wii", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", "Just Dance 2", "Just Dance 3", "Wii Play"], "y": [97.0, 93.0, 87.0, 82.0, 80.0, 80.0, 80.0, 74.0, 74.0, 58.0], "type": "bar", "uid": "f4f72f85-d4bb-437d-a612-205c836208b8"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "x": ["Super Mario Galaxy", "Super Smash Bros. Brawl", "New Super Mario Bros. Wii", "Mario Kart Wii", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", "Just Dance 2", "Just Dance 3", "Wii Play"], "y": [
# ...

# %%
#-----------------------------------------------------------------------
# Nintendo
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

NintendouC_bar_df = df_Nintendo_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_Nintendo_TOP_10uC.groupby('Name')[['gSales']].sum()
)
NintendouC_bar_df.columns = ['naSales', 'gSales']
NintendouC_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=NintendouC_bar_df.index,
    x=NintendouC_bar_df['gSales'],
    name='Global Sales',
    orientation='h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=NintendouC_bar_df.index,
    x=NintendouC_bar_df['naSales'],
    name='North American Sales',
    orientation='h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = go.Layout(
    title= 'Top 10 Nintendo Games (NA Sales vs Global Sales) [User Count]',
    barmode='stack'
)
NintendouC_bar_fig = go.Figure(data=data, layout=layout)
iplot(NintendouC_bar_fig, show_link=False)
# Out:
# <div id="4116be77-f83e-4c16-a2c9-2059b12db56c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4116be77-f83e-4c16-a2c9-2059b12db56c", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [0.76, 0.84, 4.43, 3.95, 4.32, 7.09, 7.51, 7.15, 11.35, 12.84], "y": ["Bayonetta 2", "Xenoblade Chronicles X", "Splatoon", "The Legend of Zelda: Skyward Sword", "Super Mario 3D World", "Mario Kart 8", "Super Mario Galaxy 2", "The Legend of Zelda: Twilight Princess", "Super Mario Galaxy", "Super Smash Bros. Brawl"], "type": "bar", "uid": "4e27e79a-9444-4f73-9e10-0d826b507643"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.32, 0.36, 1.54, 2.03, 2.11, 3.15, 3.56, 3.74, 6.06, 6.62], "y": ["Bayonetta 2", "Xe
# ...

# %%
NintendocS_bar_df = df_Nintendo_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_Nintendo_TOP_10cS.groupby('Name')[['gSales']].sum()
)
NintendocS_bar_df.columns = ['naSales', 'gSales']
NintendocS_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=NintendocS_bar_df.index,
    x=NintendocS_bar_df['gSales'],
    name='Global Sales',
    orientation='h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=NintendocS_bar_df.index,
    x=NintendocS_bar_df['naSales'],
    name='North American Sales',
    orientation='h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = go.Layout(
    title= 'Top 10 Nintendo Games (NA Sales vs Global Sales) [Critic Score]',
    barmode='stack'
)
NintendocS_bar_fig = go.Figure(data=data, layout=layout)
iplot(NintendocS_bar_fig, show_link=False)
# Out:
# <div id="82afb2e1-8a25-48c5-a057-d81854d6a385" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("82afb2e1-8a25-48c5-a057-d81854d6a385", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [2.7, 2.82, 4.32, 4.6, 5.47, 7.51, 8.74, 11.35, 12.84], "y": ["The Legend of Zelda: A Link to the Past", "Metroid Prime", "Super Mario 3D World", "The Legend of Zelda: The Wind Waker", "Mario Kart: Super Circuit", "Super Mario Galaxy 2", "The Legend of Zelda: Twilight Princess", "Super Mario Galaxy", "Super Smash Bros. Brawl"], "type": "bar", "uid": "c0dca52e-4788-4454-b444-430483eb500d"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [1.75, 1.96, 2.11, 2.6, 2.62, 3.56, 4.890000000000001, 6.06, 6.62], "y": 
# ...

# %%
NintendouS_bar_df = df_Nintendo_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_Nintendo_TOP_10uS.groupby('Name')[['gSales']].sum()
)
NintendouS_bar_df.columns = ['naSales', 'gSales']
NintendouS_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=NintendouS_bar_df.index,
    x=NintendouS_bar_df['gSales'],
    name='Global Sales',
    orientation='h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=NintendouS_bar_df.index,
    x=NintendouS_bar_df['naSales'],
    name='North American Sales',
    orientation='h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = go.Layout(
    title= 'Top 10 Nintendo Games (NA Sales vs Global Sales) [User Score]',
    barmode='stack'
)
NintendouS_bar_fig = go.Figure(data=data, layout=layout)
iplot(NintendouS_bar_fig, show_link=False)
# Out:
# <div id="004fbc6f-eaa9-46c2-9e38-84b1f079dd3b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("004fbc6f-eaa9-46c2-9e38-84b1f079dd3b", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [0.36, 0.61, 0.65, 0.97, 3.26, 1.22, 1.76, 1.59, 2.25, 2.82], "y": ["Hamtaro: Ham-Ham Heartbreak", "Metroid Prime: Trilogy", "Advance Wars 2: Black Hole Rising", "Fire Emblem", "Professor Layton and the Unwound Future", "Golden Sun: The Lost Age", "Golden Sun", "The Legend of Zelda: Twilight Princess", "Paper Mario: The Thousand-Year Door", "Metroid Prime"], "type": "bar", "uid": "a655e61d-2340-4241-968c-f1b2f40b2c89"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.26, 0.42, 0.47, 0.49, 0.6, 0.61, 0.93, 
# ...

# %%
NintendogS_bar_df = df_Nintendo_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_Nintendo_TOP_10gS.groupby('Name')[['uScore']].sum()
)
NintendogS_bar_df.columns = ['cScore', 'uScore']
NintendogS_bar_df.sort_values('cScore', ascending=True, inplace=True)

trace0 = go.Bar(
    y=NintendogS_bar_df.index,
    x=NintendogS_bar_df['cScore'],
    name='Critic Score',
    orientation='h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=NintendogS_bar_df.index,
    x=NintendogS_bar_df['uScore'],
    name='User Score',
    orientation='h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)


data = [trace0, trace1]
layout = go.Layout(
    title= 'Top 10 Nintendo Games (Critic Score vs User Score) [Global Sales]',
    barmode='stack'
)
NintendogS_bar_fig = go.Figure(data=data, layout=layout)
iplot(NintendogS_bar_fig, show_link=False)
# Out:
# <div id="ba8a7653-d814-455f-929e-021601284c47" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ba8a7653-d814-455f-929e-021601284c47", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "orientation": "h", "x": [58.0, 77.0, 77.0, 80.0, 80.0, 80.0, 82.0, 87.0, 89.0, 91.0], "y": ["Wii Play", "Brain Age 2: More Training in Minutes a Day", "Brain Age: Train Your Brain in Minutes a Day", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", "Mario Kart Wii", "New Super Mario Bros. Wii", "New Super Mario Bros.", "Mario Kart DS"], "type": "bar", "uid": "fde56474-7fb8-4310-b47a-7889004b39fa"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "orientation": "h", "x": [66.0, 71.0, 79.0, 77.0, 74.0, 80.0, 83.0, 84.0, 85.0, 86.0], "y": ["Wii Play", "Brain Age 2: More T
# ...

# %%
NintendonaS_bar_df = df_Nintendo_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_Nintendo_TOP_10naS.groupby('Name')[['uScore']].sum()
)
NintendonaS_bar_df.columns = ['cScore', 'uScore']
NintendonaS_bar_df.sort_values('cScore', ascending=True, inplace=True)

trace0 = go.Bar(
    y=NintendonaS_bar_df.index,
    x=NintendonaS_bar_df['cScore'],
    name='Critic Score',
    orientation='h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=NintendonaS_bar_df.index,
    x=NintendonaS_bar_df['uScore'],
    name='User Score',
    orientation='h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = go.Layout(
    title= 'Top 10 Nintendo Games (Critic Score vs User Score) [North American Sales]',
    barmode='stack'
)
NintendonaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(NintendonaS_bar_fig, show_link=False)
# Out:
# <div id="37bc9ad0-8d76-4244-ba9b-9a0a0102f535" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("37bc9ad0-8d76-4244-ba9b-9a0a0102f535", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "orientation": "h", "x": [58.0, 80.0, 80.0, 80.0, 82.0, 87.0, 89.0, 91.0, 93.0, 97.0], "y": ["Wii Play", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", "Mario Kart Wii", "New Super Mario Bros. Wii", "New Super Mario Bros.", "Mario Kart DS", "Super Smash Bros. Brawl", "Super Mario Galaxy"], "type": "bar", "uid": "efc563d5-a981-4509-b48d-adddf5de11f1"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "orientation": "h", "x": [66.0, 77.0, 74.0, 80.0, 83.0, 84.0, 85.0, 86.0, 89.0, 89.0], "y": ["Wii Play", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", "Mario Kart Wii", 
# ...

# %%
#-----------------------------------------------------------------------
# EA
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

EAuC_bar_df = df_EA_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_EA_TOP_10uC.groupby('Name')[['gSales']].sum()
)
EAuC_bar_df.columns = ['naSales', 'gSales']
EAuC_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=EAuC_bar_df.index,
    x=EAuC_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=EAuC_bar_df.index,
    x=EAuC_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = go.Layout(
    title= 'Top 10 EA Games (NA Sales vs Global Sales) [User Count]',
    barmode='stack'
)
EAuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(EAuC_bar_fig, show_link=False)
# Out:
# <div id="5a0ad34b-28fe-4207-a0e7-25c4f31e655f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5a0ad34b-28fe-4207-a0e7-25c4f31e655f", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [0.51, 0.02, 0.39, 0.63, 0.73, 1.35, 1.42, 2.78, 4.01], "y": ["Dragon Age: Origins", "Left 4 Dead", "Mass Effect 2", "Dragon Age II", "Dragon Age: Inquisition", "Battlefield 4", "SimCity (2013)", "Battlefield 3", "Mass Effect 3"], "type": "bar", "uid": "19dca2e7-efe1-45a0-98a6-772d881847e1"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.0, 0.0, 0.01, 0.23, 0.33, 0.39, 0.48, 0.89, 2.34], "y": ["Dragon Age: Origins", "Left 4 Dead", "Mass Effect 2", "Dragon Age II", "Dragon Age: Inquisition", "Battlefield 
# ...

# %%
EAcS_bar_df = df_EA_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_EA_TOP_10cS.groupby('Name')[['gSales']].sum()
)
EAcS_bar_df.columns = ['naSales', 'gSales']
EAcS_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=EAcS_bar_df.index,
    x=EAcS_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=EAcS_bar_df.index,
    x=EAcS_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = go.Layout(
    title= 'Top 10 EA Games (NA Sales vs Global Sales) [Critic Score]',
    barmode='stack'
)
EAcS_bar_fig = go.Figure(data=data, layout=layout)
iplot(EAcS_bar_fig, show_link=False)
# Out:
# <div id="114338e6-3724-4e26-89c5-68c91aff6d43" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("114338e6-3724-4e26-89c5-68c91aff6d43", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [0.51, 1.31, 1.96, 1.67, 3.08, 4.9399999999999995, 4.14], "y": ["Madden NFL 2004", "Burnout 3: Takedown", "The Orange Box", "NCAA Football 2004", "Madden NFL 2002", "Mass Effect 2", "Madden NFL 2003"], "type": "bar", "uid": "404dabd4-2219-4d23-8f4f-a0cfe22a7e09"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.4, 0.84, 1.09, 1.35, 2.5, 2.78, 3.36], "y": ["Madden NFL 2004", "Burnout 3: Takedown", "The Orange Box", "NCAA Football 2004", "Madden NFL 2002", "Mass Effect 2", "Madden NFL 2003"], "type": "bar", 
# ...

# %%
EAuS_bar_df = df_EA_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_EA_TOP_10uS.groupby('Name')[['gSales']].sum()
)
EAuS_bar_df.columns = ['naSales', 'gSales']
EAuS_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=EAuS_bar_df.index,
    x=EAuS_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=EAuS_bar_df.index,
    x=EAuS_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace0, trace1]
layout = go.Layout(
    title= 'Top 10 EA Games (NA Sales vs Global Sales) [User Score]',
    barmode='stack'
)
EAuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(EAuS_bar_fig, show_link=False)
# Out:
# <div id="449a9ed5-bfd6-4055-ba28-7780eb8876f3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("449a9ed5-bfd6-4055-ba28-7780eb8876f3", [{"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [0.02, 0.14, 0.08, 0.17, 0.62, 0.65, 2.31, 2.68, 4.37], "y": ["Left 4 Dead", "The Orange Box", "NHL 06", "Spawn: Armageddon", "The Urbz: Sims in the City", "Madden NFL 07", "James Bond 007: Everything or Nothing", "Burnout 3: Takedown", "Need for Speed: Most Wanted"], "type": "bar", "uid": "f31f51c9-2654-48da-ae43-be0eec1faad9"}, {"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.0, 0.0, 0.06, 0.13, 0.37, 0.5, 0.85, 1.23, 2.03], "y": ["Left 4 Dead", "The Orange Box", "NHL 06", "Spawn: Armageddon", "The Urbz: 
# ...

# %%
EAgS_bar_df = df_EA_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_EA_TOP_10gS.groupby('Name')[['uScore']].sum()
)
EAgS_bar_df.columns = ['cScore', 'uScore']
EAgS_bar_df.sort_values('cScore', ascending=True, inplace=True)

trace0 = go.Bar(
    y=EAgS_bar_df.index,
    x=EAgS_bar_df['cScore'],
    name='Critic Score',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=EAgS_bar_df.index,
    x=EAgS_bar_df['uScore'],
    name='User Score',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 EA Games (Critic Score vs User Score) [Global Sales]',
    barmode='stack'
)

EAgS_bar_fig = go.Figure(data=data, layout=layout)
iplot(EAgS_bar_fig, validate=False)
# Out:
# <div id="103c0ebe-6c97-41af-be85-d8fbbea4907b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("103c0ebe-6c97-41af-be85-d8fbbea4907b", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "orientation": "h", "x": [43.0, 86.0, 50.0, 86.0, 43.0, 76.0, 66.0, 85.0, 149.0], "y": ["FIFA 16", "Need for Speed Underground 2", "FIFA 17", "Need for Speed Underground", "FIFA 14", "The Sims 3", "FIFA Soccer 13", "Medal of Honor: Frontline", "Battlefield 3"], "type": "bar", "uid": "58154bce-2de4-4fc9-b078-495316b8670a"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "orientation": "h", "x": [82.0, 82.0, 85.0, 85.0, 86.0, 86.0, 88.0, 88.0, 169.0], "y": ["FIFA 16", "Need for Speed Underground 2", "FIFA 17", "Need for Speed Underground", "FIFA 14", "The Sims 3", "FIF
# ...

# %%
EAnaS_bar_df = df_EA_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_EA_TOP_10naS.groupby('Name')[['uScore']].sum()
)
EAnaS_bar_df.columns = ['cScore', 'uScore']
EAnaS_bar_df.sort_values('cScore', ascending=True, inplace=True)

trace0 = go.Bar(
    y=EAnaS_bar_df.index,
    x=EAnaS_bar_df['cScore'],
    name='Critic Score',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)
trace1 = go.Bar(
    y=EAnaS_bar_df.index,
    x=EAnaS_bar_df['uScore'],
    name='User Score',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 EA Games (Critic Score vs User Score) [North American Sales]',
    barmode='stack'
)

EAnaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(EAnaS_bar_fig, show_link=False)
# Out:
# <div id="b7352f55-4a56-42b7-afcf-dfedbc7d11f3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b7352f55-4a56-42b7-afcf-dfedbc7d11f3", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "orientation": "h", "x": [86.0, 82.0, 86.0, 80.0, 85.0, 86.0, 79.0, 77.0, 149.0], "y": ["Need for Speed Underground 2", "Madden NFL 07", "Need for Speed Underground", "Madden NFL 06", "Medal of Honor: Frontline", "Left 4 Dead 2", "Madden NFL 2005", "Madden NFL 2003", "Battlefield 3"], "type": "bar", "uid": "cf60e85f-6cf2-49c8-a859-91f926ade63b"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "orientation": "h", "x": [82.0, 84.0, 85.0, 88.0, 88.0, 89.0, 91.0, 95.0, 169.0], "y": ["Need for Speed Underground 2", "Madden NFL 07", "Need for Speed Underground", "Madden NF
# ...

# %%
#-----------------------------------------------------------------------
# Sony
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------
SonyuC_bar_df = df_Sony_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_Sony_TOP_10uC.groupby('Name')[['gSales']].sum()
)
SonyuC_bar_df.columns = ['naSales', 'gSales']
SonyuC_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=SonyuC_bar_df.index,
    x=SonyuC_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)
trace1 = go.Bar(
    y=SonyuC_bar_df.index,
    x=SonyuC_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 EA Games (NA Sales vs Global Sales) [User Count]',
    barmode='stack'
)

EAuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(EAuC_bar_fig, show_link=False)
# Out:
# <div id="dc236ee0-60c1-4d0c-8bc1-e861a9e5dc5e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("dc236ee0-60c1-4d0c-8bc1-e861a9e5dc5e", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.52, 0.61, 1.03, 1.28, 1.29, 1.85, 2.74, 2.77, 2.8, 3.27], "y": ["Beyond: Two Souls", "The Order: 1886", "Bloodborne", "inFAMOUS: Second Son", "Heavy Rain", "Uncharted 4: A Thief's End", "God of War III", "Uncharted 3: Drake's Deception", "LittleBigPlanet", "Uncharted 2: Among Thieves"], "type": "bar", "uid": "e014680c-15ed-4896-8394-949938fdca4a"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [1.63, 1.74, 2.48, 2.79, 3.03, 5.38, 4.8, 6.74, 5.82, 6.66], "y": ["Beyond: Two Souls", "The Order: 1886", "Bloo
# ...

# %%
SonycS_bar_df = df_Sony_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_Sony_TOP_10cS.groupby('Name')[['gSales']].sum()
)
SonycS_bar_df.columns = ['naSales', 'gSales']
SonycS_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=SonycS_bar_df.index,
    x=SonycS_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)
trace1 = go.Bar(
    y=SonycS_bar_df.index,
    x=SonycS_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Sony Games (NA Sales vs Global Sales) [Critic Score]',
    barmode='stack'
)
SonycS_bar_fig = go.Figure(data=data, layout=layout)
iplot(SonycS_bar_fig, show_link=False)
# Out:
# <div id="a21ee445-33a3-4771-9e03-488bb4b5074d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a21ee445-33a3-4771-9e03-488bb4b5074d", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [1.85, 2.32, 2.71, 2.8, 3.01, 3.27, 3.27, 3.88, 4.02, 6.85], "y": ["Uncharted 4: A Thief's End", "God of War II", "God of War", "LittleBigPlanet", "Final Fantasy VII", "Tekken 3", "Uncharted 2: Among Thieves", "Gran Turismo 2", "Gran Turismo", "Gran Turismo 3: A-Spec"], "type": "bar", "uid": "b31cdc30-e1a6-4300-a836-26f37cec764b"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [5.38, 4.07, 4.45, 5.82, 9.72, 7.16, 6.66, 9.49, 10.95, 14.98], "y": ["Uncharted 4: A Thief's End", "God of War II", "God of War", "
# ...

# %%
SonyuS_bar_df = df_Sony_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_Sony_TOP_10uS.groupby('Name')[['gSales']].sum()
)
SonyuS_bar_df.columns = ['naSales', 'gSales']
SonyuS_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=SonyuS_bar_df.index,
    x=SonyuS_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)
trace1 = go.Bar(
    y=SonyuS_bar_df.index,
    x=SonyuS_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Sony Games (NA Sales vs Global Sales) [User Score]',
    barmode='stack'
)
SonyuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(SonyuS_bar_fig, show_link=False)
# Out:
# <div id="36588107-9d8d-4133-8e14-cc2b6e62eccc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("36588107-9d8d-4133-8e14-cc2b6e62eccc", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.06, 0.08, 0.12, 0.38, 0.78, 2.22, 2.57, 3.01, 3.27, 3.88], "y": ["Smash Court Tennis Pro Tournament 2", "Gretzky NHL 2005", "Klonoa 2: Lunatea's Veil", "Dark Cloud 2", "Shadow of the Colossus", "SOCOM II: U.S. Navy SEALs", "Crash Team Racing", "Final Fantasy VII", "Tekken 3", "Gran Turismo 2"], "type": "bar", "uid": "f5794c57-3185-496e-81ce-2a2302a34398"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [0.13, 0.17, 0.33, 0.96, 1.14, 2.94, 4.79, 9.72, 7.16, 9.49], "y": ["Smash Court Tennis Pro Tournament 2
# ...

# %%
SonygS_bar_df = df_Sony_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_Sony_TOP_10gS.groupby('Name')[['uScore']].sum()
)
SonygS_bar_df.columns = ['cScore', 'uScore']
SonygS_bar_df.sort_values('cScore', ascending=True, inplace=True)

trace0 = go.Bar(
    y=SonygS_bar_df.index,
    x=SonygS_bar_df['cScore'],
    name='Critic Score',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)
trace1 = go.Bar(
    y=SonygS_bar_df.index,
    x=SonygS_bar_df['uScore'],
    name='User Score',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Sony Games (Critic Score vs User Score) [Global Sales]',
    barmode='stack'
)
SonyuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(SonyuS_bar_fig, show_link=False)
# Out:
# <div id="ed8774c7-cf91-4246-a723-aeb94bd4aa78" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ed8774c7-cf91-4246-a723-aeb94bd4aa78", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "orientation": "h", "x": [75.0, 85.0, 89.0, 92.0, 87.0, 83.0, 90.0, 84.0, 87.0, 91.0], "y": ["Gran Turismo 5", "Gran Turismo 4", "Crash Bandicoot 3: Warped", "Final Fantasy VII", "Final Fantasy X", "Uncharted 3: Drake's Deception", "Gran Turismo 2", "Gran Turismo 3: A-Spec", "Gran Turismo", "Tekken 3"], "type": "bar", "uid": "24b5d3ab-d174-4d39-984b-4d3014d0ebac"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "orientation": "h", "x": [84.0, 89.0, 91.0, 92.0, 92.0, 92.0, 93.0, 95.0, 96.0, 96.0], "y": ["Gran Turismo 5", "Gran Turismo 4", "Crash Bandicoot 3: Warped", 
# ...

# %%
SonynaS_bar_df = df_Sony_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_Sony_TOP_10naS.groupby('Name')[['uScore']].sum()
)
SonynaS_bar_df.columns = ['cScore', 'uScore']
SonynaS_bar_df.sort_values('cScore', ascending=True, inplace=True)

trace0 = go.Bar(
    y=SonynaS_bar_df.index,
    x=SonynaS_bar_df['cScore'],
    name='Critic Score',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)
trace1 = go.Bar(
    y=SonynaS_bar_df.index,
    x=SonynaS_bar_df['uScore'],
    name='User Score',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Sony Games (Critic Score vs User Score) [North American Sales]',
    barmode='stack'
)
SonynaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(SonynaS_bar_fig, show_link=False)
# Out:
# <div id="22297efd-a588-4181-a97f-c638ff9e8088" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("22297efd-a588-4181-a97f-c638ff9e8088", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "orientation": "h", "x": [75.0, 88.0, 85.0, 89.0, 92.0, 90.0, 84.0, 87.0, 91.0, 88.0], "y": ["Gran Turismo 5", "Kingdom Hearts", "Gran Turismo 4", "Crash Bandicoot 3: Warped", "Final Fantasy VII", "Gran Turismo 2", "Gran Turismo 3: A-Spec", "Gran Turismo", "Tekken 3", "Uncharted 2: Among Thieves"], "type": "bar", "uid": "00cabd29-3497-40fc-8128-0dbe0da19f8f"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "orientation": "h", "x": [84.0, 85.0, 89.0, 91.0, 92.0, 93.0, 95.0, 96.0, 96.0, 96.0], "y": ["Gran Turismo 5", "Kingdom Hearts", "Gran Turismo 4", "Crash Bandicoot
# ...

# %%
#-----------------------------------------------------------------------
# Activision
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

ActivisionuC_bar_df = df_Activision_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_Activision_TOP_10uC.groupby('Name')[['gSales']].sum()
)
ActivisionuC_bar_df.columns = ['naSales', 'gSales']
ActivisionuC_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=ActivisionuC_bar_df.index,
    x=ActivisionuC_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=ActivisionuC_bar_df.index,
    x=ActivisionuC_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Activision Games (NA Sales vs Global Sales) [User Count]',
    barmode='stack'
)
ActivisionuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(ActivisionuC_bar_fig, show_link=False)
# Out:
# <div id="efe26890-df0d-47f0-a242-a55358721aef" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("efe26890-df0d-47f0-a242-a55358721aef", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.0, 0.25, 2.44, 2.49, 2.57, 8.53, 14.989999999999998], "y": ["Call of Duty 4: Modern Warfare", "Overwatch", "Diablo III", "Destiny", "StarCraft II: Wings of Liberty", "Call of Duty: Modern Warfare 2", "Call of Duty: Modern Warfare 3"], "type": "bar", "uid": "be40b976-5d3f-4713-b1b6-ae64505fc2fa"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [1.15, 0.53, 5.14, 5.64, 4.84, 14.350000000000001, 29.77], "y": ["Call of Duty 4: Modern Warfare", "Overwatch", "Diablo III", "Destiny", "StarCraft II: Wings of Libe
# ...

# %%
ActivisioncS_bar_df = df_Activision_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_Activision_TOP_10cS.groupby('Name')[['gSales']].sum()
)
ActivisioncS_bar_df.columns = ['naSales', 'gSales']
ActivisioncS_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=ActivisioncS_bar_df.index,
    x=ActivisioncS_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=ActivisioncS_bar_df.index,
    x=ActivisioncS_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Activision Games (NA Sales vs Global Sales) [Critic Score]',
    barmode='stack'
)
ActivisioncS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ActivisioncS_bar_fig, show_link=False)
# Out:
# <div id="b889646d-d843-4293-9338-f4036d003504" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b889646d-d843-4293-9338-f4036d003504", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.01, 1.68, 2.13, 2.66, 3.9, 9.04, 13.51], "y": ["Diablo", "Star Wars: Knights of the Old Republic", "Tony Hawk's Pro Skater 4", "Tony Hawk's Pro Skater 3", "Tony Hawk's Pro Skater 2", "Call of Duty 4: Modern Warfare", "Call of Duty: Modern Warfare 2"], "type": "bar", "uid": "1151fc4b-ebaf-4807-b0de-8eaa7ad9803f"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [1.59, 2.19, 3.67, 4.41, 5.859999999999999, 15.99, 24.07], "y": ["Diablo", "Star Wars: Knights of the Old Republic", "Tony Hawk's Pro Skater 4", "To
# ...

# %%
ActivisionuS_bar_df = df_Activision_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_Activision_TOP_10uS.groupby('Name')[['gSales']].sum()
)
ActivisionuS_bar_df.columns = ['naSales', 'gSales']
ActivisionuS_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=ActivisionuS_bar_df.index,
    x=ActivisionuS_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=ActivisionuS_bar_df.index,
    x=ActivisionuS_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Sports Games (NA Sales vs Global Sales) [User Score]',
    barmode='stack'
)
ActivisionuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ActivisionuS_bar_fig, show_link=False)
# Out:
# <div id="786e1cd9-b5cb-434d-8e23-696e636764b0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("786e1cd9-b5cb-434d-8e23-696e636764b0", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.01, 0.03, 0.05, 0.07, 0.27, 0.46, 0.85, 1.24, 1.68, 3.42], "y": ["Greg Hastings' Tournament Paintball Max'd", "Rock 'N Roll Racing", "X-Men: The Official Game", "Shrek SuperSlam", "Over the Hedge", "Greg Hastings' Tournament Paintball", "Tony Hawk's Underground", "Star Wars: Battlefront", "Star Wars: Knights of the Old Republic", "Tony Hawk's Pro Skater"], "type": "bar", "uid": "c8e9403d-be23-427b-a1f6-d25809cbf8b7"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [0.01, 0.05, 0.07, 0.09, 0.35, 0.54, 1.27
# ...

# %%
ActivisiongS_bar_df = df_Activision_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_Activision_TOP_10gS.groupby('Name')[['uScore']].sum()
)
ActivisiongS_bar_df.columns = ['cScore', 'uScore']
ActivisiongS_bar_df.sort_values('cScore', ascending=True, inplace=True)

trace0 = go.Bar(
    y=ActivisiongS_bar_df.index,
    x=ActivisiongS_bar_df['cScore'],
    name='Critic Score',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)
trace1 = go.Bar(
    y=ActivisiongS_bar_df.index,
    x=ActivisiongS_bar_df['uScore'],
    name='User Score',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Activision Games (Critic Score vs User Score) [Global Sales]',
    barmode='stack'
)
ActivisionuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ActivisionuS_bar_fig, show_link=False)
# Out:
# <div id="3238118e-50d9-42bb-a612-d00d5c0016f4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3238118e-50d9-42bb-a612-d00d5c0016f4", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "orientation": "h", "x": [52.0, 101.0, 127.0, 66.0, 126.0], "y": ["Call of Duty: Ghosts", "Call of Duty: Black Ops II", "Call of Duty: Black Ops", "Call of Duty: Modern Warfare 3", "Call of Duty: Modern Warfare 2"], "type": "bar", "uid": "8bdd25b3-470f-4248-a46f-fb3fd9d5b7da"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "orientation": "h", "x": [144.0, 166.0, 175.0, 176.0, 188.0], "y": ["Call of Duty: Ghosts", "Call of Duty: Black Ops II", "Call of Duty: Black Ops", "Call of Duty: Modern Warfare 3", "Call of Duty: Modern Warfare 2"], "type": "bar", "uid": "05699b
# ...

# %%
ActivisionnaS_bar_df = df_Activision_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_Activision_TOP_10naS.groupby('Name')[['uScore']].sum()
)
ActivisionnaS_bar_df.columns = ['cScore', 'uScore']
ActivisionnaS_bar_df.sort_values('cScore', ascending=True, inplace=True)

trace0 = go.Bar(
    y=ActivisionnaS_bar_df.index,
    x=ActivisionnaS_bar_df['cScore'],
    name='Critic Score',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)
trace1 = go.Bar(
    y=ActivisionnaS_bar_df.index,
    x=ActivisionnaS_bar_df['uScore'],
    name='User Score',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Activision Games (Critic Score vs User Score) [North American Sales]',
    barmode='stack'
)
ActivisionnaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ActivisionnaS_bar_fig, show_link=False)
# Out:
# <div id="dfac05fb-0eca-439e-a096-67d80df73cf0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("dfac05fb-0eca-439e-a096-67d80df73cf0", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "orientation": "h", "x": [26.0, 84.0, 101.0, 127.0, 66.0, 126.0], "y": ["Call of Duty: Ghosts", "Call of Duty 4: Modern Warfare", "Call of Duty: Black Ops II", "Call of Duty: Black Ops", "Call of Duty: Modern Warfare 3", "Call of Duty: Modern Warfare 2"], "type": "bar", "uid": "3f3d58da-ff74-4e9a-a543-826d43f1ec0a"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "orientation": "h", "x": [73.0, 94.0, 166.0, 175.0, 176.0, 188.0], "y": ["Call of Duty: Ghosts", "Call of Duty 4: Modern Warfare", "Call of Duty: Black Ops II", "Call of Duty: Black Ops", "Call of Duty: Mode
# ...

# %%
#-----------------------------------------------------------------------
# Bethesda
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------
BethesdauC_bar_df = df_Bethesda_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_Bethesda_TOP_10uC.groupby('Name')[['gSales']].sum()
)
BethesdauC_bar_df.columns = ['naSales', 'gSales']
BethesdauC_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=BethesdauC_bar_df.index,
    x=BethesdauC_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=BethesdauC_bar_df.index,
    x=BethesdauC_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Bethesda Games (NA Sales vs Global Sales) [User Count]',
    barmode='stack'
)
BethesdauC_bar_fig = go.Figure(data=data, layout=layout)
iplot(BethesdauC_bar_fig, show_link=False)
# Out:
# <div id="380e4254-68e1-49df-8820-33d6feb1522b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("380e4254-68e1-49df-8820-33d6feb1522b", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.32, 0.59, 3.42, 5.55, 8.76], "y": ["The Elder Scrolls Online", "Fallout: New Vegas", "Fallout 3", "Fallout 4", "The Elder Scrolls V: Skyrim"], "type": "bar", "uid": "bf6fd48a-88d9-4934-aaa1-be782e3b28e5"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [0.9, 1.17, 5.91, 12.669999999999998, 19.08], "y": ["The Elder Scrolls Online", "Fallout: New Vegas", "Fallout 3", "Fallout 4", "The Elder Scrolls V: Skyrim"], "type": "bar", "uid": "86f0693c-b97e-4e58-8c6e-e5edb619fab4"}], {"barmode": "stack", "title": {"t
# ...

# %%
BethesdacS_bar_df = df_Bethesda_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_Bethesda_TOP_10cS.groupby('Name')[['gSales']].sum()
)
BethesdacS_bar_df.columns = ['naSales', 'gSales']
BethesdacS_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=BethesdacS_bar_df.index,
    x=BethesdacS_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=BethesdacS_bar_df.index,
    x=BethesdacS_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Bethesda Games (NA Sales vs Global Sales) [Critic Score]',
    barmode='stack'
)
BethesdacS_bar_fig = go.Figure(data=data, layout=layout)
iplot(BethesdacS_bar_fig, show_link=False)
# Out:
# <div id="a39b79c0-a7e7-4a93-b098-28cd475c97ae" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a39b79c0-a7e7-4a93-b098-28cd475c97ae", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.22, 1.78, 2.51, 5.57, 8.76], "y": ["Dishonored 2", "Dishonored", "Fallout 4", "Fallout 3", "The Elder Scrolls V: Skyrim"], "type": "bar", "uid": "bcbb419d-e80f-40d8-b98c-f349b913878d"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [0.64, 3.24, 4.22, 9.85, 19.08], "y": ["Dishonored 2", "Dishonored", "Fallout 4", "Fallout 3", "The Elder Scrolls V: Skyrim"], "type": "bar", "uid": "d40716f2-ba61-449e-9d07-563f04580fe5"}], {"barmode": "stack", "title": {"text": "Top 10 Bethesda Games (NA Sales vs Global Sale
# ...

# %%
BethesdauS_bar_df = df_Bethesda_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_Bethesda_TOP_10uS.groupby('Name')[['gSales']].sum()
)
BethesdauS_bar_df.columns = ['naSales', 'gSales']
BethesdauS_bar_df.sort_values('naSales', ascending=True, inplace=True)

trace0 = go.Bar(
    y=BethesdauS_bar_df.index,
    x=BethesdauS_bar_df['gSales'],
    name='Global Sales',
    orientation = 'h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=BethesdauS_bar_df.index,
    x=BethesdauS_bar_df['naSales'],
    name='North American Sales',
    orientation = 'h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Bethesda Games (NA Sales vs Global Sales) [User Score]',
    barmode='stack'
)
BethesdauS_bar_fig = go.Figure(data=data, layout=layout)
iplot(BethesdauS_bar_fig, show_link=False)
# Out:
# <div id="14f557f0-4fbf-4560-a25c-5ff00423ce55" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("14f557f0-4fbf-4560-a25c-5ff00423ce55", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "North American Sales", "orientation": "h", "x": [0.6, 0.78, 1.06, 3.25, 5.55, 6.21], "y": ["Wolfenstein: The New Order", "The Elder Scrolls Online", "Dishonored", "Fallout: New Vegas", "Fallout 3", "The Elder Scrolls V: Skyrim"], "type": "bar", "uid": "46f57fda-8368-4bc5-a38f-8cac111c6125"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Global Sales", "orientation": "h", "x": [2.0, 1.28, 1.71, 5.22, 8.87, 12.669999999999998], "y": ["Wolfenstein: The New Order", "The Elder Scrolls Online", "Dishonored", "Fallout: New Vegas", "Fallout 3", "The Elder Scrolls V: Skyrim"], "type": "bar", "uid": "b2
# ...

# %%
BethesdagS_bar_df = df_Bethesda_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_Bethesda_TOP_10gS.groupby('Name')[['uScore']].sum()
)
BethesdagS_bar_df.columns = ['cScore', 'uScore']
BethesdagS_bar_df.sort_values('cScore', ascending=True, inplace=True)

trace0 = go.Bar(
    y=BethesdagS_bar_df.index,
    x=BethesdagS_bar_df['cScore'],
    name='Critic Score',
    orientation='h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=BethesdagS_bar_df.index,
    x=BethesdagS_bar_df['uScore'],
    name='User Score',
    orientation='h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Bethesda Games (Critic Score vs User Score) [Global Sales]',
    barmode='stack'
)
BethesdagS_bar_fig = go.Figure(data=data, layout=layout)
iplot(BethesdagS_bar_fig, show_link=False)
# Out:
# <div id="cd89da47-854f-4824-9298-64c93a05cdb8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cd89da47-854f-4824-9298-64c93a05cdb8", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "orientation": "h", "x": [73.0, 159.0, 127.0, 165.0, 229.0], "y": ["The Evil Within", "Fallout: New Vegas", "Fallout 4", "Fallout 3", "The Elder Scrolls V: Skyrim"], "type": "bar", "uid": "232c7c55-ecb6-441e-8577-ae594e8b3cc5"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "orientation": "h", "x": [75.0, 166.0, 175.0, 183.0, 282.0], "y": ["The Evil Within", "Fallout: New Vegas", "Fallout 4", "Fallout 3", "The Elder Scrolls V: Skyrim"], "type": "bar", "uid": "a654dbfe-13cd-4d07-887b-fa6dd76b6f38"}], {"barmode": "stack", "title": {"text": "Top 10 Bethesda Games (Crit
# ...

# %%
BethesdanaS_bar_df = df_Bethesda_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_Bethesda_TOP_10naS.groupby('Name')[['uScore']].sum()
)
BethesdanaS_bar_df.columns = ['cScore', 'uScore']
BethesdanaS_bar_df.sort_values('cScore', ascending=True, inplace=True)

trace0 = go.Bar(
    y=BethesdanaS_bar_df.index,
    x=BethesdanaS_bar_df['cScore'],
    name='Critic Score',
    orientation='h',
    marker=dict(
        color='seagreen',
        opacity=0.6
    )
)

trace1 = go.Bar(
    y=BethesdanaS_bar_df.index,
    x=BethesdanaS_bar_df['uScore'],
    name='User Score',
    orientation='h',
    marker=dict(
        color='dodgerblue',
        opacity=0.6
    )
)

data = [trace1, trace0]
layout = go.Layout(
    title= 'Top 10 Bethesda Games (Critic Score vs User Score) [North American Sales]',
    barmode='stack'
)
BethesdanaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(BethesdanaS_bar_fig, show_link=False)
# Out:
# <div id="00a3bcc9-0794-4e06-9726-06317a137b1d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("00a3bcc9-0794-4e06-9726-06317a137b1d", [{"marker": {"color": "dodgerblue", "opacity": 0.6}, "name": "User Score", "orientation": "h", "x": [79.0, 159.0, 127.0, 165.0, 229.0], "y": ["Dishonored", "Fallout: New Vegas", "Fallout 4", "Fallout 3", "The Elder Scrolls V: Skyrim"], "type": "bar", "uid": "5ba82e59-7f1e-4af7-8c97-7cba32acb7c4"}, {"marker": {"color": "seagreen", "opacity": 0.6}, "name": "Critic Score", "orientation": "h", "x": [88.0, 166.0, 175.0, 183.0, 282.0], "y": ["Dishonored", "Fallout: New Vegas", "Fallout 4", "Fallout 3", "The Elder Scrolls V: Skyrim"], "type": "bar", "uid": "da878576-250d-42b7-97f7-aedbaf4a947f"}], {"barmode": "stack", "title": {"text": "Top 10 Bethesda Games (Critic Score v
# ...

# %%
#-----------------------------------------------------------------------
# 2011
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

y2011uC_bar_df = df_2011_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_2011_TOP_10uC.groupby('Name')[['gSales']].sum()
)
y2011uC_bar_df.columns = ['naSales', 'gSales']
y2011uC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2011uC_bar_df.index,
    y=y2011uC_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2011uC_bar_df.index,
    y=y2011uC_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2011 Games (NA Sales vs Global Sales) [User Count]'}
y2011uC_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2011uC_bar_fig, show_link=False)
# Out:
# <div id="866500d5-422f-4f9e-b4cd-322c8b7a31cc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("866500d5-422f-4f9e-b4cd-322c8b7a31cc", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Call of Duty: Modern Warfare 3", "The Elder Scrolls V: Skyrim", "Uncharted 3: Drake's Deception", "Battlefield 3", "Portal 2", "The Witcher 2: Assassins of Kings", "Dragon Age II"], "y": [29.77, 12.669999999999998, 6.74, 2.78, 0.76, 0.96, 0.63], "type": "scatter", "uid": "f5f106d1-7885-4d5f-b160-08ce5411fff6"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Call of Duty: Modern Warfare 3", "The Elder Scrolls V: Skyrim", "Uncharted 3: Drake's Deception", "Battlefield 3", "Portal 2", "The Witcher 2: Assassins of Kings", "Dragon Age II"], "y": [14.989999999999998, 6.21, 2.77,
# ...

# %%
y2011cS_bar_df = df_2011_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_2011_TOP_10cS.groupby('Name')[['gSales']].sum()
)
y2011cS_bar_df.columns = ['naSales', 'gSales']
y2011cS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2011cS_bar_df.index,
    y=y2011cS_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2011cS_bar_df.index,
    y=y2011cS_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2011 Games (NA Sales vs Global Sales) [Critic Score]'}
y2011cS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2011cS_bar_fig, show_link=False)
# Out:
# <div id="85157526-3ad6-4ccf-ae4a-8fa40e673cd4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("85157526-3ad6-4ccf-ae4a-8fa40e673cd4", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["The Elder Scrolls V: Skyrim", "Batman: Arkham City", "Uncharted 3: Drake's Deception", "Portal 2", "The Legend of Zelda: Skyward Sword", "Mass Effect 2"], "y": [12.669999999999998, 10.21, 6.74, 4.54, 3.95, 1.45], "type": "scatter", "uid": "7b92a6ec-89ab-4d26-a9be-8200223795c1"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["The Elder Scrolls V: Skyrim", "Batman: Arkham City", "Uncharted 3: Drake's Deception", "Portal 2", "The Legend of Zelda: Skyward Sword", "Mass Effect 2"], "y": [6.21, 5.7, 2.77, 2.57, 2.03, 0.78], "type": "scatter", "uid": "74f01db2-a1fa-44c4-bb80-e8fd
# ...

# %%
y2011uS_bar_df = df_2011_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_2011_TOP_10uS.groupby('Name')[['gSales']].sum()
)
y2011uS_bar_df.columns = ['naSales', 'gSales']
y2011uS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2011uS_bar_df.index,
    y=y2011uS_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2011uS_bar_df.index,
    y=y2011uS_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2011 Games (NA Sales vs Global Sales) [User Score]'}
y2011uS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2011uS_bar_fig, show_link=False)
# Out:
# <div id="f8faacb4-24e1-4502-84f6-452f30a89b51" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f8faacb4-24e1-4502-84f6-452f30a89b51", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Batman: Arkham City", "Dead Space 2", "Dark Souls", "Ni no Kuni: Wrath of the White Witch", "Kirby: Mass Attack", "Portal 2", "Shin Megami Tensei: Devil Survivor 2", "Jimmie Johnson's Anything With an Engine", "BIT.TRIP COMPLETE"], "y": [10.21, 1.51, 2.02, 1.51, 0.99, 0.76, 0.31, 0.09, 0.09], "type": "scatter", "uid": "80b71959-5c64-4533-9985-95901ff48165"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Batman: Arkham City", "Dead Space 2", "Dark Souls", "Ni no Kuni: Wrath of the White Witch", "Kirby: Mass Attack", "Portal 2", "Shin Megami Tensei: Devil Survivor 2", "Jimm
# ...

# %%
y2011gS_bar_df = df_2011_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_2011_TOP_10gS.groupby('Name')[['uScore']].sum()
)
y2011gS_bar_df.columns = ['cScore', 'uScore']
y2011gS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2011gS_bar_df.index,
    y=y2011gS_bar_df['cScore'],
    name='Critic Score',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2011gS_bar_df.index,
    y=y2011gS_bar_df['uScore'],
    name='User Score',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2011 Games (Critic Score vs User Score) [Global Sales]'}
y2011gS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2011gS_bar_fig, show_link=False)
# Out:
# <div id="61f7f0e3-41e7-495d-95e5-e5419d98c82a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("61f7f0e3-41e7-495d-95e5-e5419d98c82a", [{"fill": "tozeroy", "mode": "none", "name": "Critic Score", "x": ["The Elder Scrolls V: Skyrim", "Call of Duty: Modern Warfare 3", "Battlefield 3", "Uncharted 3: Drake's Deception", "Super Mario 3D Land", "Mario Kart 7", "Just Dance 3"], "y": [188.0, 176.0, 169.0, 92.0, 90.0, 85.0, 74.0], "type": "scatter", "uid": "15894507-0f19-4c6f-97fa-2c1e89b6c90b"}, {"fill": "tonexty", "mode": "none", "name": "User Score", "x": ["The Elder Scrolls V: Skyrim", "Call of Duty: Modern Warfare 3", "Battlefield 3", "Uncharted 3: Drake's Deception", "Super Mario 3D Land", "Mario Kart 7", "Just Dance 3"], "y": [148.0, 66.0, 149.0, 83.0, 84.0, 82.0, 78.0], "type": "scatter", "uid": "213
# ...

# %%
y2011naS_bar_df = df_2011_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_2011_TOP_10naS.groupby('Name')[['uScore']].sum()
)
y2011naS_bar_df.columns = ['cScore', 'uScore']
y2011naS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2011naS_bar_df.index,
    y=y2011naS_bar_df['cScore'],
    name='Critic Score',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2011naS_bar_df.index,
    y=y2011naS_bar_df['uScore'],
    name='User Score',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2011 Games (Critic Score vs User Score) [North American Sales]'}
y2011naS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2011naS_bar_fig, show_link=False)
# Out:
# <div id="2acb4f99-75ae-4eef-b831-f7bf37b67ce8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2acb4f99-75ae-4eef-b831-f7bf37b67ce8", [{"fill": "tozeroy", "mode": "none", "name": "Critic Score", "x": ["Call of Duty: Modern Warfare 3", "Battlefield 3", "The Elder Scrolls V: Skyrim", "Batman: Arkham City", "Gears of War 3", "Super Mario 3D Land", "Mario Kart 7", "Just Dance 3"], "y": [176.0, 169.0, 96.0, 94.0, 91.0, 90.0, 85.0, 74.0], "type": "scatter", "uid": "41228c4e-dc1d-46bb-b812-6a3f5b60c3cc"}, {"fill": "tonexty", "mode": "none", "name": "User Score", "x": ["Call of Duty: Modern Warfare 3", "Battlefield 3", "The Elder Scrolls V: Skyrim", "Batman: Arkham City", "Gears of War 3", "Super Mario 3D Land", "Mario Kart 7", "Just Dance 3"], "y": [66.0, 149.0, 84.0, 87.0, 78.0, 84.0, 82.0, 78.0], "type"
# ...

# %%
#-----------------------------------------------------------------------
# 2012
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

y2012uC_bar_df = df_2012_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_2012_TOP_10uC.groupby('Name')[['gSales']].sum()
)
y2012uC_bar_df.columns = ['naSales', 'gSales']
y2012uC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2012uC_bar_df.index,
    y=y2012uC_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2012uC_bar_df.index,
    y=y2012uC_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2012 Games (NA Sales vs Global Sales) [User Count]'}
y2012uC_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2012uC_bar_fig, show_link=False)
# Out:
# <div id="25d8eb1c-de0e-4d96-8e1d-2ca913ff5624" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("25d8eb1c-de0e-4d96-8e1d-2ca913ff5624", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Call of Duty: Black Ops II", "Halo 4", "Diablo III", "Mass Effect 3", "Guild Wars 2", "Borderlands 2", "XCOM: Enemy Unknown", "Far Cry 3", "Max Payne 3"], "y": [13.67, 9.71, 5.14, 4.01, 2.31, 0.93, 0.71, 0.96, 0.43], "type": "scatter", "uid": "b219d37a-1254-43d7-9907-8ca079f86b97"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Call of Duty: Black Ops II", "Halo 4", "Diablo III", "Mass Effect 3", "Guild Wars 2", "Borderlands 2", "XCOM: Enemy Unknown", "Far Cry 3", "Max Payne 3"], "y": [8.25, 6.65, 2.44, 2.34, 0.96, 0.42, 0.27, 0.22, 0.16], "type": "scatter", "uid": "e2571
# ...

# %%
y2012cS_bar_df = df_2012_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_2012_TOP_10cS.groupby('Name')[['gSales']].sum()
)
y2012cS_bar_df.columns = ['naSales', 'gSales']
y2012cS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2012cS_bar_df.index,
    y=y2012cS_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2012cS_bar_df.index,
    y=y2012cS_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2012 Games (NA Sales vs Global Sales) [Critic Score]'}
y2012cS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2012cS_bar_fig, show_link=False)
# Out:
# <div id="de1dc1c8-d375-46b6-b39c-cf883ccbf610" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("de1dc1c8-d375-46b6-b39c-cf883ccbf610", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Mass Effect 3", "Far Cry 3", "NBA 2K13", "FIFA Soccer 13", "Borderlands 2", "Fire Emblem: Awakening", "Persona 4: Golden", "Journey"], "y": [4.46, 6.35, 2.47, 5.16, 2.23, 2.01, 1.12, 0.21], "type": "scatter", "uid": "cebc51b2-b3f0-4c16-946f-6e5dc8488140"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Mass Effect 3", "Far Cry 3", "NBA 2K13", "FIFA Soccer 13", "Borderlands 2", "Fire Emblem: Awakening", "Persona 4: Golden", "Journey"], "y": [2.57, 2.26, 1.73, 1.09, 1.05, 0.9, 0.36, 0.04], "type": "scatter", "uid": "44ad79fe-c536-4ef1-9b80-312a53a99f58"}], {"title": {"text":
# ...

# %%
y2012uS_bar_df = df_2012_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_2012_TOP_10uS.groupby('Name')[['gSales']].sum()
)
y2012uS_bar_df.columns = ['naSales', 'gSales']
y2012uS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2012uS_bar_df.index,
    y=y2012uS_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2012uS_bar_df.index,
    y=y2012uS_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2012 Games (NA Sales vs Global Sales) [User Score]'}
y2012uS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2012uS_bar_fig, show_link=False)
# Out:
# <div id="78d94b1a-a38c-4e60-b7ef-4fa0c3d98712" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("78d94b1a-a38c-4e60-b7ef-4fa0c3d98712", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Animal Crossing: New Leaf", "Fire Emblem: Awakening", "Devil May Cry HD Collection", "Persona 4: Golden", "Kirby's Dream Collection: Special Edition", "Zone of the Enders HD Collection", "Birds of Steel", "Ys: Memories of Celceta", "Journey", "Zero Escape: Virtue's Last Reward"], "y": [9.16, 2.01, 0.82, 1.12, 0.67, 0.2, 0.15, 0.24, 0.21, 0.03], "type": "scatter", "uid": "dcefbc70-d920-4201-bcac-df8542ae9034"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Animal Crossing: New Leaf", "Fire Emblem: Awakening", "Devil May Cry HD Collection", "Persona 4: Golden", "Kirby's Dre
# ...

# %%
y2012gS_bar_df = df_2012_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_2012_TOP_10gS.groupby('Name')[['uScore']].sum()
)
y2012gS_bar_df.columns = ['cScore', 'uScore']
y2012gS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2012gS_bar_df.index,
    y=y2012gS_bar_df['cScore'],
    name='Critic Score',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2012gS_bar_df.index,
    y=y2012gS_bar_df['uScore'],
    name='User Score',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2012 Games (Critic Score vs User Score) [Global Sales]'}
y2012gS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2012gS_bar_fig, show_link=False)
# Out:
# <div id="0014a0ef-4707-426a-858d-136cabcefc0b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0014a0ef-4707-426a-858d-136cabcefc0b", [{"fill": "tozeroy", "mode": "none", "name": "Critic Score", "x": ["Assassin's Creed III", "Call of Duty: Black Ops II", "Animal Crossing: New Leaf", "FIFA Soccer 13", "Halo 4", "New Super Mario Bros. U", "New Super Mario Bros. 2", "Just Dance 4"], "y": [169.0, 166.0, 88.0, 88.0, 87.0, 84.0, 78.0, 74.0], "type": "scatter", "uid": "b6396fd3-9007-4827-aff7-f3f1642b06e8"}, {"fill": "tonexty", "mode": "none", "name": "User Score", "x": ["Assassin's Creed III", "Call of Duty: Black Ops II", "Animal Crossing: New Leaf", "FIFA Soccer 13", "Halo 4", "New Super Mario Bros. U", "New Super Mario Bros. 2", "Just Dance 4"], "y": [136.0, 101.0, 87.0, 66.0, 70.0, 81.0, 72.0, 73.0],
# ...

# %%
y2012naS_bar_df = df_2012_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_2012_TOP_10naS.groupby('Name')[['uScore']].sum()
)
y2012naS_bar_df.columns = ['cScore', 'uScore']
y2012naS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2012naS_bar_df.index,
    y=y2012naS_bar_df['cScore'],
    name='Critic Score',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2012naS_bar_df.index,
    y=y2012naS_bar_df['uScore'],
    name='User Score',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2012 Games (Critic Score vs User Score) [North American Sales]'}
y2012naS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2012naS_bar_fig, show_link=False)
# Out:
# <div id="b34adf3f-6474-4532-bdbc-f94b87f767bd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b34adf3f-6474-4532-bdbc-f94b87f767bd", [{"fill": "tozeroy", "mode": "none", "name": "Critic Score", "x": ["Assassin's Creed III", "Call of Duty: Black Ops II", "NBA 2K13", "Halo 4", "Madden NFL 13", "New Super Mario Bros. 2", "Nintendo Land", "Just Dance 4"], "y": [169.0, 166.0, 88.0, 87.0, 81.0, 78.0, 77.0, 74.0], "type": "scatter", "uid": "e215eb0b-f38b-4336-96eb-4e4b6b3ed1af"}, {"fill": "tonexty", "mode": "none", "name": "User Score", "x": ["Assassin's Creed III", "Call of Duty: Black Ops II", "NBA 2K13", "Halo 4", "Madden NFL 13", "New Super Mario Bros. 2", "Nintendo Land", "Just Dance 4"], "y": [136.0, 101.0, 72.0, 70.0, 58.0, 72.0, 79.0, 73.0], "type": "scatter", "uid": "57347c8a-8da1-4a6d-8e4a-1d19
# ...

# %%
#-----------------------------------------------------------------------
# 2013
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

y2013uC_bar_df = df_2013_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_2013_TOP_10uC.groupby('Name')[['gSales']].sum()
)
y2013uC_bar_df.columns = ['naSales', 'gSales']
y2013uC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2013uC_bar_df.index,
    y=y2013uC_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2013uC_bar_df.index,
    y=y2013uC_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2013 Games (NA Sales vs Global Sales) [User Count]'}
y2013uC_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2013uC_bar_fig, show_link=False)
# Out:
# <div id="425c52ca-0763-4a82-b662-7d9dfc1e32dd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("425c52ca-0763-4a82-b662-7d9dfc1e32dd", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Grand Theft Auto V", "The Last of Us", "SimCity (2013)", "Battlefield 4", "BioShock Infinite", "Total War: Rome II", "Company of Heroes 2", "Metro: Last Light", "Payday 2"], "y": [37.31, 5.87, 1.42, 1.35, 0.66, 0.72, 0.34, 0.19, 0.05], "type": "scatter", "uid": "6fa953aa-7131-48e3-9864-7392a646d576"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Grand Theft Auto V", "The Last of Us", "SimCity (2013)", "Battlefield 4", "BioShock Infinite", "Total War: Rome II", "Company of Heroes 2", "Metro: Last Light", "Payday 2"], "y": [16.68, 2.41, 0.48, 0.39, 0.29, 0.12, 0.06, 0.06, 
# ...

# %%
y2013cS_bar_df = df_2013_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_2013_TOP_10cS.groupby('Name')[['gSales']].sum()
)
y2013cS_bar_df.columns = ['naSales', 'gSales']
y2013cS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2013cS_bar_df.index,
    y=y2013cS_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2013cS_bar_df.index,
    y=y2013cS_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2013 Games (NA Sales vs Global Sales) [Critic Score]'}
y2013cS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2013cS_bar_fig, show_link=False)
# Out:
# <div id="cc7e0968-3f15-4090-8212-5a618e79ed14" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cc7e0968-3f15-4090-8212-5a618e79ed14", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Grand Theft Auto V", "The Last of Us", "BioShock Infinite", "Super Mario 3D World", "The Legend of Zelda: A Link Between Worlds", "Metal Gear Solid: The Legacy Collection", "Rayman Legends"], "y": [37.31, 5.87, 4.28, 4.32, 3.1, 0.4, 0.66], "type": "scatter", "uid": "0ffd4c13-0ca2-47d2-ae94-e7adf3aa75ae"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Grand Theft Auto V", "The Last of Us", "BioShock Infinite", "Super Mario 3D World", "The Legend of Zelda: A Link Between Worlds", "Metal Gear Solid: The Legacy Collection", "Rayman Legends"], "y": [16.68, 2.41, 2.23, 2.11, 1.
# ...

# %%
y2013uS_bar_df = df_2013_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_2013_TOP_10uS.groupby('Name')[['gSales']].sum()
)
y2013uS_bar_df.columns = ['naSales', 'gSales']
y2013uS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2013uS_bar_df.index,
    y=y2013uS_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2013uS_bar_df.index,
    y=y2013uS_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2013 Games (NA Sales vs Global Sales) [User Score]'}
y2013uS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2013uS_bar_fig, show_link=False)
# Out:
# <div id="04425771-2c32-404a-9ea2-943ce58e5aff" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("04425771-2c32-404a-9ea2-943ce58e5aff", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["The Last of Us", "Super Mario 3D World", "The Legend of Zelda: A Link Between Worlds", "Pikmin 3", "Rayman Legends", "Metal Gear Solid: The Legacy Collection", "Killzone: Mercenary", "Tearaway", "Steins;Gate"], "y": [5.87, 4.32, 3.1, 1.11, 1.24, 0.4, 0.8, 0.61, 0.1], "type": "scatter", "uid": "2b79d528-cf2b-4e04-9efb-056c7652264c"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["The Last of Us", "Super Mario 3D World", "The Legend of Zelda: A Link Between Worlds", "Pikmin 3", "Rayman Legends", "Metal Gear Solid: The Legacy Collection", "Killzone: Mercenary", "Tearaway", "S
# ...

# %%
y2013gS_bar_df = df_2013_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_2013_TOP_10gS.groupby('Name')[['uScore']].sum()
)
y2013gS_bar_df.columns = ['cScore', 'uScore']
y2013gS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2013gS_bar_df.index,
    y=y2013gS_bar_df['cScore'],
    name='Critic Score',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2013gS_bar_df.index,
    y=y2013gS_bar_df['uScore'],
    name='User Score',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2013 Games (Critic Score vs User Score) [Global Sales]'}
y2013gS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2013gS_bar_fig, show_link=False)
# Out:
# <div id="1ec7ffec-dfa4-45c8-aeb2-89e714e6c0f6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1ec7ffec-dfa4-45c8-aeb2-89e714e6c0f6", [{"fill": "tozeroy", "mode": "none", "name": "Critic Score", "x": ["Call of Duty: Ghosts", "Grand Theft Auto V", "FIFA 14", "The Last of Us", "Super Mario 3D World", "Luigi's Mansion: Dark Moon"], "y": [222.0, 194.0, 170.0, 95.0, 93.0, 86.0], "type": "scatter", "uid": "13ca05d0-984f-4cfe-b830-4ccacce133b5"}, {"fill": "tonexty", "mode": "none", "name": "User Score", "x": ["Call of Duty: Ghosts", "Grand Theft Auto V", "FIFA 14", "The Last of Us", "Super Mario 3D World", "Luigi's Mansion: Dark Moon"], "y": [89.0, 163.0, 85.0, 91.0, 90.0, 84.0], "type": "scatter", "uid": "34fd2b33-9a1d-44a2-9e9d-c6c0fb2f95ac"}], {"title": {"text": "Top 10 2013 Games (Critic Score vs User
# ...

# %%
y2013naS_bar_df = df_2013_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_2013_TOP_10naS.groupby('Name')[['uScore']].sum()
)
y2013naS_bar_df.columns = ['cScore', 'uScore']
y2013naS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2013naS_bar_df.index,
    y=y2013naS_bar_df['cScore'],
    name='Critic Score',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2013naS_bar_df.index,
    y=y2013naS_bar_df['uScore'],
    name='User Score',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2013 Games (Critic Score vs User Score) [North American Sales]'}
y2013naS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2013naS_bar_fig, show_link=False)
# Out:
# <div id="355330ed-3f11-4c7a-b4df-cb53339f5950" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("355330ed-3f11-4c7a-b4df-cb53339f5950", [{"fill": "tozeroy", "mode": "none", "name": "Critic Score", "x": ["Grand Theft Auto V", "Call of Duty: Ghosts", "The Last of Us", "Super Mario 3D World", "NBA 2K14", "Assassin's Creed IV: Black Flag", "Madden NFL 25", "Battlefield 4"], "y": [194.0, 144.0, 95.0, 93.0, 87.0, 86.0, 80.0, 79.0], "type": "scatter", "uid": "96c04974-d9b6-484a-9bed-5feb2faefbca"}, {"fill": "tonexty", "mode": "none", "name": "User Score", "x": ["Grand Theft Auto V", "Call of Duty: Ghosts", "The Last of Us", "Super Mario 3D World", "NBA 2K14", "Assassin's Creed IV: Black Flag", "Madden NFL 25", "Battlefield 4"], "y": [163.0, 52.0, 91.0, 90.0, 49.0, 79.0, 56.0, 56.0], "type": "scatter", "uid"
# ...

# %%
#-----------------------------------------------------------------------
# 2014
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

y2014uC_bar_df = df_2014_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_2014_TOP_10uC.groupby('Name')[['gSales']].sum()
)
y2014uC_bar_df.columns = ['naSales', 'gSales']
y2014uC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2014uC_bar_df.index,
    y=y2014uC_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2014uC_bar_df.index,
    y=y2014uC_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2014 Games (NA Sales vs Global Sales) [User Count]'}
y2014uC_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2014uC_bar_fig, show_link=False)
# Out:
# <div id="1c9c8742-a5ee-432a-820a-f476983868df" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1c9c8742-a5ee-432a-820a-f476983868df", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Grand Theft Auto V", "Destiny", "Titanfall", "Watch Dogs", "inFAMOUS: Second Son", "Dragon Age: Inquisition", "The Elder Scrolls Online", "Dark Souls II", "Pillars of Eternity"], "y": [12.61, 5.64, 2.95, 4.5, 2.79, 0.73, 0.9, 0.17, 0.02], "type": "scatter", "uid": "49242010-7c33-4c45-9c3f-2c538b928771"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Grand Theft Auto V", "Destiny", "Titanfall", "Watch Dogs", "inFAMOUS: Second Son", "Dragon Age: Inquisition", "The Elder Scrolls Online", "Dark Souls II", "Pillars of Eternity"], "y": [3.96, 2.49, 1.84, 1.5499999999999998, 1.2
# ...

# %%
y2014cS_bar_df = df_2014_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_2014_TOP_10cS.groupby('Name')[['gSales']].sum()
)
y2014cS_bar_df.columns = ['naSales', 'gSales']
y2014cS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2014cS_bar_df.index,
    y=y2014cS_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2014cS_bar_df.index,
    y=y2014cS_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2014 Games (NA Sales vs Global Sales) [Critic Score]'}
y2014cS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2014cS_bar_fig, show_link=False)
# Out:
# <div id="8685faeb-ca1a-46a2-9dc0-d92abf9b5165" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8685faeb-ca1a-46a2-9dc0-d92abf9b5165", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Grand Theft Auto V", "Dark Souls II", "Dragon Age: Inquisition", "Rayman Legends", "Bayonetta 2", "The Legend of Heroes: Trails of Cold Steel II"], "y": [18.09, 2.1799999999999997, 2.01, 1.35, 0.76, 0.15], "type": "scatter", "uid": "efacc593-fb21-43d4-8ba8-f42e4e4e2765"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Grand Theft Auto V", "Dark Souls II", "Dragon Age: Inquisition", "Rayman Legends", "Bayonetta 2", "The Legend of Heroes: Trails of Cold Steel II"], "y": [6.77, 0.96, 0.73, 0.35, 0.32, 0.02], "type": "scatter", "uid": "3f26f406-32ef-4d7e-9aed-8407f8e03fc9"}], 
# ...

# %%
y2014uS_bar_df = df_2014_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_2014_TOP_10uS.groupby('Name')[['gSales']].sum()
)
y2014uS_bar_df.columns = ['naSales', 'gSales']
y2014uS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2014uS_bar_df.index,
    y=y2014uS_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2014uS_bar_df.index,
    y=y2014uS_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2014 Games (NA Sales vs Global Sales) [User Score]'}
y2014uS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2014uS_bar_fig, show_link=False)
# Out:
# <div id="33a4ca26-0509-44b3-93ed-ce8660c5eeb7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("33a4ca26-0509-44b3-93ed-ce8660c5eeb7", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Mario Kart 8", "Donkey Kong Country: Tropical Freeze", "Monster Hunter 4 Ultimate", "Kirby: Triple Deluxe", "Captain Toad: Treasure Tracker", "LEGO The Hobbit", "Hatsune Miku: Project Diva F 2nd", "Danganronpa 2: Goodbye Despair", "Divinity: Original Sin", "Phoenix Wright: Ace Attorney Trilogy"], "y": [7.09, 1.52, 3.89, 1.83, 1.19, 0.45, 0.25, 0.17, 0.02, 0.02], "type": "scatter", "uid": "10edbb7e-0bac-4b2c-80a1-819d7ae133c0"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Mario Kart 8", "Donkey Kong Country: Tropical Freeze", "Monster Hunter 4 Ultimate", "Kirby: Triple D
# ...

# %%
y2014gS_bar_df = df_2014_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_2014_TOP_10gS.groupby('Name')[['uScore']].sum()
)
y2014gS_bar_df.columns = ['cScore', 'uScore']
y2014gS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2014gS_bar_df.index,
    y=y2014gS_bar_df['cScore'],
    name='Critic Score',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2014gS_bar_df.index,
    y=y2014gS_bar_df['uScore'],
    name='User Score',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2014 Games (Critic Score vs User Score) [Global Sales]'}
y2014gS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2014gS_bar_fig, show_link=False)
# Out:
# <div id="da83014a-0fb2-46c2-82a6-2323fb7bfac0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("da83014a-0fb2-46c2-82a6-2323fb7bfac0", [{"fill": "tozeroy", "mode": "none", "name": "Critic Score", "x": ["Grand Theft Auto V", "Call of Duty: Advanced Warfare", "Mario Kart 8", "Far Cry 4", "FIFA 15", "Watch Dogs", "Destiny", "Assassin's Creed: Unity"], "y": [194.0, 164.0, 88.0, 85.0, 82.0, 80.0, 76.0, 70.0], "type": "scatter", "uid": "d78042f4-1dc0-4768-a969-5f65c492a683"}, {"fill": "tonexty", "mode": "none", "name": "User Score", "x": ["Grand Theft Auto V", "Call of Duty: Advanced Warfare", "Mario Kart 8", "Far Cry 4", "FIFA 15", "Watch Dogs", "Destiny", "Assassin's Creed: Unity"], "y": [162.0, 111.0, 91.0, 77.0, 57.0, 63.0, 61.0, 49.0], "type": "scatter", "uid": "923c4abb-a74e-442e-b5a0-474d86281189"}
# ...

# %%
y2014naS_bar_df = df_2014_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_2014_TOP_10naS.groupby('Name')[['uScore']].sum()
)
y2014naS_bar_df.columns = ['cScore', 'uScore']
y2014naS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2014naS_bar_df.index,
    y=y2014naS_bar_df['cScore'],
    name='Critic Score',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2014naS_bar_df.index,
    y=y2014naS_bar_df['uScore'],
    name='User Score',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2014 Games (Critic Score vs User Score) [North American Sales]'}
y2014naS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2014naS_bar_fig, show_link=False)
# Out:
# <div id="3b698aad-142e-4a6d-995a-fd97cc90d120" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3b698aad-142e-4a6d-995a-fd97cc90d120", [{"fill": "tozeroy", "mode": "none", "name": "Critic Score", "x": ["Grand Theft Auto V", "Call of Duty: Advanced Warfare", "Destiny", "Mario Kart 8", "Titanfall", "Halo: The Master Chief Collection", "Assassin's Creed: Unity"], "y": [194.0, 164.0, 151.0, 88.0, 86.0, 85.0, 72.0], "type": "scatter", "uid": "43e46898-f43e-43d3-b87f-64f2a354394f"}, {"fill": "tonexty", "mode": "none", "name": "User Score", "x": ["Grand Theft Auto V", "Call of Duty: Advanced Warfare", "Destiny", "Mario Kart 8", "Titanfall", "Halo: The Master Chief Collection", "Assassin's Creed: Unity"], "y": [162.0, 111.0, 116.0, 91.0, 64.0, 72.0, 41.0], "type": "scatter", "uid": "87a94dbe-7c2a-444b-b9a6-
# ...

# %%
#-----------------------------------------------------------------------
# 2015
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

y2015uC_bar_df = df_2015_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_2015_TOP_10uC.groupby('Name')[['gSales']].sum()
)
y2015uC_bar_df.columns = ['naSales', 'gSales']
y2015uC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2015uC_bar_df.index,
    y=y2015uC_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2015uC_bar_df.index,
    y=y2015uC_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2015 Games (NA Sales vs Global Sales) [User Count]'}
y2015uC_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2015uC_bar_fig, show_link=False)
# Out:
# <div id="74125358-1514-4264-909e-b4583fb412fe" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("74125358-1514-4264-909e-b4583fb412fe", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Grand Theft Auto V", "Destiny", "Titanfall", "Watch Dogs", "inFAMOUS: Second Son", "Dragon Age: Inquisition", "The Elder Scrolls Online", "Dark Souls II", "Pillars of Eternity"], "y": [12.61, 5.64, 2.95, 4.5, 2.79, 0.73, 0.9, 0.17, 0.02], "type": "scatter", "uid": "035f4749-6682-49fa-9cc1-ed9d32e96d9e"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Grand Theft Auto V", "Destiny", "Titanfall", "Watch Dogs", "inFAMOUS: Second Son", "Dragon Age: Inquisition", "The Elder Scrolls Online", "Dark Souls II", "Pillars of Eternity"], "y": [3.96, 2.49, 1.84, 1.5499999999999998, 1.2
# ...

# %%
y2015cS_bar_df = df_2015_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_2015_TOP_10cS.groupby('Name')[['gSales']].sum()
)
y2015cS_bar_df.columns = ['naSales', 'gSales']
y2015cS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2015cS_bar_df.index,
    y=y2015cS_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2015cS_bar_df.index,
    y=y2015cS_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2015 Games (NA Sales vs Global Sales) [Critic Score]'}
y2015cS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2015cS_bar_fig, show_link=False)
# Out:
# <div id="75353d5d-807d-4204-a1cf-4410e6a84a71" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("75353d5d-807d-4204-a1cf-4410e6a84a71", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Grand Theft Auto V", "Dark Souls II", "Dragon Age: Inquisition", "Rayman Legends", "Bayonetta 2", "The Legend of Heroes: Trails of Cold Steel II"], "y": [18.09, 2.1799999999999997, 2.01, 1.35, 0.76, 0.15], "type": "scatter", "uid": "a5a03ee2-1820-4783-8751-3d98a8f9a6ca"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Grand Theft Auto V", "Dark Souls II", "Dragon Age: Inquisition", "Rayman Legends", "Bayonetta 2", "The Legend of Heroes: Trails of Cold Steel II"], "y": [6.77, 0.96, 0.73, 0.35, 0.32, 0.02], "type": "scatter", "uid": "c8a5857d-a36d-4801-aedb-ebda39a5a5ea"}], 
# ...

# %%
y2015uS_bar_df = df_2015_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_2015_TOP_10uS.groupby('Name')[['gSales']].sum()
)
y2015uS_bar_df.columns = ['naSales', 'gSales']
y2015uS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2015uS_bar_df.index,
    y=y2015uS_bar_df['gSales'],
    name='Global Sales',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2015uS_bar_df.index,
    y=y2015uS_bar_df['naSales'],
    name='North American Sales',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2015 Games (NA Sales vs Global Sales) [User Score]'}
y2015uS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2015uS_bar_fig, show_link=False)
# Out:
# <div id="58862f71-3ced-4262-9e53-91ac1fd720dc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("58862f71-3ced-4262-9e53-91ac1fd720dc", [{"fill": "tozeroy", "mode": "none", "name": "Global Sales", "x": ["Mario Kart 8", "Donkey Kong Country: Tropical Freeze", "Monster Hunter 4 Ultimate", "Kirby: Triple Deluxe", "Captain Toad: Treasure Tracker", "LEGO The Hobbit", "Hatsune Miku: Project Diva F 2nd", "Danganronpa 2: Goodbye Despair", "Divinity: Original Sin", "Phoenix Wright: Ace Attorney Trilogy"], "y": [7.09, 1.52, 3.89, 1.83, 1.19, 0.45, 0.25, 0.17, 0.02, 0.02], "type": "scatter", "uid": "93890b4d-a101-4983-982b-596c37110d8d"}, {"fill": "tonexty", "mode": "none", "name": "North American Sales", "x": ["Mario Kart 8", "Donkey Kong Country: Tropical Freeze", "Monster Hunter 4 Ultimate", "Kirby: Triple D
# ...

# %%
y2015gS_bar_df = df_2015_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_2015_TOP_10gS.groupby('Name')[['uScore']].sum()
)
y2015gS_bar_df.columns = ['cScore', 'uScore']
y2015gS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2015gS_bar_df.index,
    y=y2015gS_bar_df['cScore'],
    name='Critic Score',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2015gS_bar_df.index,
    y=y2015gS_bar_df['uScore'],
    name='User Score',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2015 Games (Critic Score vs User Score) [Global Sales]'}
y2015gS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2015gS_bar_fig, show_link=False)
# Out:
# <div id="9f3190aa-8216-4a58-8fc4-af184f6ead88" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9f3190aa-8216-4a58-8fc4-af184f6ead88", [{"fill": "tozeroy", "mode": "none", "name": "Critic Score", "x": ["Grand Theft Auto V", "Call of Duty: Advanced Warfare", "Mario Kart 8", "Far Cry 4", "FIFA 15", "Watch Dogs", "Destiny", "Assassin's Creed: Unity"], "y": [194.0, 164.0, 88.0, 85.0, 82.0, 80.0, 76.0, 70.0], "type": "scatter", "uid": "0de836e5-0eb5-4bfb-8541-6c49468ad18b"}, {"fill": "tonexty", "mode": "none", "name": "User Score", "x": ["Grand Theft Auto V", "Call of Duty: Advanced Warfare", "Mario Kart 8", "Far Cry 4", "FIFA 15", "Watch Dogs", "Destiny", "Assassin's Creed: Unity"], "y": [162.0, 111.0, 91.0, 77.0, 57.0, 63.0, 61.0, 49.0], "type": "scatter", "uid": "1bfaed7e-1a36-4fa1-9af1-428d2ad9a0e0"}
# ...

# %%
y2015naS_bar_df = df_2015_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_2015_TOP_10naS.groupby('Name')[['uScore']].sum()
)
y2015naS_bar_df.columns = ['cScore', 'uScore']
y2015naS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=y2015naS_bar_df.index,
    y=y2015naS_bar_df['cScore'],
    name='Critic Score',
    fill='tozeroy',
    mode='none'
)

trace1 = go.Scatter(
    x=y2015naS_bar_df.index,
    y=y2015naS_bar_df['uScore'],
    name='User Score',
    fill='tonexty',
    mode='none'
)

data = [trace0, trace1]
layout = {'title': 'Top 10 2015 Games (Critic Score vs User Score) [North American Sales]'}
y2015naS_bar_fig = go.Figure(data=data, layout=layout)
iplot(y2015naS_bar_fig, show_link=False)
# Out:
# <div id="3a0c8c43-34a9-4b21-9a16-10f2b6c8fc30" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3a0c8c43-34a9-4b21-9a16-10f2b6c8fc30", [{"fill": "tozeroy", "mode": "none", "name": "Critic Score", "x": ["Grand Theft Auto V", "Call of Duty: Advanced Warfare", "Destiny", "Mario Kart 8", "Titanfall", "Halo: The Master Chief Collection", "Assassin's Creed: Unity"], "y": [194.0, 164.0, 151.0, 88.0, 86.0, 85.0, 72.0], "type": "scatter", "uid": "39028a8a-c15d-4476-bab6-5b06b8eb1263"}, {"fill": "tonexty", "mode": "none", "name": "User Score", "x": ["Grand Theft Auto V", "Call of Duty: Advanced Warfare", "Destiny", "Mario Kart 8", "Titanfall", "Halo: The Master Chief Collection", "Assassin's Creed: Unity"], "y": [162.0, 111.0, 116.0, 91.0, 64.0, 72.0, 41.0], "type": "scatter", "uid": "82e59a71-bf16-45bb-b3f3-
# ...

# %%
#-----------------------------------------------------------------------
# Action
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

ActionuC_bar_df = df_Action_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_Action_TOP_10uC.groupby('Name')[['gSales']].sum()
)
ActionuC_bar_df.columns = ['naSales', 'gSales']
ActionuC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ActionuC_bar_df.index,
    y=ActionuC_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Action_TOP_10uC['gSales']*5,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ActionuC_bar_df.index,
    y=ActionuC_bar_df['naSales'],
    name='North American Sales',
    mode='markers',
    marker=dict(
        size=df_Action_TOP_10uC['naSales']*5,
        color='dodgerblue'
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Action Games (NA Sales vs Global Sales) [User Count]'}
ActionuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(ActionuC_bar_fig, show_link=False)
# Out:
# <div id="24f43abb-f543-4bc4-810e-0959a9674b6c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("24f43abb-f543-4bc4-810e-0959a9674b6c", [{"marker": {"color": "seagreen", "size": [29.35, 12.4, 33.3, 8.5, 3.15, 4.8, 105.19999999999999, 17.05, 5.85, 33.7]}, "mode": "markers", "name": "Global Sales", "x": ["Grand Theft Auto V", "Uncharted 2: Among Thieves", "Uncharted 3: Drake's Deception", "The Last of Us", "Metal Gear Solid V: The Phantom Pain", "Bloodborne", "No Man's Sky", "The Witcher 2: Assassins of Kings", "Dragon Age II"], "y": [22.21, 6.66, 6.74, 5.87, 3.41, 2.48, 1.7, 0.96, 0.63], "type": "scatter", "uid": "a8be0a5f-9acc-44c1-a45a-ebe10738606c"}, {"marker": {"color": "dodgerblue", "size": [12.05, 5.15, 16.35, 3.15, 1.1500000000000001, 1.25, 35.099999999999994, 5.45, 1.9500000000000002, 13.85]},
# ...

# %%
ActioncS_bar_df = df_Action_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_Action_TOP_10cS.groupby('Name')[['gSales']].sum()
)
ActioncS_bar_df.columns = ['naSales', 'gSales']
ActioncS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ActioncS_bar_df.index,
    y=ActioncS_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Action_TOP_10cS['gSales']*5,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ActioncS_bar_df.index,
    y=ActioncS_bar_df['naSales'],
    name='North American Sales',
    mode='markers',
    marker=dict(
        size=df_Action_TOP_10cS['naSales']*5,
        color='dodgerblue'
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Action Games (NA Sales vs Global Sales) [Critic Score]'}
ActioncS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ActioncS_bar_fig, show_link=False)
# Out:
# <div id="da347850-7e29-462a-a016-46592bb5142e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("da347850-7e29-462a-a016-46592bb5142e", [{"marker": {"color": "seagreen", "size": [55.05, 52.5, 105.19999999999999, 81.35, 65.5, 63.05, 27.400000000000002, 33.3, 30.25, 27.400000000000002]}, "mode": "markers", "name": "Global Sales", "x": ["Grand Theft Auto V", "Grand Theft Auto IV", "Grand Theft Auto III", "Uncharted 2: Among Thieves", "Batman: Arkham City", "Metal Gear Solid 2: Sons of Liberty"], "y": [55.400000000000006, 21.509999999999998, 13.1, 6.66, 5.48, 6.05], "type": "scatter", "uid": "fc25b212-febd-4a8d-b04b-6d172bb37b72"}, {"marker": {"color": "dodgerblue", "size": [33.8, 23.799999999999997, 35.099999999999994, 48.3, 34.95, 19.8, 14.05, 16.35, 12.25, 13.55]}, "mode": "markers", "name": "North Am
# ...

# %%
ActionuS_bar_df = df_Action_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_Action_TOP_10uS.groupby('Name')[['gSales']].sum()
)
ActionuS_bar_df.columns = ['naSales', 'gSales']
ActionuS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ActionuS_bar_df.index,
    y=ActionuS_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Action_TOP_10uS['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ActionuS_bar_df.index,
    y=ActionuS_bar_df['naSales'],
    name='North American Sales',
    mode='markers',
    marker=dict(
        size=df_Action_TOP_10uS['naSales']*10,
        color='dodgerblue'
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Action Games (NA Sales vs Global Sales) [User Score]'}
ActionuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ActionuS_bar_fig, show_link=False)
# Out:
# <div id="bacec42c-7aaf-4623-bd11-1bcdc7d7dde0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bacec42c-7aaf-4623-bd11-1bcdc7d7dde0", [{"marker": {"color": "seagreen", "size": [60.300000000000004, 16.9, 42.300000000000004, 21.099999999999998, 10.0, 6.3, 5.5, 5.300000000000001, 3.5999999999999996, 0.8999999999999999]}, "mode": "markers", "name": "Global Sales", "x": ["Metal Gear Solid", "Metal Gear Solid 3: Snake Eater", "Resident Evil 4", "Dynasty Warriors 4", "Metal Gear Solid 3: Subsistence", "Hamtaro: Ham-Ham Heartbreak", "Legacy of Kain: Defiance", "Dynasty Warriors 3: Xtreme Legends", "Okami", "Shrek SuperSlam"], "y": [6.03, 4.23, 1.69, 2.11, 0.55, 0.36, 0.53, 1.0, 0.63, 0.09], "type": "scatter", "uid": "32445237-3952-4275-8954-3b12bffacd4a"}, {"marker": {"color": "dodgerblue", "size": [31.8, 
# ...

# %%
ActiongS_bar_df = df_Action_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_Action_TOP_10gS.groupby('Name')[['uScore']].sum()
)
ActiongS_bar_df.columns = ['cScore', 'uScore']
ActiongS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ActiongS_bar_df.index,
    y=ActiongS_bar_df['cScore'],
    name='Critic Score',
    mode='markers',
    marker=dict(
        size=df_Action_TOP_10gS['cScore'],
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ActiongS_bar_df.index,
    y=ActiongS_bar_df['uScore'],
    name='User Score',
    mode='markers',
    marker=dict(
        size=df_Action_TOP_10gS['uScore'],
        color='dodgerblue'
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Action Games (Critic Score vs User Score) [Global Sales]'}
ActiongS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ActiongS_bar_fig, show_link=False)
# Out:
# <div id="a16b2ed0-486d-41f4-997d-e1f0d57926df" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a16b2ed0-486d-41f4-997d-e1f0d57926df", [{"marker": {"color": "seagreen", "size": [97.0, 95.0, 97.0, 95.0, 97.0, 97.0, 98.0, 98.0, 88.0, 88.0]}, "mode": "markers", "name": "Critic Score", "x": ["Grand Theft Auto V", "Grand Theft Auto IV", "Grand Theft Auto III", "Grand Theft Auto: San Andreas", "Grand Theft Auto: Vice City", "FIFA Soccer 13", "Grand Theft Auto: Liberty City Stories"], "y": [291.0, 196.0, 97.0, 95.0, 95.0, 88.0, 88.0], "type": "scatter", "uid": "df27cb0d-375a-4c49-a2dc-546c85001b4d"}, {"marker": {"color": "dodgerblue", "size": [82.0, 90.0, 81.0, 87.0, 85.0, 83.0, 79.0, 75.0, 66.0, 76.0]}, "mode": "markers", "name": "User Score", "x": ["Grand Theft Auto V", "Grand Theft Auto IV", "Grand Thef
# ...

# %%
ActionnaS_bar_df = df_Action_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_Action_TOP_10naS.groupby('Name')[['uScore']].sum()
)
ActionnaS_bar_df.columns = ['cScore', 'uScore']
ActionnaS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ActionnaS_bar_df.index,
    y=ActionnaS_bar_df['cScore'],
    name='Critic Score',
    mode='markers',
    marker=dict(
        size=df_Action_TOP_10naS['cScore'],
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ActionnaS_bar_df.index,
    y=ActionnaS_bar_df['uScore'],
    name='User Score',
    mode='markers',
    marker=dict(
        size=df_Action_TOP_10naS['uScore'],
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Action Games (Critic Score vs User Score) [North American Sales]'}
ActionnaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ActionnaS_bar_fig, show_link=False)
# Out:
# <div id="205e8599-2274-4b3c-8004-7b607f2e985b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("205e8599-2274-4b3c-8004-7b607f2e985b", [{"marker": {"color": "seagreen", "size": [97.0, 95.0, 95.0, 97.0, 97.0, 98.0, 98.0, 97.0, 95.0, 95.0]}, "mode": "markers", "name": "Critic Score", "x": ["Grand Theft Auto V", "Grand Theft Auto IV", "Grand Theft Auto III", "Grand Theft Auto: San Andreas", "Grand Theft Auto: Vice City", "Red Dead Redemption", "The Legend of Zelda: Twilight Princess"], "y": [291.0, 196.0, 97.0, 95.0, 95.0, 95.0, 95.0], "type": "scatter", "uid": "ebd85322-b03a-4b30-aa25-7a631c854c0c"}, {"marker": {"color": "dodgerblue", "size": [81.0, 90.0, 87.0, 82.0, 85.0, 79.0, 75.0, 83.0, 90.0, 90.0]}, "mode": "markers", "name": "User Score", "x": ["Grand Theft Auto V", "Grand Theft Auto IV", "Grand
# ...

# %%
#-----------------------------------------------------------------------
# Shooter
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

ShooteruC_bar_df = df_Shooter_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_Shooter_TOP_10uC.groupby('Name')[['gSales']].sum()
)
ShooteruC_bar_df.columns = ['naSales', 'gSales']
ShooteruC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ShooteruC_bar_df.index,
    y=ShooteruC_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10uC['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ShooteruC_bar_df.index,
    y=ShooteruC_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10uC['naSales']*10,
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Shooter Games (NA Sales vs Global Sales) [User Count]'}
ShooteruC_bar_fig = go.Figure(data=data, layout=layout)
iplot(ShooteruC_bar_fig, show_link=False)
# Out:
# <div id="52235833-544f-44ca-97f9-abda7dbfa2e8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("52235833-544f-44ca-97f9-abda7dbfa2e8", [{"marker": {"color": "seagreen", "size": [0.8, 147.3, 23.700000000000003, 6.6000000000000005, 53.8, 8.8, 7.6, 17.2, 56.4, 133.2]}, "mode": "markers", "name": "Global Sales", "x": ["Call of Duty: Modern Warfare 3", "Destiny", "Half-Life 2", "Uncharted 4: A Thief's End", "Portal 2", "BioShock Infinite", "Call of Duty: Modern Warfare 2", "Counter-Strike: Source"], "y": [29.77, 5.64, 2.37, 5.38, 0.76, 0.66, 0.88, 0.08], "type": "scatter", "uid": "e0396333-a5a3-4eca-8a82-3ffd62b73bf0"}, {"marker": {"color": "dodgerblue", "size": [0.0, 90.39999999999999, 22.799999999999997, 2.9, 18.5, 0.1, 3.3000000000000003, 4.1, 24.900000000000002, 55.4]}, "mode": "markers", "name": "NA
# ...

# %%
ShootercS_bar_df = df_Shooter_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_Shooter_TOP_10cS.groupby('Name')[['gSales']].sum()
)
ShootercS_bar_df.columns = ['naSales', 'gSales']
ShootercS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ShootercS_bar_df.index,
    y=ShootercS_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10cS['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ShootercS_bar_df.index,
    y=ShootercS_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10cS['naSales']*10,
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Shooter Games (NA Sales vs Global Sales) [Critic Score]'}
ShootercS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ShootercS_bar_fig, show_link=False)
# Out:
# <div id="81ad8271-8a68-4678-8bed-2ae10fd95fef" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("81ad8271-8a68-4678-8bed-2ae10fd95fef", [{"marker": {"color": "seagreen", "size": [64.3, 28.2, 41.2, 28.3, 23.700000000000003, 18.2, 4.1, 1.4000000000000001, 84.9, 20.8]}, "mode": "markers", "name": "Global Sales", "x": ["Halo 2", "Halo: Combat Evolved", "Half-Life", "Half-Life 2", "Metroid Prime", "BioShock", "Portal 2", "The Orange Box"], "y": [8.49, 6.43, 4.12, 2.37, 2.82, 3.24, 2.08, 1.96], "type": "scatter", "uid": "bfff48d8-7dda-4820-8237-6a732c54506f"}, {"marker": {"color": "dodgerblue", "size": [49.800000000000004, 19.6, 40.300000000000004, 16.5, 22.799999999999997, 10.9, 0.1, 0.0, 68.2, 14.1]}, "mode": "markers", "name": "NA Sales", "x": ["Halo 2", "Halo: Combat Evolved", "Half-Life", "Half-Life 2
# ...

# %%
ShooteruS_bar_df = df_Shooter_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_Shooter_TOP_10uS.groupby('Name')[['gSales']].sum()
)
ShooteruS_bar_df.columns = ['naSales', 'gSales']
ShooteruS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ShooteruS_bar_df.index,
    y=ShooteruS_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10uS['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ShooteruS_bar_df.index,
    y=ShooteruS_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10uS['naSales']*10,
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Shooter Games (NA Sales vs Global Sales) [User Score]'}
ShooteruS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ShooteruS_bar_fig, show_link=False)
# Out:
# <div id="5aa29b8a-a7ed-4111-b263-36854168d40e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5aa29b8a-a7ed-4111-b263-36854168d40e", [{"marker": {"color": "seagreen", "size": [28.2, 6.1, 1.4000000000000001, 1.0, 0.5, 5.4, 0.2, 0.2, 0.1, 41.2]}, "mode": "markers", "name": "Global Sales", "x": ["Half-Life", "Metroid Prime", "Greg Hastings' Tournament Paintball", "Metroid Prime: Trilogy", "Metal Arms: Glitch in the System", "Yager", "Total Overdose: A Gunslinger's Tale in Mexico", "Greg Hastings' Tournament Paintball Max'd", "Left 4 Dead", "The Orange Box"], "y": [4.12, 2.82, 0.54, 0.61, 0.1, 0.05, 0.02, 0.01, 0.02, 0.14], "type": "scatter", "uid": "a9922816-ef8e-416a-a4d3-02643c9083a1"}, {"marker": {"color": "dodgerblue", "size": [19.6, 4.2, 0.0, 0.8, 0.3, 4.6000000000000005, 0.2, 0.0, 0.1, 40.30000
# ...

# %%
ShootergS_bar_df = df_Shooter_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_Shooter_TOP_10gS.groupby('Name')[['uScore']].sum()
)
ShootergS_bar_df.columns = ['cScore', 'uScore']
ShootergS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ShootergS_bar_df.index,
    y=ShootergS_bar_df['cScore'],
    name='Critic Score',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10gS['cScore'],
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ShootergS_bar_df.index,
    y=ShootergS_bar_df['uScore'],
    name='User Score',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10gS['uScore'],
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Shooter Games (Critic Score vs User Score) [Global Sales]'}
ShootergS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ShootergS_bar_fig, show_link=False)
# Out:
# <div id="c7b02816-8ed1-43c1-9502-fd6f2c9b4614" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c7b02816-8ed1-43c1-9502-fd6f2c9b4614", [{"marker": {"color": "seagreen", "size": [88.0, 87.0, 83.0, 83.0, 94.0, 88.0, 88.0, 94.0, 94.0, 73.0]}, "mode": "markers", "name": "Critic Score", "x": ["Call of Duty: Modern Warfare 2", "Call of Duty: Modern Warfare 3", "Call of Duty: Black Ops", "Call of Duty: Black Ops II", "Halo 3", "Call of Duty: Ghosts"], "y": [188.0, 176.0, 175.0, 166.0, 94.0, 73.0], "type": "scatter", "uid": "af313862-2ec0-4df9-9915-163393f61328"}, {"marker": {"color": "dodgerblue", "size": [34.0, 63.0, 53.0, 48.0, 63.0, 32.0, 64.0, 78.0, 63.0, 26.0]}, "mode": "markers", "name": "User Score", "x": ["Call of Duty: Modern Warfare 2", "Call of Duty: Modern Warfare 3", "Call of Duty: Black Ops",
# ...

# %%
ShooternaS_bar_df = df_Shooter_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_Shooter_TOP_10naS.groupby('Name')[['uScore']].sum()
)
ShooternaS_bar_df.columns = ['cScore', 'uScore']
ShooternaS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ShooternaS_bar_df.index,
    y=ShooternaS_bar_df['cScore'],
    name='Critic Score',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10naS['cScore'],
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ShooternaS_bar_df.index,
    y=ShooternaS_bar_df['uScore'],
    name='User Score',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10naS['uScore'],
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Shooter Games (Critic Score vs User Score) [NA Sales]'}
ShooteruS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ShooteruS_bar_fig, show_link=False)
# Out:
# <div id="70f5f1c5-604f-4ccf-83de-b801ecab999e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("70f5f1c5-604f-4ccf-83de-b801ecab999e", [{"marker": {"color": "seagreen", "size": [87.0, 88.0, 94.0, 83.0, 94.0, 91.0, 95.0, 73.0, 87.0, 88.0]}, "mode": "markers", "name": "Critic Score", "x": ["Call of Duty: Black Ops", "Halo 2", "Call of Duty: Modern Warfare 2", "Halo 3", "Halo: Reach", "Call of Duty: Modern Warfare 3", "Halo 4", "Call of Duty: Black Ops II", "Call of Duty: Ghosts"], "y": [175.0, 95.0, 94.0, 94.0, 91.0, 88.0, 87.0, 83.0, 73.0], "type": "scatter", "uid": "ad3eba08-9d35-4edf-ada0-bd43d1df69f9"}, {"marker": {"color": "dodgerblue", "size": [63.0, 34.0, 63.0, 48.0, 78.0, 79.0, 82.0, 26.0, 70.0, 64.0]}, "mode": "markers", "name": "User Score", "x": ["Call of Duty: Black Ops", "Halo 2", "Call o
# ...

# %%
#-----------------------------------------------------------------------
# Strategy
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

StrategyuC_bar_df = df_Strategy_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_Strategy_TOP_10uC.groupby('Name')[['gSales']].sum()
)
StrategyuC_bar_df.columns = ['naSales', 'gSales']
StrategyuC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=StrategyuC_bar_df.index,
    y=StrategyuC_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Strategy_TOP_10uC['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=StrategyuC_bar_df.index,
    y=StrategyuC_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_Strategy_TOP_10uC['naSales']*10,
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Strategy Games (NA Sales vs Global Sales) [User Count]'}
StrategyuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(StrategyuC_bar_fig, show_link=False)
# Out:
# <div id="1caf654e-4e1e-4f19-964e-d94b74b8b182" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1caf654e-4e1e-4f19-964e-d94b74b8b182", [{"marker": {"color": "seagreen", "size": [3.4000000000000004, 7.199999999999999, 48.4, 10.8, 16.8, 7.1, 11.7, 4.699999999999999, 16.7, 2.3000000000000003]}, "mode": "markers", "name": "Global Sales", "x": ["StarCraft II: Wings of Liberty", "Sid Meier's Civilization V", "StarCraft II: Heart of the Swarm", "XCOM: Enemy Unknown", "Total War: Rome II", "XCOM 2", "Company of Heroes 2", "Spore", "Empire: Total War", "Warhammer 40,000: Dawn of War II"], "y": [4.84, 1.68, 1.67, 0.71, 0.72, 0.23, 0.34, 1.17, 1.08, 0.47], "type": "scatter", "uid": "fe880ea0-735a-484c-babe-978d20a41d11"}, {"marker": {"color": "dodgerblue", "size": [0.6, 1.2, 25.7, 0.1, 9.8, 2.7, 0.3, 0.0, 8.29
# ...

# %%
StrategycS_bar_df = df_Strategy_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_Strategy_TOP_10cS.groupby('Name')[['gSales']].sum()
)
StrategycS_bar_df.columns = ['naSales', 'gSales']
StrategycS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=StrategycS_bar_df.index,
    y=StrategycS_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Strategy_TOP_10cS['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=StrategycS_bar_df.index,
    y=StrategycS_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_Strategy_TOP_10cS['naSales']*10,
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Strategy Games (NA Sales vs Global Sales) [Critic Score]'}
StrategycS_bar_fig = go.Figure(data=data, layout=layout)
iplot(StrategycS_bar_fig, show_link=False)
# Out:
# <div id="ef819d56-2d96-462d-bbb1-f0cd143b0a76" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ef819d56-2d96-462d-bbb1-f0cd143b0a76", [{"marker": {"color": "seagreen", "size": [1.6, 48.4, 0.5, 0.2, 7.0, 1.3, 1.0, 0.8999999999999999, 16.8, 12.0]}, "mode": "markers", "name": "Global Sales", "x": ["StarCraft II: Wings of Liberty", "Sid Meier's Civilization V", "Advance Wars", "Pikmin 2", "Warcraft III: Reign of Chaos", "Sid Meier's Civilization IV", "Age of Empires II: The Age of Kings", "Company of Heroes", "Homeworld", "Rome: Total War"], "y": [4.84, 1.68, 0.7, 1.2, 0.13, 0.16, 0.09, 0.05, 0.02, 0.1], "type": "scatter", "uid": "c5992574-7449-4369-abe6-89373f51ce58"}, {"marker": {"color": "dodgerblue", "size": [0.2, 25.7, 0.0, 0.0, 5.0, 0.3, 0.0, 0.1, 9.8, 4.8]}, "mode": "markers", "name": "NA Sales"
# ...

# %%
StrategyuS_bar_df = df_Strategy_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_Strategy_TOP_10uS.groupby('Name')[['gSales']].sum()
)
StrategyuS_bar_df.columns = ['naSales', 'gSales']
StrategyuS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=StrategyuS_bar_df.index,
    y=StrategyuS_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Strategy_TOP_10uS['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=StrategyuS_bar_df.index,
    y=StrategyuS_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_Strategy_TOP_10uS['naSales']*10,
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Strategy Games (NA Sales vs Global Sales) [User Score]'}
StrategyuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(StrategyuS_bar_fig, show_link=False)
# Out:
# <div id="5c0c0f54-ec7a-472c-b438-fc641e2d4391" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5c0c0f54-ec7a-472c-b438-fc641e2d4391", [{"marker": {"color": "seagreen", "size": [6.5, 9.7, 0.4, 12.0, 8.9, 3.5, 1.3, 1.1, 1.0, 0.5]}, "mode": "markers", "name": "Global Sales", "x": ["Fire Emblem", "Pikmin 2", "Advance Wars 2: Black Hole Rising", "Fire Emblem: The Sacred Stones", "Worms: Open Warfare 2", "Dynasty Tactics 2", "Rebelstar: Tactical Command", "Warcraft III: Reign of Chaos", "Worms 4: Mayhem", "Rome: Total War"], "y": [0.97, 1.2, 0.65, 0.89, 0.35, 0.11, 0.05, 0.13, 0.04, 0.1], "type": "scatter", "uid": "c6ebd3b3-a5d0-40b1-8e8b-3f4f8d8ad334"}, {"marker": {"color": "dodgerblue", "size": [4.699999999999999, 4.9, 0.3, 4.8, 4.2, 0.7000000000000001, 0.3, 0.5, 0.0, 0.4]}, "mode": "markers", "name": 
# ...

# %%
StrategygS_bar_df = df_Strategy_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_Strategy_TOP_10gS.groupby('Name')[['uScore']].sum()
)
StrategygS_bar_df.columns = ['cScore', 'uScore']
StrategygS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=StrategygS_bar_df.index,
    y=StrategygS_bar_df['cScore'],
    name='Critic Score',
    mode='markers',
    marker=dict(
        size=df_Strategy_TOP_10gS['cScore'],
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=StrategygS_bar_df.index,
    y=StrategygS_bar_df['uScore'],
    name='User Score',
    mode='markers',
    marker=dict(
        size=df_Strategy_TOP_10gS['uScore'],
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Strategy Games (Critic Score vs User Score) [Global Sales]'}
StrategygS_bar_fig = go.Figure(data=data, layout=layout)
iplot(StrategygS_bar_fig, show_link=False)
# Out:
# <div id="f7ee5858-470f-42fc-9bd3-661bca6bc20f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f7ee5858-470f-42fc-9bd3-661bca6bc20f", [{"marker": {"color": "seagreen", "size": [93.0, 82.0, 90.0, 86.0, 89.0, 88.0, 59.0, 83.0, 65.0, 74.0]}, "mode": "markers", "name": "Critic Score", "x": ["StarCraft II: Wings of Liberty", "Sid Meier's Civilization V", "Pikmin", "Warcraft III: The Frozen Throne", "StarCraft II: Heart of the Swarm", "Anno 2070", "Halo Wars", "RollerCoaster Tycoon 2", "LEGO Battles", "LEGO Battles: Ninjago"], "y": [93.0, 90.0, 89.0, 88.0, 86.0, 83.0, 82.0, 74.0, 65.0, 59.0], "type": "scatter", "uid": "e714d664-c706-40f1-9269-6b4540b8b431"}, {"marker": {"color": "dodgerblue", "size": [82.0, 72.0, 79.0, 79.0, 87.0, 90.0, 69.0, 70.0, 89.0, 85.0]}, "mode": "markers", "name": "User Score", "
# ...

# %%
StrategynaS_bar_df = df_Strategy_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_Strategy_TOP_10naS.groupby('Name')[['uScore']].sum()
)
StrategynaS_bar_df.columns = ['cScore', 'uScore']
StrategynaS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=StrategynaS_bar_df.index,
    y=StrategynaS_bar_df['cScore'],
    name='Critic Score',
    mode='markers',
    marker=dict(
        size=df_Strategy_TOP_10naS['cScore'],
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=StrategynaS_bar_df.index,
    y=StrategynaS_bar_df['uScore'],
    name='User Score',
    mode='markers',
    marker=dict(
        size=df_Strategy_TOP_10naS['uScore'],
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Strategy Games (Critic Score vs User Score) [NA Sales]'}
StrategyuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(StrategyuS_bar_fig, show_link=False)
# Out:
# <div id="fc58b2a0-1538-4905-909f-1cf203e8c809" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fc58b2a0-1538-4905-909f-1cf203e8c809", [{"marker": {"color": "seagreen", "size": [93.0, 82.0, 74.0, 59.0, 90.0, 81.0, 44.0, 86.0, 89.0, 65.0]}, "mode": "markers", "name": "Critic Score", "x": ["StarCraft II: Wings of Liberty", "Sid Meier's Civilization V", "Pikmin", "StarCraft II: Heart of the Swarm", "Halo Wars", "Plants vs. Zombies", "RollerCoaster Tycoon 2", "LEGO Battles", "LEGO Battles: Ninjago", "Zoo Tycoon DS"], "y": [93.0, 90.0, 89.0, 86.0, 82.0, 81.0, 74.0, 65.0, 59.0, 44.0], "type": "scatter", "uid": "6369b2dc-7c42-49b2-bf4c-a4facc348825"}, {"marker": {"color": "dodgerblue", "size": [82.0, 72.0, 85.0, 69.0, 79.0, 74.0, 66.0, 79.0, 87.0, 89.0]}, "mode": "markers", "name": "User Score", "x": ["Sta
# ...

# %%
#-----------------------------------------------------------------------
# Sports
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

SportsuC_bar_df = df_Sports_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_Sports_TOP_10uC.groupby('Name')[['gSales']].sum()
)
SportsuC_bar_df.columns = ['naSales', 'gSales']
SportsuC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=SportsuC_bar_df.index,
    y=SportsuC_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Sports_TOP_10uC['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=SportsuC_bar_df.index,
    y=SportsuC_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_Sports_TOP_10uC['naSales']*10,
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Sports Games (NA Sales vs Global Sales) [User Count]'}
SportsuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(SportsuC_bar_fig, show_link=False)
# Out:
# <div id="d5526f47-ad79-4781-b1c9-401ae82b4825" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d5526f47-ad79-4781-b1c9-401ae82b4825", [{"marker": {"color": "seagreen", "size": [3.7, 60.8, 85.7, 7.9, 30.099999999999998, 0.6, 64.7, 4.5, 32.5, 4.0]}, "mode": "markers", "name": "Global Sales", "x": ["FIFA 16", "FIFA 14", "FIFA 15", "Pro Evolution Soccer 2016", "Rocket League", "Pro Evolution Soccer 2017"], "y": [11.82, 9.88, 6.08, 0.79, 0.43, 0.45], "type": "scatter", "uid": "02cff4f2-d577-4d1e-88e2-fa2844918817"}, {"marker": {"color": "dodgerblue", "size": [0.3, 8.0, 11.200000000000001, 1.3, 6.1, 0.1, 7.800000000000001, 0.2, 8.9, 0.1]}, "mode": "markers", "name": "NA Sales", "x": ["FIFA 16", "FIFA 14", "FIFA 15", "Pro Evolution Soccer 2016", "Rocket League", "Pro Evolution Soccer 2017"], "y": [2.01000
# ...

# %%
SportscS_bar_df = df_Sports_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_Sports_TOP_10cS.groupby('Name')[['gSales']].sum()
)
SportscS_bar_df.columns = ['naSales', 'gSales']
SportscS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=SportscS_bar_df.index,
    y=SportscS_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Sports_TOP_10cS['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=SportscS_bar_df.index,
    y=SportscS_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_Sports_TOP_10cS['naSales']*10,
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Sports Games (NA Sales vs Global Sales) [Critic Score]'}
SportscS_bar_fig = go.Figure(data=data, layout=layout)
iplot(SportscS_bar_fig, show_link=False)
# Out:
# <div id="628d3c47-32a7-4286-875d-5920333247e9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("628d3c47-32a7-4286-875d-5920333247e9", [{"marker": {"color": "seagreen", "size": [46.8, 44.1, 10.9, 41.4, 11.799999999999999, 36.7, 30.8, 16.7, 7.6, 5.1]}, "mode": "markers", "name": "Global Sales", "x": ["Tony Hawk's Pro Skater 2", "Madden NFL 2003", "Tony Hawk's Pro Skater 3", "Madden NFL 2002", "Tony Hawk's Pro Skater 4", "NCAA Football 2004", "NFL 2K1", "Madden NFL 2004", "ISS Pro Evolution"], "y": [5.859999999999999, 4.14, 4.41, 3.08, 3.67, 1.67, 1.09, 0.51, 0.76], "type": "scatter", "uid": "7a53795e-a1da-445d-be73-aff95244fa5c"}, {"marker": {"color": "dodgerblue", "size": [30.5, 26.6, 10.2, 33.6, 8.5, 21.299999999999997, 25.0, 13.5, 0.0, 4.0]}, "mode": "markers", "name": "NA Sales", "x": ["Tony Hawk
# ...

# %%
SportsuS_bar_df = df_Sports_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_Sports_TOP_10uS.groupby('Name')[['gSales']].sum()
)
SportsuS_bar_df.columns = ['naSales', 'gSales']
SportsuS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=SportsuS_bar_df.index,
    y=SportsuS_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_Sports_TOP_10uS['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=SportsuS_bar_df.index,
    y=SportsuS_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_Sports_TOP_10uS['naSales']*10,
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Sports Games (NA Sales vs Global Sales) [User Score]'}
SportsuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(SportsuS_bar_fig, show_link=False)
# Out:
# <div id="e80175be-a10b-4a83-8543-dc403789c7d5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e80175be-a10b-4a83-8543-dc403789c7d5", [{"marker": {"color": "seagreen", "size": [3.0, 0.1, 1.3, 0.8, 0.8, 0.3, 50.199999999999996, 16.599999999999998, 6.2, 1.0]}, "mode": "markers", "name": "Global Sales", "x": ["Tony Hawk's Pro Skater", "NBA Ballers", "Madden NFL 07", "MLB SlugFest Loaded", "Backyard Baseball", "College Hoops 2K6", "NHL 06", "Swingerz Golf", "Wade Hixton's Counter Punch"], "y": [5.02, 1.66, 0.65, 0.3, 0.13, 0.1, 0.08, 0.08, 0.01], "type": "scatter", "uid": "c473362a-bdf3-408e-bbe1-f02c190c0bd7"}, {"marker": {"color": "dodgerblue", "size": [1.4000000000000001, 0.1, 1.0, 0.6, 0.6, 0.2, 34.2, 8.100000000000001, 4.8, 0.7000000000000001]}, "mode": "markers", "name": "NA Sales", "x": ["Tony H
# ...

# %%
ShootergS_bar_df = df_Shooter_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_Shooter_TOP_10gS.groupby('Name')[['uScore']].sum()
)
ShootergS_bar_df.columns = ['cScore', 'uScore']
ShootergS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ShootergS_bar_df.index,
    y=ShootergS_bar_df['cScore'],
    name='Critic Score',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10gS['cScore'],
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ShootergS_bar_df.index,
    y=ShootergS_bar_df['uScore'],
    name='User Score',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10gS['uScore'],
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Shooter Games (Critic Score vs User Score) [Global Sales]'}
ShootergS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ShootergS_bar_fig, show_link=False)
# Out:
# <div id="eeaa1a26-1954-4331-878f-84b9e9d708db" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("eeaa1a26-1954-4331-878f-84b9e9d708db", [{"marker": {"color": "seagreen", "size": [88.0, 87.0, 83.0, 83.0, 94.0, 88.0, 88.0, 94.0, 94.0, 73.0]}, "mode": "markers", "name": "Critic Score", "x": ["Call of Duty: Modern Warfare 2", "Call of Duty: Modern Warfare 3", "Call of Duty: Black Ops", "Call of Duty: Black Ops II", "Halo 3", "Call of Duty: Ghosts"], "y": [188.0, 176.0, 175.0, 166.0, 94.0, 73.0], "type": "scatter", "uid": "427b090c-6517-4075-a54f-ff038391e9cb"}, {"marker": {"color": "dodgerblue", "size": [34.0, 63.0, 53.0, 48.0, 63.0, 32.0, 64.0, 78.0, 63.0, 26.0]}, "mode": "markers", "name": "User Score", "x": ["Call of Duty: Modern Warfare 2", "Call of Duty: Modern Warfare 3", "Call of Duty: Black Ops",
# ...

# %%
ShooternaS_bar_df = df_Shooter_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_Shooter_TOP_10naS.groupby('Name')[['uScore']].sum()
)
ShooternaS_bar_df.columns = ['cScore', 'uScore']
ShooternaS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=ShooternaS_bar_df.index,
    y=ShooternaS_bar_df['cScore'],
    name='Critic Score',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10naS['cScore'],
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=ShooternaS_bar_df.index,
    y=ShooternaS_bar_df['uScore'],
    name='User Score',
    mode='markers',
    marker=dict(
        size=df_Shooter_TOP_10naS['uScore'],
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 Shooter Games (Critic Score vs User Score) [NA Sales]'}
ShooternaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(ShooternaS_bar_fig, show_link=False)
# Out:
# <div id="3c4a8e1f-2b7f-47c4-b7fc-624660175d23" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3c4a8e1f-2b7f-47c4-b7fc-624660175d23", [{"marker": {"color": "seagreen", "size": [87.0, 88.0, 94.0, 83.0, 94.0, 91.0, 95.0, 73.0, 87.0, 88.0]}, "mode": "markers", "name": "Critic Score", "x": ["Call of Duty: Black Ops", "Halo 2", "Call of Duty: Modern Warfare 2", "Halo 3", "Halo: Reach", "Call of Duty: Modern Warfare 3", "Halo 4", "Call of Duty: Black Ops II", "Call of Duty: Ghosts"], "y": [175.0, 95.0, 94.0, 94.0, 91.0, 88.0, 87.0, 83.0, 73.0], "type": "scatter", "uid": "cd0542fd-8761-4c83-a55a-4b077233590c"}, {"marker": {"color": "dodgerblue", "size": [63.0, 34.0, 63.0, 48.0, 78.0, 79.0, 82.0, 26.0, 70.0, 64.0]}, "mode": "markers", "name": "User Score", "x": ["Call of Duty: Black Ops", "Halo 2", "Call o
# ...

# %%
#-----------------------------------------------------------------------
# RPG
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

RPGuC_bar_df = df_RPG_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_RPG_TOP_10uC.groupby('Name')[['gSales']].sum()
)
RPGuC_bar_df.columns = ['naSales', 'gSales']
RPGuC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=RPGuC_bar_df.index,
    y=RPGuC_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_RPG_TOP_10uC['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=RPGuC_bar_df.index,
    y=RPGuC_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_RPG_TOP_10uC['naSales']*10,
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 RPG Games (NA Sales vs Global Sales) [User Count]'}
RPGuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(RPGuC_bar_fig, show_link=False)
# Out:
# <div id="a9d28de6-ea78-43e9-a2de-dbdc54adbefd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a9d28de6-ea78-43e9-a2de-dbdc54adbefd", [{"marker": {"color": "seagreen", "size": [7.199999999999999, 39.7, 51.4, 38.8, 12.9, 9.7, 71.6, 13.100000000000001, 7.3, 30.4]}, "mode": "markers", "name": "Global Sales", "x": ["Fallout 4", "Diablo III", "Mass Effect 3", "The Witcher 3: Wild Hunt", "The Elder Scrolls V: Skyrim", "Dragon Age: Inquisition"], "y": [8.45, 5.14, 4.01, 6.0, 3.88, 0.73], "type": "scatter", "uid": "34feb18d-b214-443a-b7eb-53ed52e4197c"}, {"marker": {"color": "dodgerblue", "size": [2.1, 10.2, 24.4, 11.6, 5.1, 4.0, 25.299999999999997, 6.8999999999999995, 3.3000000000000003, 19.4]}, "mode": "markers", "name": "NA Sales", "x": ["Fallout 4", "Diablo III", "Mass Effect 3", "The Witcher 3: Wild H
# ...

# %%
RPGcS_bar_df = df_RPG_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_RPG_TOP_10cS.groupby('Name')[['gSales']].sum()
)
RPGcS_bar_df.columns = ['naSales', 'gSales']
RPGcS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=RPGcS_bar_df.index,
    y=RPGcS_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_RPG_TOP_10cS['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=RPGcS_bar_df.index,
    y=RPGcS_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_RPG_TOP_10cS['naSales']*10,
        color='dodgerblue',
    )
)


data = [trace0, trace1]
layout = {'title': 'Top 10 RPG Games (NA Sales vs Global Sales) [Critic Score]'}
RPGcS_bar_fig = go.Figure(data=data, layout=layout)
iplot(RPGcS_bar_fig, show_link=False)
# Out:
# <div id="611c00bb-f321-4ada-8b1d-2e079c3b663c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("611c00bb-f321-4ada-8b1d-2e079c3b663c", [{"marker": {"color": "seagreen", "size": [87.89999999999999, 31.0, 53.0, 43.8, 38.8, 21.9, 18.6, 15.9, 14.5, 3.9000000000000004]}, "mode": "markers", "name": "Global Sales", "x": ["The Elder Scrolls V: Skyrim", "The Elder Scrolls IV: Oblivion", "Mass Effect 2", "Star Wars: Knights of the Old Republic", "Final Fantasy IX", "Chrono Cross", "Diablo"], "y": [12.669999999999998, 4.38, 4.9399999999999995, 2.19, 5.3, 1.86, 1.59], "type": "scatter", "uid": "01d39076-ee38-4a65-82eb-53ad58efd071"}, {"marker": {"color": "dodgerblue", "size": [50.5, 19.9, 16.200000000000003, 28.2, 11.6, 16.8, 6.2, 0.1, 7.800000000000001, 0.1]}, "mode": "markers", "name": "NA Sales", "x": ["The 
# ...

# %%
RPGuS_bar_df = df_RPG_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_RPG_TOP_10uS.groupby('Name')[['gSales']].sum()
)
RPGuS_bar_df.columns = ['naSales', 'gSales']
RPGuS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=RPGuS_bar_df.index,
    y=RPGuS_bar_df['gSales'],
    name='Global Sales',
    mode='markers',
    marker=dict(
        size=df_RPG_TOP_10uS['gSales']*10,
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=RPGuS_bar_df.index,
    y=RPGuS_bar_df['naSales'],
    name='NA Sales',
    mode='markers',
    marker=dict(
        size=df_RPG_TOP_10uS['naSales']*10,
        color='dodgerblue',
    )
)


data = [trace0, trace1]
layout = {'title': 'Top 10 RPG Games (NA Sales vs Global Sales) [User Score]'}
RPGuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(RPGuS_bar_fig, show_link=False)
# Out:
# <div id="55a656b2-d75e-469d-a03b-1301fa6260e9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("55a656b2-d75e-469d-a03b-1301fa6260e9", [{"marker": {"color": "seagreen", "size": [1.5, 12.2, 22.5, 0.8999999999999999, 17.6, 7.199999999999999, 0.1, 97.2, 39.7, 21.9]}, "mode": "markers", "name": "Global Sales", "x": ["Final Fantasy VII", "Star Wars: Knights of the Old Republic", "Paper Mario: The Thousand-Year Door", "The Witcher 3: Wild Hunt", "Golden Sun", "Golden Sun: The Lost Age", "Boktai: The Sun is in Your Hand", "Deus Ex", "Skies of Arcadia"], "y": [9.72, 2.19, 2.25, 4.69, 1.76, 1.22, 0.15, 0.01, 0.09], "type": "scatter", "uid": "1d18c7e8-37b8-4199-bbef-c1b93d31acb3"}, {"marker": {"color": "dodgerblue", "size": [1.0, 6.1, 14.8, 0.0, 9.3, 2.1, 0.0, 30.099999999999998, 10.2, 16.8]}, "mode": "marker
# ...

# %%
RPGgS_bar_df = df_RPG_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_RPG_TOP_10gS.groupby('Name')[['uScore']].sum()
)
RPGgS_bar_df.columns = ['cScore', 'uScore']
RPGgS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=RPGgS_bar_df.index,
    y=RPGgS_bar_df['cScore'],
    name='Critic Score',
    mode='markers',
    marker=dict(
        size=df_RPG_TOP_10gS['cScore'],
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=RPGgS_bar_df.index,
    y=RPGgS_bar_df['uScore'],
    name='User Score',
    mode='markers',
    marker=dict(
        size=df_RPG_TOP_10gS['uScore'],
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 RPG Games (Critic Score vs User Score) [Global Sales]'}
RPGgS_bar_fig = go.Figure(data=data, layout=layout)
iplot(RPGgS_bar_fig, show_link=False)
# Out:
# <div id="6a882891-9cdb-48f0-aa2c-68f7bf715904" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6a882891-9cdb-48f0-aa2c-68f7bf715904", [{"marker": {"color": "seagreen", "size": [92.0, 96.0, 92.0, 90.0, 83.0, 87.0, 92.0, 76.0, 85.0, 93.0]}, "mode": "markers", "name": "Critic Score", "x": ["The Elder Scrolls V: Skyrim", "World of Warcraft", "Final Fantasy VII", "Final Fantasy X", "Final Fantasy VIII", "Fallout 4", "Kingdom Hearts", "Pok\u00e9mon Platinum Version", "Pok\u00e9mon Emerald Version"], "y": [188.0, 93.0, 92.0, 92.0, 90.0, 87.0, 85.0, 83.0, 76.0], "type": "scatter", "uid": "fc74bee2-6342-4303-8eef-47f6ca93f530"}, {"marker": {"color": "dodgerblue", "size": [92.0, 84.0, 87.0, 86.0, 85.0, 65.0, 64.0, 90.0, 88.0, 73.0]}, "mode": "markers", "name": "User Score", "x": ["The Elder Scrolls V: Skyrim
# ...

# %%
RPGnaS_bar_df = df_RPG_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_RPG_TOP_10naS.groupby('Name')[['uScore']].sum()
)
RPGnaS_bar_df.columns = ['cScore', 'uScore']
RPGnaS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=RPGnaS_bar_df.index,
    y=RPGnaS_bar_df['cScore'],
    name='Critic Score',
    mode='markers',
    marker=dict(
        size=df_RPG_TOP_10naS['cScore'],
        color='seagreen'
    )
)

trace1 = go.Scatter(
    x=RPGnaS_bar_df.index,
    y=RPGnaS_bar_df['uScore'],
    name='User Score',
    mode='markers',
    marker=dict(
        size=df_RPG_TOP_10naS['uScore'],
        color='dodgerblue',
    )
)

data = [trace0, trace1]
layout = {'title': 'Top 10 RPG Games (Critic Score vs User Score) [NA Sales]'}
RPGnaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(RPGnaS_bar_fig, show_link=False)
# Out:
# <div id="5d04e571-6ec5-40aa-bb65-a82833b2f288" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5d04e571-6ec5-40aa-bb65-a82833b2f288", [{"marker": {"color": "seagreen", "size": [96.0, 85.0, 80.0, 93.0, 92.0, 92.0, 94.0, 83.0, 84.0, 76.0]}, "mode": "markers", "name": "Critic Score", "x": ["The Elder Scrolls V: Skyrim", "The Elder Scrolls IV: Oblivion", "Fallout 3", "Final Fantasy VII", "Final Fantasy X", "Kingdom Hearts", "Fallout: New Vegas", "Pok\u00e9mon Platinum Version", "Fable III", "Pok\u00e9mon Emerald Version"], "y": [96.0, 94.0, 93.0, 92.0, 92.0, 85.0, 84.0, 83.0, 80.0, 76.0], "type": "scatter", "uid": "142dae51-298e-44c6-959f-afd65f25fd29"}, {"marker": {"color": "dodgerblue", "size": [84.0, 88.0, 65.0, 85.0, 92.0, 87.0, 87.0, 85.0, 81.0, 90.0]}, "mode": "markers", "name": "User Score", "x"
# ...

# %%
#-----------------------------------------------------------------------
# E
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

EuC_bar_df = df_E_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_E_TOP_10uC.groupby('Name')[['gSales']].sum()
)
EuC_bar_df.columns = ['naSales', 'gSales']
EuC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=EuC_bar_df.index,
    y=EuC_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=EuC_bar_df.index,
    y=EuC_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 E Games (NA Sales vs Global Sales) [User Count]'}
EuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(EuC_bar_fig, show_link=False)
# Out:
# <div id="35e168b3-5139-4934-a13d-06cb06f9e273" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("35e168b3-5139-4934-a13d-06cb06f9e273", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["Super Mario Galaxy", "Super Mario Galaxy 2", "Mario Kart 8", "Gran Turismo 5", "LittleBigPlanet", "Super Mario 3D World", "DriveClub", "Journey", "Rocket League", "Cities: Skylines"], "y": [11.35, 7.51, 7.09, 10.7, 5.82, 4.32, 2.07, 0.21, 0.37, 0.14], "type": "scatter", "uid": "b26d68e4-cd3a-4ebb-81a2-38f579538aa4"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["Super Mario Galaxy", "Super Mario Galaxy 2", "Mario Kart 8", "Gran Turismo 5", "LittleBigPlanet", "Super Mario 3D World", "DriveClub", "Journey", "Rocket League", "
# ...

# %%
EcS_bar_df = df_E_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_E_TOP_10cS.groupby('Name')[['gSales']].sum()
)
EcS_bar_df.columns = ['naSales', 'gSales']
EcS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=EcS_bar_df.index,
    y=EcS_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=EcS_bar_df.index,
    y=EcS_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dot')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 E Games (NA Sales vs Global Sales) [Critic Score]'}
EcS_bar_fig = go.Figure(data=data, layout=layout)
iplot(EcS_bar_fig, show_link=False)
# Out:
# <div id="3c41751a-3725-4e08-a615-a2b4af0e396e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3c41751a-3725-4e08-a615-a2b4af0e396e", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["Gran Turismo 3: A-Spec", "Super Mario Galaxy", "Gran Turismo", "Super Mario Galaxy 2", "Madden NFL 2003", "LittleBigPlanet", "The Legend of Zelda: The Wind Waker", "The Legend of Zelda: A Link to the Past", "NFL 2K1", "Tony Hawk's Pro Skater 2"], "y": [14.98, 11.35, 10.95, 7.51, 4.14, 5.82, 4.6, 2.7, 1.09, 1.18], "type": "scatter", "uid": "9d4c67fc-00c2-4f24-a00a-4cde65647a72"}, {"line": {"color": "dodgerblue", "dash": "dot", "width": 4}, "name": "North American Sales", "x": ["Gran Turismo 3: A-Spec", "Super Mario Galaxy", "Gran Turismo", "Super Mario Galaxy 2", "Madden NFL 200
# ...

# %%
EuS_bar_df = df_E_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_E_TOP_10uS.groupby('Name')[['gSales']].sum()
)
EuS_bar_df.columns = ['naSales', 'gSales']
EuS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=EuS_bar_df.index,
    y=EuS_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=EuS_bar_df.index,
    y=EuS_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 E Games (NA Sales vs Global Sales) [User Score]'}
EuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(EuS_bar_fig, show_link=False)
# Out:
# <div id="565e6c15-cdcb-4693-8764-9f1cbd56c246" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("565e6c15-cdcb-4693-8764-9f1cbd56c246", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["Paper Mario: The Thousand-Year Door", "Golden Sun", "Golden Sun: The Lost Age", "Advance Wars 2: Black Hole Rising", "Harvest Moon: Friends of Mineral Town", "Backyard Baseball", "Boktai: The Sun is in Your Hand", "Rock 'N Roll Racing", "Karnaaj Rally", "Monster Rancher Advance 2"], "y": [2.25, 1.76, 1.22, 0.65, 0.59, 0.13, 0.15, 0.05, 0.01, 0.01], "type": "scatter", "uid": "04b931a8-2b89-4ee7-a7ab-746265562ebe"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["Paper Mario: The Thousand-Year Door", "Golden Sun", "Golden Sun: 
# ...

# %%
EgS_bar_df = df_E_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_E_TOP_10gS.groupby('Name')[['uScore']].sum()
)
EgS_bar_df.columns = ['cScore', 'uScore']
EgS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=EgS_bar_df.index,
    y=EgS_bar_df['cScore'],
    name='Critic Score',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=EgS_bar_df.index,
    y=EgS_bar_df['uScore'],
    name='User Score',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 E Games (Critic Score vs User Score) [Global Sales]'}
EgS_bar_fig = go.Figure(data=data, layout=layout)
iplot(EgS_bar_fig, show_link=False)
# Out:
# <div id="2632b1d8-e8a6-4563-b276-7d13745ef690" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2632b1d8-e8a6-4563-b276-7d13745ef690", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Critic Score", "x": ["Mario Kart DS", "New Super Mario Bros.", "New Super Mario Bros. Wii", "Mario Kart Wii", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", "Brain Age: Train Your Brain in Minutes a Day", "Kinect Adventures!", "Wii Play"], "y": [91.0, 89.0, 87.0, 82.0, 80.0, 80.0, 80.0, 77.0, 61.0, 58.0], "type": "scatter", "uid": "40bcced0-3b6c-4de1-8f31-4e259ec6a084"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "User Score", "x": ["Mario Kart DS", "New Super Mario Bros.", "New Super Mario Bros. Wii", "Mario Kart Wii", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", "Bra
# ...

# %%
EnaS_bar_df = df_E_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_E_TOP_10naS.groupby('Name')[['uScore']].sum()
)
EnaS_bar_df.columns = ['cScore', 'uScore']
EnaS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=EnaS_bar_df.index,
    y=EnaS_bar_df['cScore'],
    name='Critic Score',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=EnaS_bar_df.index,
    y=EnaS_bar_df['uScore'],
    name='User Score',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 E Games (Critic Score vs User Score) [NA Sales]'}
EnaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(EnaS_bar_fig, show_link=False)
# Out:
# <div id="9aa7f0f6-608c-48b9-9aa9-7619e9ad7978" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9aa7f0f6-608c-48b9-9aa9-7619e9ad7978", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Critic Score", "x": ["Gran Turismo 3: A-Spec", "Mario Kart DS", "New Super Mario Bros.", "New Super Mario Bros. Wii", "Mario Kart Wii", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", "Kinect Adventures!", "Wii Play"], "y": [95.0, 91.0, 89.0, 87.0, 82.0, 80.0, 80.0, 80.0, 61.0, 58.0], "type": "scatter", "uid": "d92c3f38-2b09-4ac8-b871-3f83c40f4106"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "User Score", "x": ["Gran Turismo 3: A-Spec", "Mario Kart DS", "New Super Mario Bros.", "New Super Mario Bros. Wii", "Mario Kart Wii", "Wii Fit", "Wii Fit Plus", "Wii Sports Resort", 
# ...

# %%
#-----------------------------------------------------------------------
# E10+
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

E10uC_bar_df = df_E10_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_E10_TOP_10uC.groupby('Name')[['gSales']].sum()
)
E10uC_bar_df.columns = ['naSales', 'gSales']
E10uC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=E10uC_bar_df.index,
    y=E10uC_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=E10uC_bar_df.index,
    y=E10uC_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 E10 Games (NA Sales vs Global Sales) [User Count]'}
E10uC_bar_fig = go.Figure(data=data, layout=layout)
iplot(E10uC_bar_fig, show_link=False)
# Out:
# <div id="aefffb5b-6012-47c3-b7c9-18df7873e4c1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aefffb5b-6012-47c3-b7c9-18df7873e4c1", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["The Legend of Zelda: Skyward Sword", "Portal 2", "Splatoon", "Sid Meier's Civilization V", "SimCity (2013)", "Knack", "Sid Meier's Civilization: Beyond Earth", "Spore", "SimCity"], "y": [3.95, 2.84, 4.43, 1.68, 1.42, 1.73, 0.36, 1.17, 0.03], "type": "scatter", "uid": "65baab86-7795-417e-9ff0-984e2179665c"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["The Legend of Zelda: Skyward Sword", "Portal 2", "Splatoon", "Sid Meier's Civilization V", "SimCity (2013)", "Knack", "Sid Meier's Civilization: Beyond Earth", "Spore", "SimC
# ...

# %%
E10uC_bar_df = df_E10_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_E10_TOP_10uC.groupby('Name')[['gSales']].sum()
)
E10uC_bar_df.columns = ['naSales', 'gSales']
E10uC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=E10uC_bar_df.index,
    y=E10uC_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=E10uC_bar_df.index,
    y=E10uC_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 E10 Games (NA Sales vs Global Sales) [User Count]'}
E10uC_bar_fig = go.Figure(data=data, layout=layout)
iplot(E10uC_bar_fig, show_link=False)
# Out:
# <div id="6bbde0c4-e5ce-4cf7-925f-6e2e70c4aaf2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6bbde0c4-e5ce-4cf7-925f-6e2e70c4aaf2", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["The Legend of Zelda: Skyward Sword", "Portal 2", "Splatoon", "Sid Meier's Civilization V", "SimCity (2013)", "Knack", "Sid Meier's Civilization: Beyond Earth", "Spore", "SimCity"], "y": [3.95, 2.84, 4.43, 1.68, 1.42, 1.73, 0.36, 1.17, 0.03], "type": "scatter", "uid": "f62998b6-4e04-41a1-a72d-b52c158e8016"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["The Legend of Zelda: Skyward Sword", "Portal 2", "Splatoon", "Sid Meier's Civilization V", "SimCity (2013)", "Knack", "Sid Meier's Civilization: Beyond Earth", "Spore", "SimC
# ...

# %%
E10cS_bar_df = df_E10_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_E10_TOP_10cS.groupby('Name')[['gSales']].sum()
)
E10cS_bar_df.columns = ['naSales', 'gSales']
E10cS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=E10cS_bar_df.index,
    y=E10cS_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=E10cS_bar_df.index,
    y=E10cS_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 E10 Games (NA Sales vs Global Sales) [Critic Score]'}
E10cS_bar_fig = go.Figure(data=data, layout=layout)
iplot(E10cS_bar_fig, show_link=False)
# Out:
# <div id="47f814c0-1c6b-4d1c-ba5d-56879203b272" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("47f814c0-1c6b-4d1c-ba5d-56879203b272", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["Portal 2", "The Legend of Zelda: Skyward Sword", "Chrono Trigger", "Rayman Legends", "Rayman Origins", "Sid Meier's Civilization IV", "Final Fantasy VI Advance"], "y": [4.54, 3.95, 1.34, 1.24, 0.55, 0.16, 0.28], "type": "scatter", "uid": "14de6e39-23a1-4ed4-9f2c-f0b30df16a71"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["Portal 2", "The Legend of Zelda: Skyward Sword", "Chrono Trigger", "Rayman Legends", "Rayman Origins", "Sid Meier's Civilization IV", "Final Fantasy VI Advance"], "y": [2.57, 2.03, 0.61, 0.39, 0.21, 0.02,
# ...

# %%
E10gS_bar_df = df_E10_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_E10_TOP_10gS.groupby('Name')[['uScore']].sum()
)
E10gS_bar_df.columns = ['cScore', 'uScore']
E10gS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=E10gS_bar_df.index,
    y=E10gS_bar_df['cScore'],
    name='Critic Score',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=E10gS_bar_df.index,
    y=E10gS_bar_df['uScore'],
    name='User Score',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 E10 Games (Critic Score vs User Score) [Global Sales]'}
E10gS_bar_fig = go.Figure(data=data, layout=layout)
iplot(E10gS_bar_fig, show_link=False)
# Out:
# <div id="de8cce00-e3a7-4678-a3fd-8d59e88e4c76" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("de8cce00-e3a7-4678-a3fd-8d59e88e4c76", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Critic Score", "x": ["Dragon Quest IX: Sentinels of the Starry Skies", "Splatoon", "LEGO Star Wars: The Complete Saga", "Nintendo Land", "Just Dance 2", "Just Dance 3", "Just Dance 4", "Kinect Sports", "Michael Jackson: The Experience", "Just Dance"], "y": [87.0, 81.0, 80.0, 77.0, 74.0, 74.0, 74.0, 73.0, 56.0, 49.0], "type": "scatter", "uid": "53e7e3c0-94a1-47b3-88d4-58040b9d2a5d"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "User Score", "x": ["Dragon Quest IX: Sentinels of the Starry Skies", "Splatoon", "LEGO Star Wars: The Complete Saga", "Nintendo Land", "Just Dance 2"
# ...

# %%
E10naS_bar_df = df_E10_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_E10_TOP_10naS.groupby('Name')[['uScore']].sum()
)
E10naS_bar_df.columns = ['cScore', 'uScore']
E10naS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=E10naS_bar_df.index,
    y=E10naS_bar_df['cScore'],
    name='Critic Score',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=E10naS_bar_df.index,
    y=E10naS_bar_df['uScore'],
    name='User Score',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 E10 Games (Critic Score vs User Score) [NA Sales]'}
E10naS_bar_fig = go.Figure(data=data, layout=layout)
iplot(E10naS_bar_fig, show_link=False)
# Out:
# <div id="e56b4f00-f811-46f7-97c9-e521391951a5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e56b4f00-f811-46f7-97c9-e521391951a5", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Critic Score", "x": ["NBA 2K16", "Daxter", "LEGO Star Wars: The Complete Saga", "Nintendo Land", "Just Dance 2", "Just Dance 3", "Just Dance 4", "Kinect Sports", "Michael Jackson: The Experience", "Just Dance"], "y": [87.0, 85.0, 80.0, 77.0, 74.0, 74.0, 74.0, 73.0, 56.0, 49.0], "type": "scatter", "uid": "24724cd4-ef1b-4ad9-9e96-3262741bfe63"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "User Score", "x": ["NBA 2K16", "Daxter", "LEGO Star Wars: The Complete Saga", "Nintendo Land", "Just Dance 2", "Just Dance 3", "Just Dance 4", "Kinect Sports", "Michael Jackson: The Experie
# ...

# %%
#-----------------------------------------------------------------------
# T
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------

TuS_bar_df = df_T_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_T_TOP_10uS.groupby('Name')[['gSales']].sum()
)
TuS_bar_df.columns = ['naSales', 'gSales']
TuS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=TuS_bar_df.index,
    y=TuS_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=TuS_bar_df.index,
    y=TuS_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 T Games (NA Sales vs Global Sales) [User Score]'}
TuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(TuS_bar_fig, show_link=False)
# Out:
# <div id="ff616772-e8a9-4410-a605-c23738883cb1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ff616772-e8a9-4410-a605-c23738883cb1", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["Metroid Prime", "Dynasty Warriors 4", "Castlevania: Symphony of the Night", "Shenmue", "MLB SlugFest Loaded", "Dynasty Warriors 3: Xtreme Legends", "Okami", "Wade Hixton's Counter Punch", "Shenmue II", "Skies of Arcadia"], "y": [2.82, 2.11, 1.27, 1.18, 0.3, 1.0, 0.63, 0.01, 0.15, 0.09], "type": "scatter", "uid": "f04b8210-f644-4569-b675-4724f2a3a685"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["Metroid Prime", "Dynasty Warriors 4", "Castlevania: Symphony of the Night", "Shenmue", "MLB SlugFest Loaded", "Dynasty Warriors 
# ...

# %%
TcS_bar_df = df_T_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_T_TOP_10cS.groupby('Name')[['gSales']].sum()
)
TcS_bar_df.columns = ['naSales', 'gSales']
TcS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=TcS_bar_df.index,
    y=TcS_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=TcS_bar_df.index,
    y=TcS_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 T Games (NA Sales vs Global Sales) [Critic Score]'}
TcS_bar_fig = go.Figure(data=data, layout=layout)
iplot(TcS_bar_fig, show_link=False)
# Out:
# <div id="b2f1a548-a88c-4862-a789-88118cf2b47a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b2f1a548-a88c-4862-a789-88118cf2b47a", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["The Legend of Zelda: Twilight Princess", "Tekken 3", "Uncharted 2: Among Thieves", "Tony Hawk's Pro Skater 2", "Batman: Arkham City", "Tony Hawk's Pro Skater 3", "Metroid Prime", "Final Fantasy IX", "SoulCalibur"], "y": [8.74, 7.16, 6.66, 4.68, 5.48, 4.41, 2.82, 5.3, 0.34], "type": "scatter", "uid": "18af1b46-ddc4-451b-8560-0d389496b584"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["The Legend of Zelda: Twilight Princess", "Tekken 3", "Uncharted 2: Among Thieves", "Tony Hawk's Pro Skater 2", "Batman: Arkham City", "Tony H
# ...

# %%
TuS_bar_df = df_T_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_T_TOP_10uS.groupby('Name')[['gSales']].sum()
)
TuS_bar_df.columns = ['naSales', 'gSales']
TuS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=TuS_bar_df.index,
    y=TuS_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=TuS_bar_df.index,
    y=TuS_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 T Games (NA Sales vs Global Sales) [User Score]'}
TuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(TuS_bar_fig, show_link=False)
# Out:
# <div id="bbc28c10-9f92-4a70-842d-228168961648" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bbc28c10-9f92-4a70-842d-228168961648", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["Metroid Prime", "Dynasty Warriors 4", "Castlevania: Symphony of the Night", "Shenmue", "MLB SlugFest Loaded", "Dynasty Warriors 3: Xtreme Legends", "Okami", "Wade Hixton's Counter Punch", "Shenmue II", "Skies of Arcadia"], "y": [2.82, 2.11, 1.27, 1.18, 0.3, 1.0, 0.63, 0.01, 0.15, 0.09], "type": "scatter", "uid": "07336514-857f-460b-92be-2b265908cad0"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["Metroid Prime", "Dynasty Warriors 4", "Castlevania: Symphony of the Night", "Shenmue", "MLB SlugFest Loaded", "Dynasty Warriors 
# ...

# %%
TgS_bar_df = df_T_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_T_TOP_10gS.groupby('Name')[['uScore']].sum()
)
TgS_bar_df.columns = ['cScore', 'uScore']
TgS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=TgS_bar_df.index,
    y=TgS_bar_df['cScore'],
    name='Critic Score',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=TgS_bar_df.index,
    y=TgS_bar_df['uScore'],
    name='User Score',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 T Games (Critic Score vs User Score) [Global Sales]'}
TgS_bar_fig = go.Figure(data=data, layout=layout)
iplot(TgS_bar_fig, show_link=False)
# Out:
# <div id="ef557b42-88db-4d07-8e3f-7ecaadab3956" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ef557b42-88db-4d07-8e3f-7ecaadab3956", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Critic Score", "x": ["Tekken 3", "The Legend of Zelda: Twilight Princess", "Gran Turismo 2", "Super Smash Bros. Brawl", "Final Fantasy VII", "Final Fantasy X", "Super Smash Bros. Melee", "Final Fantasy VIII", "Medal of Honor: Frontline", "The Sims 3"], "y": [96.0, 95.0, 93.0, 93.0, 92.0, 92.0, 92.0, 90.0, 88.0, 86.0], "type": "scatter", "uid": "0856a4b1-448a-4aa0-9f51-f8f29386c448"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "User Score", "x": ["Tekken 3", "The Legend of Zelda: Twilight Princess", "Gran Turismo 2", "Super Smash Bros. Brawl", "Final Fantasy VII", "Final Fa
# ...

# %%
TnaS_bar_df = df_T_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_T_TOP_10naS.groupby('Name')[['uScore']].sum()
)
TnaS_bar_df.columns = ['cScore', 'uScore']
TnaS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=TnaS_bar_df.index,
    y=TnaS_bar_df['cScore'],
    name='Critic Score',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=TnaS_bar_df.index,
    y=TnaS_bar_df['uScore'],
    name='User Score',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 T Games (Critic Score vs User Score) [NA Sales]'}
TnaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(TnaS_bar_fig, show_link=False)
# Out:
# <div id="a4e8cbed-ed7d-48ac-9494-84dc8c7d0f08" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a4e8cbed-ed7d-48ac-9494-84dc8c7d0f08", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Critic Score", "x": ["Guitar Hero III: Legends of Rock", "Tekken 3", "Uncharted 2: Among Thieves", "The Legend of Zelda: Twilight Princess", "Gran Turismo 2", "Super Smash Bros. Brawl", "Guitar Hero II", "Super Smash Bros. Melee", "Tony Hawk's Pro Skater"], "y": [167.0, 96.0, 96.0, 95.0, 93.0, 93.0, 92.0, 92.0, 92.0], "type": "scatter", "uid": "2fcb61ee-ea78-4791-bbfe-45603f028b3b"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "User Score", "x": ["Guitar Hero III: Legends of Rock", "Tekken 3", "Uncharted 2: Among Thieves", "The Legend of Zelda: Twilight Princess", "Gran Tur
# ...

# %%
#-----------------------------------------------------------------------
# M
# 1. (NA Sales vs Global Sales) [User Count]
# 2. (NA Sales vs Global Sales) [Critic Score]
# 3. (NA Sales vs Global Sales) [User Score]
# 4. (Critic Score vs User Score) [Global Sales]
# 5. (Critic Score vs User Score) [North American Sales]
#-----------------------------------------------------------------------
MuC_bar_df = df_M_TOP_10uC.groupby('Name')[['naSales']].sum().join(
    df_M_TOP_10uC.groupby('Name')[['gSales']].sum()
)
MuC_bar_df.columns = ['naSales', 'gSales']
MuC_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=MuC_bar_df.index,
    y=MuC_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=MuC_bar_df.index,
    y=MuC_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 M Games (NA Sales vs Global Sales) [User Count]'}
MuC_bar_fig = go.Figure(data=data, layout=layout)
iplot(MuC_bar_fig, show_link=False)
# Out:
# <div id="7897d061-2205-4433-b0ee-7d2e40c75a6f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7897d061-2205-4433-b0ee-7d2e40c75a6f", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["Call of Duty: Modern Warfare 3", "Diablo III", "The Last of Us", "Half-Life 2", "The Witcher 3: Wild Hunt", "The Elder Scrolls V: Skyrim", "Fallout 4", "BioShock Infinite", "Counter-Strike: Source"], "y": [14.73, 5.14, 5.87, 2.37, 4.69, 3.88, 1.29, 0.66, 0.08], "type": "scatter", "uid": "931324e7-54b5-42e9-a0ff-85153e976704"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["Call of Duty: Modern Warfare 3", "Diablo III", "The Last of Us", "Half-Life 2", "The Witcher 3: Wild Hunt", "The Elder Scrolls V: Skyrim", "Fallout 4", "B
# ...

# %%
McS_bar_df = df_M_TOP_10cS.groupby('Name')[['naSales']].sum().join(
    df_M_TOP_10cS.groupby('Name')[['gSales']].sum()
)
McS_bar_df.columns = ['naSales', 'gSales']
McS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=McS_bar_df.index,
    y=McS_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=McS_bar_df.index,
    y=McS_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 M Games (NA Sales vs Global Sales) [Critic Score]'}
McS_bar_fig = go.Figure(data=data, layout=layout)
iplot(McS_bar_fig, show_link=False)
# Out:
# <div id="69d2c872-5fe8-460b-a167-042b74eb78a9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("69d2c872-5fe8-460b-a167-042b74eb78a9", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["Grand Theft Auto V", "Grand Theft Auto IV", "Grand Theft Auto III", "The Elder Scrolls V: Skyrim", "Halo: Combat Evolved", "Metal Gear Solid 2: Sons of Liberty"], "y": [55.400000000000006, 21.509999999999998, 13.1, 8.79, 6.43, 6.05], "type": "scatter", "uid": "24d5e9fa-f475-44e3-91a1-e7557ce24bab"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["Grand Theft Auto V", "Grand Theft Auto IV", "Grand Theft Auto III", "The Elder Scrolls V: Skyrim", "Halo: Combat Evolved", "Metal Gear Solid 2: Sons of Liberty"], "y": [23.45, 11.52,
# ...

# %%
MuS_bar_df = df_M_TOP_10uS.groupby('Name')[['naSales']].sum().join(
    df_M_TOP_10uS.groupby('Name')[['gSales']].sum()
)
MuS_bar_df.columns = ['naSales', 'gSales']
MuS_bar_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=MuS_bar_df.index,
    y=MuS_bar_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=MuS_bar_df.index,
    y=MuS_bar_df['naSales'],
    name='North American Sales',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 M Games (NA Sales vs Global Sales) [User Score]'}
MuS_bar_fig = go.Figure(data=data, layout=layout)
iplot(MuS_bar_fig, show_link=False)
# Out:
# <div id="e38b5eaf-1271-4b73-90d3-bb197b9bd298" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e38b5eaf-1271-4b73-90d3-bb197b9bd298", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Global Sales", "x": ["Metal Gear Solid", "Resident Evil 2", "Metal Gear Solid 3: Snake Eater", "Resident Evil 4", "Metal Gear Solid 3: Subsistence", "Legacy of Kain: Defiance", "The Witcher 3: Wild Hunt", "Deus Ex", "Steins;Gate 0", "The Orange Box"], "y": [6.03, 5.82, 4.23, 1.69, 0.55, 0.53, 0.72, 0.01, 0.09, 0.14], "type": "scatter", "uid": "e03b2b91-fc54-4415-88d6-db359903b708"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "North American Sales", "x": ["Metal Gear Solid", "Resident Evil 2", "Metal Gear Solid 3: Snake Eater", "Resident Evil 4", "Metal Gear Solid 3: Subsis
# ...

# %%
MgS_bar_df = df_M_TOP_10gS.groupby('Name')[['cScore']].sum().join(
    df_M_TOP_10gS.groupby('Name')[['uScore']].sum()
)
MgS_bar_df.columns = ['cScore', 'uScore']
MgS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=MgS_bar_df.index,
    y=MgS_bar_df['cScore'],
    name='Critic Score',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=MgS_bar_df.index,
    y=MgS_bar_df['uScore'],
    name='User Score',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 M Games (Critic Score vs User Score) [Global Sales]'}
MgS_bar_fig = go.Figure(data=data, layout=layout)
iplot(MgS_bar_fig, show_link=False)
# Out:
# <div id="166a668d-a641-4a16-aec3-f2883578b9c3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("166a668d-a641-4a16-aec3-f2883578b9c3", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Critic Score", "x": ["Grand Theft Auto V", "Call of Duty: Modern Warfare 3", "Call of Duty: Black Ops II", "Grand Theft Auto: San Andreas", "Grand Theft Auto: Vice City", "Call of Duty: Modern Warfare 2", "Call of Duty: Black Ops"], "y": [194.0, 176.0, 166.0, 95.0, 95.0, 94.0, 87.0], "type": "scatter", "uid": "ec1efa77-1aab-4da9-b72b-0d16bb8bfc00"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "User Score", "x": ["Grand Theft Auto V", "Call of Duty: Modern Warfare 3", "Call of Duty: Black Ops II", "Grand Theft Auto: San Andreas", "Grand Theft Auto: Vice City", "Call of Duty:
# ...

# %%
MnaS_bar_df = df_M_TOP_10naS.groupby('Name')[['cScore']].sum().join(
    df_M_TOP_10naS.groupby('Name')[['uScore']].sum()
)
MnaS_bar_df.columns = ['cScore', 'uScore']
MnaS_bar_df.sort_values('cScore', ascending=False, inplace=True)

trace0 = go.Scatter(
    x=MnaS_bar_df.index,
    y=MnaS_bar_df['cScore'],
    name='Critic Score',
    line = dict(
        color = 'seagreen',
        width = 4,
        dash = 'dot')
)

trace1 = go.Scatter(
    x=MnaS_bar_df.index,
    y=MnaS_bar_df['uScore'],
    name='User Score',
    line = dict(
        color = 'dodgerblue',
        width = 4,
        dash = 'dash')
)

data = [trace0, trace1]
layout = {'title': 'Top 10 M Games (Critic Score vs User Score) [NA Sales]'}
MnaS_bar_fig = go.Figure(data=data, layout=layout)
iplot(MnaS_bar_fig, show_link=False)
# Out:
# <div id="d179b0f2-2765-4497-a194-4d6a8b7eac36" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d179b0f2-2765-4497-a194-4d6a8b7eac36", [{"line": {"color": "seagreen", "dash": "dot", "width": 4}, "name": "Critic Score", "x": ["Grand Theft Auto V", "Grand Theft Auto: San Andreas", "Grand Theft Auto: Vice City", "Call of Duty: Modern Warfare 2", "Halo 3", "Halo: Reach", "Call of Duty: Modern Warfare 3", "Call of Duty: Black Ops", "Call of Duty: Black Ops II"], "y": [194.0, 95.0, 95.0, 94.0, 94.0, 91.0, 88.0, 87.0, 83.0], "type": "scatter", "uid": "10e158f5-3ec3-46c8-92f1-28fb6f9ea45e"}, {"line": {"color": "dodgerblue", "dash": "dash", "width": 4}, "name": "User Score", "x": ["Grand Theft Auto V", "Grand Theft Auto: San Andreas", "Grand Theft Auto: Vice City", "Call of Duty: Modern Warfare 2", "Halo 3",
# ...

# %%
#-----------------------------------------------------------------------
# PLOTLY: LINE GRAPH
# 1. Create a trace for global sales (line)
# 2. Create a trace for # of games released (line)
# 3. Define data array
# 4. Set Title
# 5. Create a figure
# 6. Plot the results
#-----------------------------------------------------------------------
overviewgS_df = df.groupby('Release Date')[['gSales']].sum().join(
    df.groupby('Release Date')[['Name']].count())
overviewgS_df.columns = ['gSales', 'Number of Games']

trace0 = go.Scatter(
    x=overviewgS_df.index,
    y=overviewgS_df['gSales'],
    name='Global Sales',
    line = dict(
        color = 'seagreen',
        width = 4,
    )
)

trace1 = go.Scatter(
    x=overviewgS_df.index,
    y=overviewgS_df['Number of Games'],
    name='Number of games released',
    line = dict(
        color = 'dodgerblue',
        width = 4,
    )
)

data = [trace0, trace1]
layout = {'title': 'Statistics for video games (Global)'}
overviewgS_fig = go.Figure(data=data, layout=layout)
iplot(overviewgS_fig, show_link=False)
# Out:
# <div id="578332be-59b5-4163-b86f-73d9291be056" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("578332be-59b5-4163-b86f-73d9291be056", [{"line": {"color": "seagreen", "width": 4}, "name": "Global Sales", "x": [1985, 1988, 1992, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], "y": [0.03, 0.03, 0.03, 1.27, 20.099999999999998, 35.01, 43.18, 51.170000000000016, 81.23999999999995, 253.88000000000008, 288.8399999999994, 255.35000000000028, 321.7799999999992, 334.31999999999914, 334.1899999999988, 456.2299999999996, 489.11999999999904, 459.84999999999974, 412.9600000000002, 383.68999999999915, 291.9299999999998, 267.1699999999998, 192.43, 159.16, 91.56000000000004], "type": "scatter", "uid": "9720f32b-254d-4ba6-9b97-57b606
# ...

# %%
#-----------------------------------------------------------------------
# PLOTLY: BAR GRAPH
# 1. Compute calculations and prep dataset
# 2. Create a trace for global sales (bar)
# 3. Create a trace for # of games released (bar)
# 4. Define data array
# 5. Set Title
# 6. Create a figure
# 7. Plot the results
#-----------------------------------------------------------------------

marketgS_df = df.groupby('Platform')[['gSales']].sum().join(
    df.groupby('Platform')[['Name']].count()
)
marketgS_df.columns = ['gSales', 'Number of Games']
marketgS_df.sort_values('gSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=marketgS_df.index,
    y=marketgS_df['gSales'],
    name='Global Sales'
)

trace1 = go.Bar(
    x=marketgS_df.index,
    y=marketgS_df['Number of Games'],
    name='Number of games released'
)

data = [trace0, trace1]
layout = {'title': 'Market share by gaming platform (Global)'}
marketgS_fig = go.Figure(data=data, layout=layout)
iplot(marketgS_fig, show_link=False)
# Out:
# <div id="230a1c42-738d-43b8-b136-5f67663ff806" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("230a1c42-738d-43b8-b136-5f67663ff806", [{"name": "Global Sales", "x": ["PS2", "X360", "PS3", "Wii", "DS", "PS4", "XB", "PS", "PSP", "PC", "GC", "GBA", "XOne", "3DS", "WiiU", "PSV", "DC"], "y": [945.9699999999991, 853.3000000000002, 784.3000000000008, 576.4500000000002, 382.3299999999998, 243.02999999999994, 212.07000000000045, 206.5500000000002, 187.92000000000021, 187.12000000000089, 159.42000000000056, 131.75000000000017, 129.57000000000002, 123.22999999999993, 66.08, 30.88000000000001, 4.550000000000001], "type": "bar", "uid": "d930309c-f580-42cf-8417-ebf44344f54f"}, {"name": "Number of games released", "x": ["PS2", "X360", "PS3", "Wii", "DS", "PS4", "XB", "PS", "PSP", "PC", "GC", "GBA", "XOne", "3DS",
# ...

# %%
#-----------------------------------------------------------------------
# PLOTLY: BAR GRAPH
# 1. Compute calculations and prep dataset
# 2. Create a trace for global sales (bar)
# 3. Create a trace for # of games released (bar)
# 4. Define data array
# 5. Set Title
# 6. Create a figure
# 7. Plot the results
#-----------------------------------------------------------------------

marketnaS_df = df.groupby('Platform')[['naSales']].sum().join(
    df.groupby('Platform')[['Name']].count()
)
marketnaS_df.columns = ['naSales', 'Number of Games']
marketnaS_df.sort_values('naSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=marketnaS_df.index,
    y=marketnaS_df['naSales'],
    name='North American Sales'
)

trace1 = go.Bar(
    x=marketnaS_df.index,
    y=marketnaS_df['Number of Games'],
    name='Games Released'
)

data = [trace0, trace1]
layout = {'title': 'Market share by gaming platform (NA vs Global)'}
marketnaS_fig = go.Figure(data=data, layout=layout)
iplot(marketnaS_fig, show_link=False)
# Out:
# <div id="0815bb79-9a8a-4371-bc5d-b46c54382888" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0815bb79-9a8a-4371-bc5d-b46c54382888", [{"name": "North American Sales", "x": ["X360", "PS2", "PS3", "Wii", "DS", "XB", "GC", "PS", "PS4", "PSP", "GBA", "XOne", "PC", "3DS", "WiiU", "PSV", "DC"], "y": [533.4300000000001, 472.64999999999856, 341.6199999999998, 301.5500000000005, 173.4000000000003, 153.23000000000062, 107.93000000000006, 91.76, 84.1600000000001, 81.69999999999992, 79.38999999999996, 75.58000000000006, 63.759999999999984, 48.67000000000001, 30.689999999999994, 9.929999999999982, 1.54], "type": "bar", "uid": "93d793a2-06b9-47a3-a96c-5f1e7faa040c"}, {"name": "Games Released", "x": ["X360", "PS2", "PS3", "Wii", "DS", "XB", "GC", "PS", "PS4", "PSP", "GBA", "XOne", "PC", "3DS", "WiiU", "PSV", "DC
# ...

# %%
naS_vs_gS_df = df.groupby('Platform')[['gSales']].sum().join(
    df.groupby('Platform')[['naSales']].sum()
)
naS_vs_gS_df.columns = ['gSales', 'naSales']
naS_vs_gS_df.sort_values('gSales', ascending=False, inplace=True)

trace0 = go.Bar(
    x=naS_vs_gS_df.index,
    y=naS_vs_gS_df['gSales'],
    name='Global Sales'
)

trace1 = go.Bar(
    x=naS_vs_gS_df.index,
    y=naS_vs_gS_df['naSales'],
    name='North American Sales'
)

data = [trace0, trace1]
layout = {'title': 'Market share by gaming platform (Global)'}
naS_vs_gS_fig = go.Figure(data=data, layout=layout)
iplot(naS_vs_gS_fig, show_link=False)
# Out:
# <div id="a2c92d55-a3bc-4e55-88eb-8f35257ef063" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a2c92d55-a3bc-4e55-88eb-8f35257ef063", [{"name": "Global Sales", "x": ["PS2", "X360", "PS3", "Wii", "DS", "PS4", "XB", "PS", "PSP", "PC", "GC", "GBA", "XOne", "3DS", "WiiU", "PSV", "DC"], "y": [945.9699999999991, 853.3000000000002, 784.3000000000008, 576.4500000000002, 382.3299999999998, 243.02999999999994, 212.07000000000045, 206.5500000000002, 187.92000000000021, 187.12000000000089, 159.42000000000056, 131.75000000000017, 129.57000000000002, 123.22999999999993, 66.08, 30.88000000000001, 4.550000000000001], "type": "bar", "uid": "1539cadf-d084-4f88-88ff-4920ee3c8235"}, {"name": "North American Sales", "x": ["PS2", "X360", "PS3", "Wii", "DS", "PS4", "XB", "PS", "PSP", "PC", "GC", "GBA", "XOne", "3DS", "Wi
# ...

# %%
#-----------------------------------------------------------------------
# PLOTLY: BOX PLOT
# 1. Prep empty array
# 2. Create a trace for each genre in dataset (box)
# 3. Visualize results
#-----------------------------------------------------------------------

data = []
for genre in df.Genre.unique():
    data.append(
        go.Box(y=df[df.Genre == genre].cScore, name=genre)
    )
    
iplot(data, show_link=False)
# Out:
# <div id="644b5371-bb2a-4743-813a-a0af743d6170" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("644b5371-bb2a-4743-813a-a0af743d6170", [{"name": "Racing", "y": [82.0, 91.0, 95.0, 85.0, 89.0, 96.0, 84.0, 93.0, 85.0, 88.0, 82.0, 92.0, 93.0, 88.0, 91.0, 82.0, 80.0, 90.0, 84.0, 74.0, 64.0, 81.0, 89.0, 93.0, 84.0, 78.0, 80.0, 85.0, 82.0, 73.0, 82.0, 62.0, 81.0, 86.0, 77.0, 79.0, 88.0, 82.0, 85.0, 89.0, 72.0, 71.0, 72.0, 59.0, 73.0, 80.0, 85.0, 69.0, 87.0, 80.0, 83.0, 87.0, 85.0, 61.0, 83.0, 64.0, 84.0, 77.0, 61.0, 79.0, 83.0, 71.0, 76.0, 60.0, 52.0, 64.0, 91.0, 87.0, 88.0, 86.0, 86.0, 78.0, 88.0, 82.0, 73.0, 84.0, 74.0, 57.0, 74.0, 94.0, 67.0, 80.0, 83.0, 57.0, 75.0, 63.0, 71.0, 83.0, 78.0, 82.0, 70.0, 55.0, 85.0, 85.0, 50.0, 57.0, 82.0, 61.0, 87.0, 83.0, 47.0, 88.0, 91.0, 81.0, 63.0, 87.0, 83.0, 61.0, 9
# ...

# %%
plotly.offline.plot(overviewgS_fig, filename='years_stats.html', show_link=False);
plotly.offline.plot(marketgS_fig, filename='global_market_share_platform.html', show_link=False);
plotly.offline.plot(marketnaS_fig, filename='na_market_share_platform.html', show_link=False);
plotly.offline.plot(naS_vs_gS_fig, filename='global_vs_na_market_share.html');
plotly.offline.plot(data, filename='genre_score_box.html', show_link=False);

# %%
plotly.offline.plot(X360uC_bar_fig, filename='X360uC.html', show_link=False);
plotly.offline.plot(X360cS_bar_fig, filename='X360cS.html', show_link=False);
plotly.offline.plot(X360uS_bar_fig, filename='X360uS.html', show_link=False);
plotly.offline.plot(X360gS_bar_fig, filename='X360gS.html', show_link=False);
plotly.offline.plot(X360naS_bar_fig, filename='X360naS.html', show_link=False);

# %%
plotly.offline.plot(PS4uC_bar_fig, filename='PS4uC_stats.html', show_link=False);
plotly.offline.plot(PS4cS_bar_fig, filename='PS4cS_stats.html', show_link=False);
plotly.offline.plot(PS4uS_bar_fig, filename='PS4uS_stats.html', show_link=False);
plotly.offline.plot(PS4gS_bar_fig, filename='PS4gS_stats.html', show_link=False);
plotly.offline.plot(PS4naS_bar_fig, filename='PS4naS_stats.html', show_link=False);

# %%
plotly.offline.plot(PS3uC_bar_fig, filename='PS3uC_stats.html', show_link=False);
plotly.offline.plot(PS3cS_bar_fig, filename='PS3cS_stats.html', show_link=False);
plotly.offline.plot(PS3uS_bar_fig, filename='PS3uS_stats.html', show_link=False);
plotly.offline.plot(PS3gS_bar_fig, filename='PS3gS_stats.html', show_link=False);
plotly.offline.plot(PS3naS_bar_fig, filename='PS3naS_stats.html', show_link=False);

# %%
plotly.offline.plot(PCuC_bar_fig, filename='PCuC_stats.html', show_link=False);
plotly.offline.plot(PCcS_bar_fig, filename='PCcS_stats.html', show_link=False);
plotly.offline.plot(PCuS_bar_fig, filename='PCuS_stats.html', show_link=False);
plotly.offline.plot(PCgS_bar_fig, filename='PCgS_stats.html', show_link=False);
plotly.offline.plot(PCnaS_bar_fig, filename='PCnaS_stats.html', show_link=False);

# %%
plotly.offline.plot(WiiuC_bar_fig, filename='WiiuC_stats.html', show_link=False);
plotly.offline.plot(WiicS_bar_fig, filename='WiicS_stats.html', show_link=False);
plotly.offline.plot(WiiuS_bar_fig, filename='WiiuS_stats.html', show_link=False);
plotly.offline.plot(WiigS_bar_fig, filename='WiigS_stats.html', show_link=False);
plotly.offline.plot(WiinaS_bar_fig, filename='WiinaS_stats.html', show_link=False);

# %%
plotly.offline.plot(NintendouC_bar_fig, filename='NintendouC_stats.html', show_link=False);
plotly.offline.plot(NintendocS_bar_fig, filename='NintendocS_stats.html', show_link=False);
plotly.offline.plot(NintendouS_bar_fig, filename='NintendouS_stats.html', show_link=False);
plotly.offline.plot(NintendogS_bar_fig, filename='NintendogS_stats.html', show_link=False);
plotly.offline.plot(NintendonaS_bar_fig, filename='NintendonaS_stats.html', show_link=False);

# %%
plotly.offline.plot(EAuC_bar_fig, filename='EAuC_stats.html', show_link=False);
plotly.offline.plot(EAcS_bar_fig, filename='EAcS_stats.html', show_link=False);
plotly.offline.plot(EAuS_bar_fig, filename='EAuS_stats.html', show_link=False);
plotly.offline.plot(EAgS_bar_fig, filename='EAgS_stats.html', show_link=False);
plotly.offline.plot(EAnaS_bar_fig, filename='EAnaS_stats.html', show_link=False);

# %%
plotly.offline.plot(SonyuC_bar_fig, filename='SonyuC_stats.html', show_link=False);
plotly.offline.plot(SonycS_bar_fig, filename='SonycS_stats.html', show_link=False);
plotly.offline.plot(SonyuS_bar_fig, filename='SonyuS_stats.html', show_link=False);
plotly.offline.plot(SonygS_bar_fig, filename='SonygS_stats.html', show_link=False);
plotly.offline.plot(SonynaS_bar_fig, filename='SonynaS_stats.html', show_link=False);

# %%
plotly.offline.plot(ActivisionuC_bar_fig, filename='ActivisionuC_stats.html', show_link=False);
plotly.offline.plot(ActivisioncS_bar_fig, filename='ActivisioncS_stats.html', show_link=False);
plotly.offline.plot(ActivisionuS_bar_fig, filename='ActivisionuS_stats.html', show_link=False);
plotly.offline.plot(ActivisiongS_bar_fig, filename='ActivisiongS_stats.html', show_link=False);
plotly.offline.plot(ActivisionnaS_bar_fig, filename='ActivisionnaS_stats.html', show_link=False);

# %%
plotly.offline.plot(BethesdauC_bar_fig, filename='BethesdauC_stats.html', show_link=False);
plotly.offline.plot(BethesdacS_bar_fig, filename='BethesdacS_stats.html', show_link=False);
plotly.offline.plot(BethesdauS_bar_fig, filename='BethesdauS_stats.html', show_link=False);
plotly.offline.plot(BethesdagS_bar_fig, filename='BethesdagS_stats.html', show_link=False);
plotly.offline.plot(BethesdanaS_bar_fig, filename='BethesdanaS_stats.html', show_link=False);

# %%
plotly.offline.plot(y2011uC_bar_fig, filename='y2011uC_stats.html', show_link=False);
plotly.offline.plot(y2011cS_bar_fig, filename='y2011cS_stats.html', show_link=False);
plotly.offline.plot(y2011uS_bar_fig, filename='y2011uS_stats.html', show_link=False);
plotly.offline.plot(y2011gS_bar_fig, filename='y2011gS_stats.html', show_link=False);
plotly.offline.plot(y2011naS_bar_fig, filename='y2011naS_stats.html', show_link=False);

# %%
plotly.offline.plot(y2012uC_bar_fig, filename='y2012uC_stats.html', show_link=False);
plotly.offline.plot(y2012cS_bar_fig, filename='y2012cS_stats.html', show_link=False);
plotly.offline.plot(y2012uS_bar_fig, filename='y2012uS_stats.html', show_link=False);
plotly.offline.plot(y2012gS_bar_fig, filename='y2012gS_stats.html', show_link=False);
plotly.offline.plot(y2012naS_bar_fig, filename='y2012naS_stats.html', show_link=False);

# %%
plotly.offline.plot(y2013uC_bar_fig, filename='y2013uC_stats.html', show_link=False);
plotly.offline.plot(y2013cS_bar_fig, filename='y2013cS_stats.html', show_link=False);
plotly.offline.plot(y2013uS_bar_fig, filename='y2013uS_stats.html', show_link=False);
plotly.offline.plot(y2013gS_bar_fig, filename='y2013gS_stats.html', show_link=False);
plotly.offline.plot(y2013naS_bar_fig, filename='y2013naS_stats.html', show_link=False);

# %%
plotly.offline.plot(y2014uC_bar_fig, filename='y2014uC_stats.html', show_link=False);
plotly.offline.plot(y2014cS_bar_fig, filename='y2014cS_stats.html', show_link=False);
plotly.offline.plot(y2014uS_bar_fig, filename='y2014uS_stats.html', show_link=False);
plotly.offline.plot(y2014gS_bar_fig, filename='y2014gS_stats.html', show_link=False);
plotly.offline.plot(y2014naS_bar_fig, filename='y2014naS_stats.html', show_link=False);

# %%
plotly.offline.plot(y2015uC_bar_fig, filename='y2015uC_stats.html', show_link=False);
plotly.offline.plot(y2015cS_bar_fig, filename='y2015cS_stats.html', show_link=False);
plotly.offline.plot(y2015uS_bar_fig, filename='y2015uS_stats.html', show_link=False);
plotly.offline.plot(y2015gS_bar_fig, filename='y2015gS_stats.html', show_link=False);
plotly.offline.plot(y2015naS_bar_fig, filename='y2015naS_stats.html', show_link=False);

# %%
plotly.offline.plot(ActionuC_bar_fig, filename='ActionuC_stats.html', show_link=False);
plotly.offline.plot(ActioncS_bar_fig, filename='ActioncS_stats.html', show_link=False);
plotly.offline.plot(ActionuS_bar_fig, filename='ActionuS_stats.html', show_link=False);
plotly.offline.plot(ActiongS_bar_fig, filename='ActiongS_stats.html', show_link=False);
plotly.offline.plot(ActionnaS_bar_fig, filename='ActionnaS_stats.html', show_link=False);

# %%
plotly.offline.plot(ShooteruC_bar_fig, filename='ShooteruC_stats.html', show_link=False);
plotly.offline.plot(ShootercS_bar_fig, filename='ShootercS_stats.html', show_link=False);
plotly.offline.plot(ShooteruS_bar_fig, filename='ShooteruS_stats.html', show_link=False);
plotly.offline.plot(ShootergS_bar_fig, filename='ShootergS_stats.html', show_link=False);
plotly.offline.plot(ShooternaS_bar_fig, filename='ShooternaS_stats.html', show_link=False);

# %%
plotly.offline.plot(StrategyuC_bar_fig, filename='StrategyuC_stats.html', show_link=False);
plotly.offline.plot(StrategycS_bar_fig, filename='StrategycS_stats.html', show_link=False);
plotly.offline.plot(StrategyuS_bar_fig, filename='StrategyuS_stats.html', show_link=False);
plotly.offline.plot(StrategygS_bar_fig, filename='StrategygS_stats.html', show_link=False);
plotly.offline.plot(StrategynaS_bar_fig, filename='StrategynaS_stats.html', show_link=False);

# %%
plotly.offline.plot(SportsuC_bar_fig, filename='SportsuC_stats.html', show_link=False);
plotly.offline.plot(SportscS_bar_fig, filename='SportscS_stats.html', show_link=False);
plotly.offline.plot(SportsuS_bar_fig, filename='SportsuS_stats.html', show_link=False);
plotly.offline.plot(SportsgS_bar_fig, filename='SportsgS_stats.html', show_link=False);
plotly.offline.plot(SportsnaS_bar_fig, filename='SportsnaS_stats.html', show_link=False);

# %%
plotly.offline.plot(RPGuC_bar_fig, filename='RPGuC_stats.html', show_link=False);
plotly.offline.plot(RPGcS_bar_fig, filename='RPGcS_stats.html', show_link=False);
plotly.offline.plot(RPGuS_bar_fig, filename='RPGuS_stats.html', show_link=False);
plotly.offline.plot(RPGgS_bar_fig, filename='RPGgS_stats.html', show_link=False);
plotly.offline.plot(RPGnaS_bar_fig, filename='RPGnaS_stats.html', show_link=False);

# %%
plotly.offline.plot(EuC_bar_fig, filename='EuC_stats.html', show_link=False);
plotly.offline.plot(EcS_bar_fig, filename='EcS_stats.html', show_link=False);
plotly.offline.plot(EuS_bar_fig, filename='EuS_stats.html', show_link=False);
plotly.offline.plot(EgS_bar_fig, filename='EgS_stats.html', show_link=False);
plotly.offline.plot(EnaS_bar_fig, filename='EnaS_stats.html', show_link=False);

# %%
plotly.offline.plot(E10uC_bar_fig, filename='E10uC_stats.html', show_link=False);
plotly.offline.plot(E10cS_bar_fig, filename='E10cS_stats.html', show_link=False);
plotly.offline.plot(E10uS_bar_fig, filename='E10uS_stats.html', show_link=False);
plotly.offline.plot(E10gS_bar_fig, filename='E10gS_stats.html', show_link=False);
plotly.offline.plot(E10naS_bar_fig, filename='E10naS_stats.html', show_link=False);

# %%
plotly.offline.plot(TuC_bar_fig, filename='TuC_stats.html', show_link=False);
plotly.offline.plot(TcS_bar_fig, filename='TcS_stats.html', show_link=False);
plotly.offline.plot(TuS_bar_fig, filename='TuS_stats.html', show_link=False);
plotly.offline.plot(TgS_bar_fig, filename='TgS_stats.html', show_link=False);
plotly.offline.plot(TnaS_bar_fig, filename='TnaS_stats.html', show_link=False);

# %%
plotly.offline.plot(MuC_bar_fig, filename='MuC_stats.html', show_link=False);
plotly.offline.plot(McS_bar_fig, filename='McS_stats.html', show_link=False);
plotly.offline.plot(MuS_bar_fig, filename='MuS_stats.html', show_link=False);
plotly.offline.plot(MgS_bar_fig, filename='MgS_stats.html', show_link=False);
plotly.offline.plot(MnaS_bar_fig, filename='MnaS_stats.html', show_link=False);
